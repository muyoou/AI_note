# %% [markdown]
# ### 双层神经网络实现非线性回归
# 加载自定义数据：

# %%
import pandas as pd
import torch
import matplotlib.pyplot as plt
data = pd.read_csv("data/myData/data_3d.csv")
plt.scatter(data['X'],data['Y'])

# %%
import pandas as pd
from torch.utils.data import DataLoader, TensorDataset
from torch.utils.data import Dataset

class CustomDataset(Dataset):
    def __init__(self, file):
        self.data = pd.read_csv(file)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        X = torch.tensor([self.data.iloc[idx, 1]]).float()
        Y = torch.tensor([self.data.iloc[idx, 2]]).float()
        return X, Y

# %%
training_data = CustomDataset("data/myData/data_3d.csv")
train_dataloader = DataLoader(training_data, batch_size=10, shuffle=True)

# %%
import torch
from torch import nn

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# #### 定义类

# %% [markdown]
# 双层神经元

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = torch.nn.Linear(1, 4)  # 输入维度为 1，输出维度为 1
        self.relu = nn.Sigmoid()
        self.linear2 = torch.nn.Linear(4, 1)  # 输入维度为 1，输出维度为 1

    def forward(self, x):
        y_pred = self.linear(x)
        y_pred = self.relu(y_pred)
        y_pred = self.linear2(y_pred)
        return y_pred

# %% [markdown]
# #### 激活函数
# - Sigmoid函数：Sigmoid函数是一种常用的非线性激活函数，其数学形式为$f(x)=\frac{1}{1+e^{-x}}$。它的输出范围在0到1之间，可以用于二分类问题。
# - ReLU函数：ReLU函数是一种非线性激活函数，其数学形式为$f(x)=max(0,x)$。它在$x>0$时输出$x$，在$x\leq 0$时输出0。ReLU函数计算速度快，可以加速神经网络的训练过程。
# - LeakyReLU函数：LeakyReLU函数是一种改进的ReLU函数，其数学形式为$f(x)=max(ax,x)$，其中$a$是一个小于1的常数。当$x\leq 0$时，LeakyReLU函数会输出一个非零的值，避免了ReLU函数在$x<0$时出现的“神经元死亡”现象。
# - Tanh函数：Tanh函数是一种常用的非线性激活函数，其数学形式为$f(x)=\frac{e^{x}-e^{-x}}{e^{x}+e^{-x}}$。它的输出范围在-1到1之间，可以用于多分类问题。
# - Softmax函数：Softmax函数是一种常用的激活函数，主要用于多分类问题。其数学形式为$f(x_{i})=\frac{e^{x_{i}}}{\sum_{j=1}^{K}e^{x_{j}}}$，其中$x_{i}$表示第$i$个神经元的输出，$K$表示神经网络的输出层大小。Softmax函数会将所有输出映射到一个概率分布上，保证所有输出的和为1。
#
# #### 损失函数
# - nn.MSELoss：均方误差损失函数，用于回归任务。
# - nn.CrossEntropyLoss：交叉熵损失函数，用于多分类任务。
# - nn.BCELoss：二元交叉熵损失函数，用于二分类任务。
# - nn.NLLLoss：负对数似然损失函数，通常用于文本分类任务。
# - nn.KLDivLoss：KL 散度损失函数，用于计算两个概率分布之间的距离。
# - nn.SmoothL1Loss：平滑 L1 损失函数，与均方误差损失函数类似，但对离群值的惩罚更小，适用于回归任务。

# %%
#将模型添加到GPU
model = NeuralNetwork().to(device)
# 定义损失函数和优化器
# 均方差
criterion = torch.nn.SmoothL1Loss()
# 随机梯度下降
optimizer = torch.optim.SGD(model.parameters(), lr=0.55)
# model.parameters()用于返回模型中所有可训练的参数

# %% [markdown]
# 训练模型

# %%
num_epochs = 200
loss_arr = []
for epoch in range(num_epochs):
        #模型进入训练模式
        model.train()
        #遍历数据
        for batch, (inputs, targets) in enumerate(train_dataloader):
                #将数据添加到GPU
                inputs, targets = inputs.to(device), targets.to(device)
                # 前向传播
                pred = model(inputs)
                # loss计算
                loss = criterion(pred, targets)
                # 梯度清零
                optimizer.zero_grad()
                # 反向传播
                loss.backward()
                # 更新参数的值
                optimizer.step()
                # 输出数据
                print('迭代: [{}/{}], Loss: {:.4f}'.format(epoch+1, num_epochs, loss.item()))
                loss_arr.append(loss.item())
# Out:
# 迭代: [1/200], Loss: 0.1757
# 迭代: [1/200], Loss: 0.2691
# 迭代: [1/200], Loss: 0.2886
# 迭代: [1/200], Loss: 0.2404
# 迭代: [1/200], Loss: 0.2708
# 迭代: [1/200], Loss: 0.2601
# 迭代: [1/200], Loss: 0.2626
# 迭代: [1/200], Loss: 0.3509
# 迭代: [1/200], Loss: 0.3089
# 迭代: [1/200], Loss: 0.1449
# 迭代: [1/200], Loss: 0.1561
# 迭代: [1/200], Loss: 0.3980
# 迭代: [1/200], Loss: 0.2429
# 迭代: [1/200], Loss: 0.3602
# 迭代: [1/200], Loss: 0.2909
# 迭代: [1/200], Loss: 0.2284
# 迭代: [1/200], Loss: 0.1688
# 迭代: [1/200], Loss: 0.2736
# 迭代: [1/200], Loss: 0.2844
# 迭代: [1/200], Loss: 0.2197
# 迭代: [1/200], Loss: 0.2709
# 迭代: [1/200], Loss: 0.1792
# 迭代: [1/200], Loss: 0.1423
# 迭代: [1/200], Loss: 0.2880
# 迭代: [1/200], Loss: 0.1742
# 迭代: [1/200], Loss: 0.2324
# 迭代: [1/200], Loss: 0.2396
# 迭代: [1/200], Loss: 0.2446
# 迭代: [1/200], Loss: 0.2618
# 迭代: [1/200], Loss: 0.2241
# 迭代: [1/200], Loss: 0.1650
# 迭代: [1/200], Loss: 0.1004
# 迭代: [1/200], Loss: 0.3894
# 迭代: [1/200], Loss: 0.1770
# 迭代: [1/200], Loss: 0.3095
# 迭代: [1/200], Loss: 0.1760
# 迭代: [1/200], Loss: 0.3805
# 迭代: [1/200], Loss: 0.2045
# 迭代: [1/200], Loss: 0.2411
# 迭代: [1/200], Loss: 0.2056
# 迭代: [1/200], Loss: 0.2427
# 迭代: [1/200], Loss: 0.2407
# 迭代: [1/200], Loss: 0.3027
# 迭代: [1/200], Loss: 0.1396
# 迭代: [1/200], Loss: 0.2360
# 迭代: [1/200], Loss: 0.3064
# 迭代: [1/200], Loss: 0.3312
# 迭代: [1/200], Loss: 0.1895
# 迭代: [1/200], Loss: 0.1078
# 迭代: [1/200], Loss: 0.2123
# 迭代: [2/200], Loss: 0.2212
# 迭代: [2/200], Loss: 0.3833
# 迭代: [2/200], Loss: 0.2676
# 迭代: [2/200], Loss: 0.3225
# 迭代: [2/200], Loss: 0.3184
# 迭代: [2/200], Loss: 0.1797
# 迭代: [2/200], Loss: 0.2178
# 迭代: [2/200], Loss: 0.1991
# 迭代: [2/200], Loss: 0.2498
# 迭代: [2/200], Loss: 0.1740
# 迭代: [2/200], Loss: 0.2623
# 迭代: [2/200], Loss: 0.2177
# 迭代: [2/200], Loss: 0.2330
# 迭代: [2/200], Loss: 0.0617
# 迭代: [2/200], Loss: 0.2799
# 迭代: [2/200], Loss: 0.0953
# 迭代: [2/200], Loss: 0.2381
# 迭代: [2/200], Loss: 0.1687
# 迭代: [2/200], Loss: 0.1589
# 迭代: [2/200], Loss: 0.2043
# 迭代: [2/200], Loss: 0.1996
# 迭代: [2/200], Loss: 0.2127
# 迭代: [2/200], Loss: 0.2217
# 迭代: [2/200], Loss: 0.0842
# 迭代: [2/200], Loss: 0.2277
# 迭代: [2/200], Loss: 0.1567
# 迭代: [2/200], Loss: 0.1779
# 迭代: [2/200], Loss: 0.1828
# 迭代: [2/200], Loss: 0.1901
# 迭代: [2/200], Loss: 0.2883
# 迭代: [2/200], Loss: 0.1385
# 迭代: [2/200], Loss: 0.2591
# 迭代: [2/200], Loss: 0.1954
# 迭代: [2/200], Loss: 0.1597
# 迭代: [2/200], Loss: 0.2287
# 迭代: [2/200], Loss: 0.1703
# 迭代: [2/200], Loss: 0.1113
# 迭代: [2/200], Loss: 0.1657
# 迭代: [2/200], Loss: 0.1881
# 迭代: [2/200], Loss: 0.2498
# 迭代: [2/200], Loss: 0.2674
# 迭代: [2/200], Loss: 0.1581
# 迭代: [2/200], Loss: 0.1767
# 迭代: [2/200], Loss: 0.1753
# 迭代: [2/200], Loss: 0.1872
# 迭代: [2/200], Loss: 0.2499
# 迭代: [2/200], Loss: 0.0708
# 迭代: [2/200], Loss: 0.1754
# 迭代: [2/200], Loss: 0.1694
# 迭代: [2/200], Loss: 0.1086
# 迭代: [3/200], Loss: 0.0865
# 迭代: [3/200], Loss: 0.1698
# 迭代: [3/200], Loss: 0.1453
# 迭代: [3/200], Loss: 0.2125
# 迭代: [3/200], Loss: 0.1468
# 迭代: [3/200], Loss: 0.2577
# 迭代: [3/200], Loss: 0.1288
# 迭代: [3/200], Loss: 0.1375
# 迭代: [3/200], Loss: 0.2407
# 迭代: [3/200], Loss: 0.1244
# 迭代: [3/200], Loss: 0.1535
# 迭代: [3/200], Loss: 0.2156
# 迭代: [3/200], Loss: 0.3377
# 迭代: [3/200], Loss: 0.2276
# 迭代: [3/200], Loss: 0.1026
# 迭代: [3/200], Loss: 0.1232
# 迭代: [3/200], Loss: 0.2441
# 迭代: [3/200], Loss: 0.1645
# 迭代: [3/200], Loss: 0.0876
# 迭代: [3/200], Loss: 0.1501
# 迭代: [3/200], Loss: 0.0823
# 迭代: [3/200], Loss: 0.1939
# 迭代: [3/200], Loss: 0.1893
# 迭代: [3/200], Loss: 0.0999
# 迭代: [3/200], Loss: 0.1845
# 迭代: [3/200], Loss: 0.0903
# 迭代: [3/200], Loss: 0.1442
# 迭代: [3/200], Loss: 0.1247
# 迭代: [3/200], Loss: 0.1037
# 迭代: [3/200], Loss: 0.0903
# 迭代: [3/200], Loss: 0.1903
# 迭代: [3/200], Loss: 0.0917
# 迭代: [3/200], Loss: 0.1151
# 迭代: [3/200], Loss: 0.1394
# 迭代: [3/200], Loss: 0.1222
# 迭代: [3/200], Loss: 0.1578
# 迭代: [3/200], Loss: 0.1148
# 迭代: [3/200], Loss: 0.1450
# 迭代: [3/200], Loss: 0.0645
# 迭代: [3/200], Loss: 0.1283
# 迭代: [3/200], Loss: 0.1199
# 迭代: [3/200], Loss: 0.1662
# 迭代: [3/200], Loss: 0.0980
# 迭代: [3/200], Loss: 0.1341
# 迭代: [3/200], Loss: 0.0558
# 迭代: [3/200], Loss: 0.1702
# 迭代: [3/200], Loss: 0.1378
# 迭代: [3/200], Loss: 0.1532
# 迭代: [3/200], Loss: 0.1431
# 迭代: [3/200], Loss: 0.1267
# 迭代: [4/200], Loss: 0.0656
# 迭代: [4/200], Loss: 0.1362
# 迭代: [4/200], Loss: 0.1031
# 迭代: [4/200], Loss: 0.1525
# 迭代: [4/200], Loss: 0.1322
# 迭代: [4/200], Loss: 0.1638
# 迭代: [4/200], Loss: 0.0661
# 迭代: [4/200], Loss: 0.1425
# 迭代: [4/200], Loss: 0.0872
# 迭代: [4/200], Loss: 0.1121
# 迭代: [4/200], Loss: 0.0593
# 迭代: [4/200], Loss: 0.1271
# 迭代: [4/200], Loss: 0.0389
# 迭代: [4/200], Loss: 0.1383
# 迭代: [4/200], Loss: 0.1076
# 迭代: [4/200], Loss: 0.1499
# 迭代: [4/200], Loss: 0.1837
# 迭代: [4/200], Loss: 0.1693
# 迭代: [4/200], Loss: 0.1338
# 迭代: [4/200], Loss: 0.1264
# 迭代: [4/200], Loss: 0.1447
# 迭代: [4/200], Loss: 0.2546
# 迭代: [4/200], Loss: 0.1705
# 迭代: [4/200], Loss: 0.0848
# 迭代: [4/200], Loss: 0.0830
# 迭代: [4/200], Loss: 0.1564
# 迭代: [4/200], Loss: 0.1035
# 迭代: [4/200], Loss: 0.0390
# 迭代: [4/200], Loss: 0.1325
# 迭代: [4/200], Loss: 0.0569
# 迭代: [4/200], Loss: 0.1235
# 迭代: [4/200], Loss: 0.0857
# 迭代: [4/200], Loss: 0.0666
# 迭代: [4/200], Loss: 0.0886
# 迭代: [4/200], Loss: 0.2522
# 迭代: [4/200], Loss: 0.1356
# 迭代: [4/200], Loss: 0.0463
# 迭代: [4/200], Loss: 0.0976
# 迭代: [4/200], Loss: 0.0978
# 迭代: [4/200], Loss: 0.0865
# 迭代: [4/200], Loss: 0.1007
# 迭代: [4/200], Loss: 0.1100
# 迭代: [4/200], Loss: 0.1054
# 迭代: [4/200], Loss: 0.1714
# 迭代: [4/200], Loss: 0.2247
# 迭代: [4/200], Loss: 0.0960
# 迭代: [4/200], Loss: 0.0725
# 迭代: [4/200], Loss: 0.0896
# 迭代: [4/200], Loss: 0.1322
# 迭代: [4/200], Loss: 0.1376
# 迭代: [5/200], Loss: 0.1573
# 迭代: [5/200], Loss: 0.0661
# 迭代: [5/200], Loss: 0.1113
# 迭代: [5/200], Loss: 0.1098
# 迭代: [5/200], Loss: 0.0750
# 迭代: [5/200], Loss: 0.0889
# 迭代: [5/200], Loss: 0.0900
# 迭代: [5/200], Loss: 0.0692
# 迭代: [5/200], Loss: 0.1010
# 迭代: [5/200], Loss: 0.0957
# 迭代: [5/200], Loss: 0.0953
# 迭代: [5/200], Loss: 0.0780
# 迭代: [5/200], Loss: 0.0930
# 迭代: [5/200], Loss: 0.1004
# 迭代: [5/200], Loss: 0.0947
# 迭代: [5/200], Loss: 0.1110
# 迭代: [5/200], Loss: 0.1401
# 迭代: [5/200], Loss: 0.1296
# 迭代: [5/200], Loss: 0.1662
# 迭代: [5/200], Loss: 0.1123
# 迭代: [5/200], Loss: 0.0887
# 迭代: [5/200], Loss: 0.1071
# 迭代: [5/200], Loss: 0.1548
# 迭代: [5/200], Loss: 0.1279
# 迭代: [5/200], Loss: 0.1382
# 迭代: [5/200], Loss: 0.0776
# 迭代: [5/200], Loss: 0.1022
# 迭代: [5/200], Loss: 0.1496
# 迭代: [5/200], Loss: 0.1458
# 迭代: [5/200], Loss: 0.2050
# 迭代: [5/200], Loss: 0.2526
# 迭代: [5/200], Loss: 0.2291
# 迭代: [5/200], Loss: 0.1699
# 迭代: [5/200], Loss: 0.0902
# 迭代: [5/200], Loss: 0.1044
# 迭代: [5/200], Loss: 0.1178
# 迭代: [5/200], Loss: 0.1208
# 迭代: [5/200], Loss: 0.1436
# 迭代: [5/200], Loss: 0.1438
# 迭代: [5/200], Loss: 0.1589
# 迭代: [5/200], Loss: 0.0997
# 迭代: [5/200], Loss: 0.0641
# 迭代: [5/200], Loss: 0.1163
# 迭代: [5/200], Loss: 0.1439
# 迭代: [5/200], Loss: 0.1362
# 迭代: [5/200], Loss: 0.0686
# 迭代: [5/200], Loss: 0.0803
# 迭代: [5/200], Loss: 0.0722
# 迭代: [5/200], Loss: 0.1049
# 迭代: [5/200], Loss: 0.0995
# 迭代: [6/200], Loss: 0.1045
# 迭代: [6/200], Loss: 0.0857
# 迭代: [6/200], Loss: 0.0515
# 迭代: [6/200], Loss: 0.1159
# 迭代: [6/200], Loss: 0.1170
# 迭代: [6/200], Loss: 0.1009
# 迭代: [6/200], Loss: 0.0726
# 迭代: [6/200], Loss: 0.0751
# 迭代: [6/200], Loss: 0.1040
# 迭代: [6/200], Loss: 0.0684
# 迭代: [6/200], Loss: 0.1026
# 迭代: [6/200], Loss: 0.0818
# 迭代: [6/200], Loss: 0.1462
# 迭代: [6/200], Loss: 0.1666
# 迭代: [6/200], Loss: 0.2346
# 迭代: [6/200], Loss: 0.0901
# 迭代: [6/200], Loss: 0.0756
# 迭代: [6/200], Loss: 0.0545
# 迭代: [6/200], Loss: 0.1310
# 迭代: [6/200], Loss: 0.0690
# 迭代: [6/200], Loss: 0.1286
# 迭代: [6/200], Loss: 0.1232
# 迭代: [6/200], Loss: 0.1422
# 迭代: [6/200], Loss: 0.0918
# 迭代: [6/200], Loss: 0.1419
# 迭代: [6/200], Loss: 0.1022
# 迭代: [6/200], Loss: 0.0716
# 迭代: [6/200], Loss: 0.1130
# 迭代: [6/200], Loss: 0.0841
# 迭代: [6/200], Loss: 0.1163
# 迭代: [6/200], Loss: 0.0973
# 迭代: [6/200], Loss: 0.1360
# 迭代: [6/200], Loss: 0.0930
# 迭代: [6/200], Loss: 0.0699
# 迭代: [6/200], Loss: 0.0847
# 迭代: [6/200], Loss: 0.1217
# 迭代: [6/200], Loss: 0.1259
# 迭代: [6/200], Loss: 0.1214
# 迭代: [6/200], Loss: 0.1014
# 迭代: [6/200], Loss: 0.1452
# 迭代: [6/200], Loss: 0.1896
# 迭代: [6/200], Loss: 0.1706
# 迭代: [6/200], Loss: 0.0790
# 迭代: [6/200], Loss: 0.1317
# 迭代: [6/200], Loss: 0.0994
# 迭代: [6/200], Loss: 0.1185
# 迭代: [6/200], Loss: 0.1868
# 迭代: [6/200], Loss: 0.1430
# 迭代: [6/200], Loss: 0.0647
# 迭代: [6/200], Loss: 0.0989
# 迭代: [7/200], Loss: 0.0825
# 迭代: [7/200], Loss: 0.1540
# 迭代: [7/200], Loss: 0.0870
# 迭代: [7/200], Loss: 0.1247
# 迭代: [7/200], Loss: 0.1217
# 迭代: [7/200], Loss: 0.0912
# 迭代: [7/200], Loss: 0.1131
# 迭代: [7/200], Loss: 0.0458
# 迭代: [7/200], Loss: 0.1436
# 迭代: [7/200], Loss: 0.0787
# 迭代: [7/200], Loss: 0.0838
# 迭代: [7/200], Loss: 0.1039
# 迭代: [7/200], Loss: 0.0757
# 迭代: [7/200], Loss: 0.1207
# 迭代: [7/200], Loss: 0.0945
# 迭代: [7/200], Loss: 0.0616
# 迭代: [7/200], Loss: 0.0698
# 迭代: [7/200], Loss: 0.0997
# 迭代: [7/200], Loss: 0.0854
# 迭代: [7/200], Loss: 0.0873
# 迭代: [7/200], Loss: 0.0862
# 迭代: [7/200], Loss: 0.0965
# 迭代: [7/200], Loss: 0.1172
# 迭代: [7/200], Loss: 0.1227
# 迭代: [7/200], Loss: 0.1455
# 迭代: [7/200], Loss: 0.0624
# 迭代: [7/200], Loss: 0.1091
# 迭代: [7/200], Loss: 0.1156
# 迭代: [7/200], Loss: 0.1029
# 迭代: [7/200], Loss: 0.1075
# 迭代: [7/200], Loss: 0.0845
# 迭代: [7/200], Loss: 0.0993
# 迭代: [7/200], Loss: 0.0801
# 迭代: [7/200], Loss: 0.0910
# 迭代: [7/200], Loss: 0.1558
# 迭代: [7/200], Loss: 0.3038
# 迭代: [7/200], Loss: 0.1550
# 迭代: [7/200], Loss: 0.1356
# 迭代: [7/200], Loss: 0.1096
# 迭代: [7/200], Loss: 0.1029
# 迭代: [7/200], Loss: 0.1144
# 迭代: [7/200], Loss: 0.1458
# 迭代: [7/200], Loss: 0.1166
# 迭代: [7/200], Loss: 0.0873
# 迭代: [7/200], Loss: 0.1293
# 迭代: [7/200], Loss: 0.1092
# 迭代: [7/200], Loss: 0.0956
# 迭代: [7/200], Loss: 0.1074
# 迭代: [7/200], Loss: 0.1713
# 迭代: [7/200], Loss: 0.1448
# 迭代: [8/200], Loss: 0.3708
# 迭代: [8/200], Loss: 0.1725
# 迭代: [8/200], Loss: 0.1670
# 迭代: [8/200], Loss: 0.0509
# 迭代: [8/200], Loss: 0.1457
# 迭代: [8/200], Loss: 0.1276
# 迭代: [8/200], Loss: 0.0824
# 迭代: [8/200], Loss: 0.1045
# 迭代: [8/200], Loss: 0.0931
# 迭代: [8/200], Loss: 0.0429
# 迭代: [8/200], Loss: 0.1109
# 迭代: [8/200], Loss: 0.0692
# 迭代: [8/200], Loss: 0.0621
# 迭代: [8/200], Loss: 0.2073
# 迭代: [8/200], Loss: 0.2294
# 迭代: [8/200], Loss: 0.1989
# 迭代: [8/200], Loss: 0.1317
# 迭代: [8/200], Loss: 0.1077
# 迭代: [8/200], Loss: 0.1258
# 迭代: [8/200], Loss: 0.0781
# 迭代: [8/200], Loss: 0.1288
# 迭代: [8/200], Loss: 0.0968
# 迭代: [8/200], Loss: 0.1940
# 迭代: [8/200], Loss: 0.2010
# 迭代: [8/200], Loss: 0.1431
# 迭代: [8/200], Loss: 0.2095
# 迭代: [8/200], Loss: 0.0334
# 迭代: [8/200], Loss: 0.1471
# 迭代: [8/200], Loss: 0.1032
# 迭代: [8/200], Loss: 0.1518
# 迭代: [8/200], Loss: 0.1935
# 迭代: [8/200], Loss: 0.1485
# 迭代: [8/200], Loss: 0.1021
# 迭代: [8/200], Loss: 0.1186
# 迭代: [8/200], Loss: 0.0889
# 迭代: [8/200], Loss: 0.0595
# 迭代: [8/200], Loss: 0.1501
# 迭代: [8/200], Loss: 0.1195
# 迭代: [8/200], Loss: 0.1106
# 迭代: [8/200], Loss: 0.1435
# 迭代: [8/200], Loss: 0.0963
# 迭代: [8/200], Loss: 0.1331
# 迭代: [8/200], Loss: 0.1455
# 迭代: [8/200], Loss: 0.0831
# 迭代: [8/200], Loss: 0.0942
# 迭代: [8/200], Loss: 0.0705
# 迭代: [8/200], Loss: 0.0728
# 迭代: [8/200], Loss: 0.0771
# 迭代: [8/200], Loss: 0.1559
# 迭代: [8/200], Loss: 0.1223
# 迭代: [9/200], Loss: 0.1527
# 迭代: [9/200], Loss: 0.0839
# 迭代: [9/200], Loss: 0.1092
# 迭代: [9/200], Loss: 0.0706
# 迭代: [9/200], Loss: 0.0633
# 迭代: [9/200], Loss: 0.0632
# 迭代: [9/200], Loss: 0.1135
# 迭代: [9/200], Loss: 0.0846
# 迭代: [9/200], Loss: 0.0974
# 迭代: [9/200], Loss: 0.0758
# 迭代: [9/200], Loss: 0.1438
# 迭代: [9/200], Loss: 0.0710
# 迭代: [9/200], Loss: 0.0499
# 迭代: [9/200], Loss: 0.0649
# 迭代: [9/200], Loss: 0.0943
# 迭代: [9/200], Loss: 0.0654
# 迭代: [9/200], Loss: 0.0845
# 迭代: [9/200], Loss: 0.0921
# 迭代: [9/200], Loss: 0.0476
# 迭代: [9/200], Loss: 0.1696
# 迭代: [9/200], Loss: 0.2858
# 迭代: [9/200], Loss: 0.0994
# 迭代: [9/200], Loss: 0.1034
# 迭代: [9/200], Loss: 0.2586
# 迭代: [9/200], Loss: 0.0805
# 迭代: [9/200], Loss: 0.0860
# 迭代: [9/200], Loss: 0.1203
# 迭代: [9/200], Loss: 0.0668
# 迭代: [9/200], Loss: 0.0680
# 迭代: [9/200], Loss: 0.0862
# 迭代: [9/200], Loss: 0.1304
# 迭代: [9/200], Loss: 0.0970
# 迭代: [9/200], Loss: 0.1326
# 迭代: [9/200], Loss: 0.0880
# 迭代: [9/200], Loss: 0.0747
# 迭代: [9/200], Loss: 0.1181
# 迭代: [9/200], Loss: 0.0761
# 迭代: [9/200], Loss: 0.0985
# 迭代: [9/200], Loss: 0.3310
# 迭代: [9/200], Loss: 0.1146
# 迭代: [9/200], Loss: 0.1017
# 迭代: [9/200], Loss: 0.1514
# 迭代: [9/200], Loss: 0.1778
# 迭代: [9/200], Loss: 0.0980
# 迭代: [9/200], Loss: 0.0832
# 迭代: [9/200], Loss: 0.1109
# 迭代: [9/200], Loss: 0.0709
# 迭代: [9/200], Loss: 0.0780
# 迭代: [9/200], Loss: 0.1299
# 迭代: [9/200], Loss: 0.1225
# 迭代: [10/200], Loss: 0.1008
# 迭代: [10/200], Loss: 0.1357
# 迭代: [10/200], Loss: 0.1034
# 迭代: [10/200], Loss: 0.2398
# 迭代: [10/200], Loss: 0.1357
# 迭代: [10/200], Loss: 0.0957
# 迭代: [10/200], Loss: 0.0844
# 迭代: [10/200], Loss: 0.0586
# 迭代: [10/200], Loss: 0.1437
# 迭代: [10/200], Loss: 0.1234
# 迭代: [10/200], Loss: 0.1595
# 迭代: [10/200], Loss: 0.0885
# 迭代: [10/200], Loss: 0.1345
# 迭代: [10/200], Loss: 0.0725
# 迭代: [10/200], Loss: 0.0773
# 迭代: [10/200], Loss: 0.0501
# 迭代: [10/200], Loss: 0.0765
# 迭代: [10/200], Loss: 0.1669
# 迭代: [10/200], Loss: 0.1475
# 迭代: [10/200], Loss: 0.0996
# 迭代: [10/200], Loss: 0.0942
# 迭代: [10/200], Loss: 0.0594
# 迭代: [10/200], Loss: 0.1109
# 迭代: [10/200], Loss: 0.0814
# 迭代: [10/200], Loss: 0.0612
# 迭代: [10/200], Loss: 0.1034
# 迭代: [10/200], Loss: 0.0928
# 迭代: [10/200], Loss: 0.0734
# 迭代: [10/200], Loss: 0.1085
# 迭代: [10/200], Loss: 0.1004
# 迭代: [10/200], Loss: 0.0845
# 迭代: [10/200], Loss: 0.1586
# 迭代: [10/200], Loss: 0.1060
# 迭代: [10/200], Loss: 0.0849
# 迭代: [10/200], Loss: 0.1000
# 迭代: [10/200], Loss: 0.1459
# 迭代: [10/200], Loss: 0.0542
# 迭代: [10/200], Loss: 0.0839
# 迭代: [10/200], Loss: 0.1003
# 迭代: [10/200], Loss: 0.0739
# 迭代: [10/200], Loss: 0.0937
# 迭代: [10/200], Loss: 0.1084
# 迭代: [10/200], Loss: 0.1096
# 迭代: [10/200], Loss: 0.1056
# 迭代: [10/200], Loss: 0.0691
# 迭代: [10/200], Loss: 0.0998
# 迭代: [10/200], Loss: 0.0931
# 迭代: [10/200], Loss: 0.1082
# 迭代: [10/200], Loss: 0.0677
# 迭代: [10/200], Loss: 0.0809
# 迭代: [11/200], Loss: 0.1609
# 迭代: [11/200], Loss: 0.1278
# 迭代: [11/200], Loss: 0.0707
# 迭代: [11/200], Loss: 0.1404
# 迭代: [11/200], Loss: 0.0859
# 迭代: [11/200], Loss: 0.0926
# 迭代: [11/200], Loss: 0.1119
# 迭代: [11/200], Loss: 0.0729
# 迭代: [11/200], Loss: 0.0544
# 迭代: [11/200], Loss: 0.1319
# 迭代: [11/200], Loss: 0.0922
# 迭代: [11/200], Loss: 0.0744
# 迭代: [11/200], Loss: 0.1554
# 迭代: [11/200], Loss: 0.0992
# 迭代: [11/200], Loss: 0.0917
# 迭代: [11/200], Loss: 0.1017
# 迭代: [11/200], Loss: 0.1084
# 迭代: [11/200], Loss: 0.1272
# 迭代: [11/200], Loss: 0.0922
# 迭代: [11/200], Loss: 0.0481
# 迭代: [11/200], Loss: 0.1078
# 迭代: [11/200], Loss: 0.1962
# 迭代: [11/200], Loss: 0.0529
# 迭代: [11/200], Loss: 0.0876
# 迭代: [11/200], Loss: 0.0848
# 迭代: [11/200], Loss: 0.0614
# 迭代: [11/200], Loss: 0.1216
# 迭代: [11/200], Loss: 0.0828
# 迭代: [11/200], Loss: 0.1222
# 迭代: [11/200], Loss: 0.0772
# 迭代: [11/200], Loss: 0.0818
# 迭代: [11/200], Loss: 0.0551
# 迭代: [11/200], Loss: 0.1451
# 迭代: [11/200], Loss: 0.1015
# 迭代: [11/200], Loss: 0.0819
# 迭代: [11/200], Loss: 0.1039
# 迭代: [11/200], Loss: 0.1151
# 迭代: [11/200], Loss: 0.1131
# 迭代: [11/200], Loss: 0.1487
# 迭代: [11/200], Loss: 0.0823
# 迭代: [11/200], Loss: 0.1023
# 迭代: [11/200], Loss: 0.0753
# 迭代: [11/200], Loss: 0.0943
# 迭代: [11/200], Loss: 0.0612
# 迭代: [11/200], Loss: 0.1158
# 迭代: [11/200], Loss: 0.1086
# 迭代: [11/200], Loss: 0.1586
# 迭代: [11/200], Loss: 0.1009
# 迭代: [11/200], Loss: 0.0985
# 迭代: [11/200], Loss: 0.0991
# 迭代: [12/200], Loss: 0.0544
# 迭代: [12/200], Loss: 0.0591
# 迭代: [12/200], Loss: 0.0814
# 迭代: [12/200], Loss: 0.1265
# 迭代: [12/200], Loss: 0.1409
# 迭代: [12/200], Loss: 0.1339
# 迭代: [12/200], Loss: 0.0814
# 迭代: [12/200], Loss: 0.1087
# 迭代: [12/200], Loss: 0.2261
# 迭代: [12/200], Loss: 0.2629
# 迭代: [12/200], Loss: 0.1286
# 迭代: [12/200], Loss: 0.0998
# 迭代: [12/200], Loss: 0.1140
# 迭代: [12/200], Loss: 0.1124
# 迭代: [12/200], Loss: 0.0769
# 迭代: [12/200], Loss: 0.1737
# 迭代: [12/200], Loss: 0.0884
# 迭代: [12/200], Loss: 0.1003
# 迭代: [12/200], Loss: 0.1629
# 迭代: [12/200], Loss: 0.0532
# 迭代: [12/200], Loss: 0.0742
# 迭代: [12/200], Loss: 0.0647
# 迭代: [12/200], Loss: 0.1544
# 迭代: [12/200], Loss: 0.1159
# 迭代: [12/200], Loss: 0.0499
# 迭代: [12/200], Loss: 0.1217
# 迭代: [12/200], Loss: 0.0754
# 迭代: [12/200], Loss: 0.0664
# 迭代: [12/200], Loss: 0.1266
# 迭代: [12/200], Loss: 0.0686
# 迭代: [12/200], Loss: 0.1280
# 迭代: [12/200], Loss: 0.1474
# 迭代: [12/200], Loss: 0.1885
# 迭代: [12/200], Loss: 0.1813
# 迭代: [12/200], Loss: 0.1128
# 迭代: [12/200], Loss: 0.1013
# 迭代: [12/200], Loss: 0.1141
# 迭代: [12/200], Loss: 0.1029
# 迭代: [12/200], Loss: 0.0231
# 迭代: [12/200], Loss: 0.1504
# 迭代: [12/200], Loss: 0.0754
# 迭代: [12/200], Loss: 0.1331
# 迭代: [12/200], Loss: 0.1104
# 迭代: [12/200], Loss: 0.1055
# 迭代: [12/200], Loss: 0.1230
# 迭代: [12/200], Loss: 0.1812
# 迭代: [12/200], Loss: 0.1857
# 迭代: [12/200], Loss: 0.1084
# 迭代: [12/200], Loss: 0.0738
# 迭代: [12/200], Loss: 0.0786
# 迭代: [13/200], Loss: 0.0613
# 迭代: [13/200], Loss: 0.1521
# 迭代: [13/200], Loss: 0.0729
# 迭代: [13/200], Loss: 0.0878
# 迭代: [13/200], Loss: 0.1087
# 迭代: [13/200], Loss: 0.0986
# 迭代: [13/200], Loss: 0.1111
# 迭代: [13/200], Loss: 0.1590
# 迭代: [13/200], Loss: 0.1020
# 迭代: [13/200], Loss: 0.0957
# 迭代: [13/200], Loss: 0.1182
# 迭代: [13/200], Loss: 0.1082
# 迭代: [13/200], Loss: 0.1105
# 迭代: [13/200], Loss: 0.1302
# 迭代: [13/200], Loss: 0.1236
# 迭代: [13/200], Loss: 0.0700
# 迭代: [13/200], Loss: 0.1282
# 迭代: [13/200], Loss: 0.0702
# 迭代: [13/200], Loss: 0.1040
# 迭代: [13/200], Loss: 0.1516
# 迭代: [13/200], Loss: 0.0805
# 迭代: [13/200], Loss: 0.0496
# 迭代: [13/200], Loss: 0.0801
# 迭代: [13/200], Loss: 0.1147
# 迭代: [13/200], Loss: 0.1339
# 迭代: [13/200], Loss: 0.0941
# 迭代: [13/200], Loss: 0.1053
# 迭代: [13/200], Loss: 0.1090
# 迭代: [13/200], Loss: 0.0845
# 迭代: [13/200], Loss: 0.1541
# 迭代: [13/200], Loss: 0.0591
# 迭代: [13/200], Loss: 0.0995
# 迭代: [13/200], Loss: 0.0813
# 迭代: [13/200], Loss: 0.0813
# 迭代: [13/200], Loss: 0.0779
# 迭代: [13/200], Loss: 0.1182
# 迭代: [13/200], Loss: 0.1344
# 迭代: [13/200], Loss: 0.0727
# 迭代: [13/200], Loss: 0.0785
# 迭代: [13/200], Loss: 0.1522
# 迭代: [13/200], Loss: 0.0815
# 迭代: [13/200], Loss: 0.1317
# 迭代: [13/200], Loss: 0.0883
# 迭代: [13/200], Loss: 0.0849
# 迭代: [13/200], Loss: 0.0705
# 迭代: [13/200], Loss: 0.0748
# 迭代: [13/200], Loss: 0.1003
# 迭代: [13/200], Loss: 0.0627
# 迭代: [13/200], Loss: 0.0598
# 迭代: [13/200], Loss: 0.0686
# 迭代: [14/200], Loss: 0.1262
# 迭代: [14/200], Loss: 0.0451
# 迭代: [14/200], Loss: 0.1380
# 迭代: [14/200], Loss: 0.0757
# 迭代: [14/200], Loss: 0.0874
# 迭代: [14/200], Loss: 0.1008
# 迭代: [14/200], Loss: 0.1122
# 迭代: [14/200], Loss: 0.0916
# 迭代: [14/200], Loss: 0.0476
# 迭代: [14/200], Loss: 0.1081
# 迭代: [14/200], Loss: 0.1514
# 迭代: [14/200], Loss: 0.1254
# 迭代: [14/200], Loss: 0.0825
# 迭代: [14/200], Loss: 0.0803
# 迭代: [14/200], Loss: 0.0522
# 迭代: [14/200], Loss: 0.1246
# 迭代: [14/200], Loss: 0.0848
# 迭代: [14/200], Loss: 0.0849
# 迭代: [14/200], Loss: 0.0697
# 迭代: [14/200], Loss: 0.1123
# 迭代: [14/200], Loss: 0.1359
# 迭代: [14/200], Loss: 0.1553
# 迭代: [14/200], Loss: 0.1309
# 迭代: [14/200], Loss: 0.1067
# 迭代: [14/200], Loss: 0.0953
# 迭代: [14/200], Loss: 0.0622
# 迭代: [14/200], Loss: 0.1226
# 迭代: [14/200], Loss: 0.0997
# 迭代: [14/200], Loss: 0.0610
# 迭代: [14/200], Loss: 0.0982
# 迭代: [14/200], Loss: 0.0518
# 迭代: [14/200], Loss: 0.0960
# 迭代: [14/200], Loss: 0.1441
# 迭代: [14/200], Loss: 0.1163
# 迭代: [14/200], Loss: 0.1237
# 迭代: [14/200], Loss: 0.1745
# 迭代: [14/200], Loss: 0.1298
# 迭代: [14/200], Loss: 0.0815
# 迭代: [14/200], Loss: 0.0859
# 迭代: [14/200], Loss: 0.1701
# 迭代: [14/200], Loss: 0.1715
# 迭代: [14/200], Loss: 0.0836
# 迭代: [14/200], Loss: 0.1049
# 迭代: [14/200], Loss: 0.0433
# 迭代: [14/200], Loss: 0.1198
# 迭代: [14/200], Loss: 0.0616
# 迭代: [14/200], Loss: 0.1230
# 迭代: [14/200], Loss: 0.1303
# 迭代: [14/200], Loss: 0.1182
# 迭代: [14/200], Loss: 0.1476
# 迭代: [15/200], Loss: 0.1710
# 迭代: [15/200], Loss: 0.0755
# 迭代: [15/200], Loss: 0.0597
# 迭代: [15/200], Loss: 0.0824
# 迭代: [15/200], Loss: 0.0833
# 迭代: [15/200], Loss: 0.0743
# 迭代: [15/200], Loss: 0.0659
# 迭代: [15/200], Loss: 0.0659
# 迭代: [15/200], Loss: 0.1340
# 迭代: [15/200], Loss: 0.1449
# 迭代: [15/200], Loss: 0.0932
# 迭代: [15/200], Loss: 0.0633
# 迭代: [15/200], Loss: 0.0922
# 迭代: [15/200], Loss: 0.0865
# 迭代: [15/200], Loss: 0.1115
# 迭代: [15/200], Loss: 0.0792
# 迭代: [15/200], Loss: 0.0900
# 迭代: [15/200], Loss: 0.0876
# 迭代: [15/200], Loss: 0.0852
# 迭代: [15/200], Loss: 0.0882
# 迭代: [15/200], Loss: 0.1146
# 迭代: [15/200], Loss: 0.1000
# 迭代: [15/200], Loss: 0.1047
# 迭代: [15/200], Loss: 0.0812
# 迭代: [15/200], Loss: 0.0738
# 迭代: [15/200], Loss: 0.1577
# 迭代: [15/200], Loss: 0.1727
# 迭代: [15/200], Loss: 0.0375
# 迭代: [15/200], Loss: 0.1519
# 迭代: [15/200], Loss: 0.0712
# 迭代: [15/200], Loss: 0.1293
# 迭代: [15/200], Loss: 0.0743
# 迭代: [15/200], Loss: 0.0904
# 迭代: [15/200], Loss: 0.0933
# 迭代: [15/200], Loss: 0.0969
# 迭代: [15/200], Loss: 0.0511
# 迭代: [15/200], Loss: 0.0907
# 迭代: [15/200], Loss: 0.0804
# 迭代: [15/200], Loss: 0.1309
# 迭代: [15/200], Loss: 0.1286
# 迭代: [15/200], Loss: 0.0755
# 迭代: [15/200], Loss: 0.1187
# 迭代: [15/200], Loss: 0.1292
# 迭代: [15/200], Loss: 0.1370
# 迭代: [15/200], Loss: 0.1122
# 迭代: [15/200], Loss: 0.0776
# 迭代: [15/200], Loss: 0.1380
# 迭代: [15/200], Loss: 0.0450
# 迭代: [15/200], Loss: 0.0460
# 迭代: [15/200], Loss: 0.0914
# 迭代: [16/200], Loss: 0.1513
# 迭代: [16/200], Loss: 0.0629
# 迭代: [16/200], Loss: 0.0856
# 迭代: [16/200], Loss: 0.1431
# 迭代: [16/200], Loss: 0.1319
# 迭代: [16/200], Loss: 0.0563
# 迭代: [16/200], Loss: 0.0602
# 迭代: [16/200], Loss: 0.1771
# 迭代: [16/200], Loss: 0.2336
# 迭代: [16/200], Loss: 0.1266
# 迭代: [16/200], Loss: 0.0775
# 迭代: [16/200], Loss: 0.0971
# 迭代: [16/200], Loss: 0.0934
# 迭代: [16/200], Loss: 0.1045
# 迭代: [16/200], Loss: 0.1453
# 迭代: [16/200], Loss: 0.1678
# 迭代: [16/200], Loss: 0.0992
# 迭代: [16/200], Loss: 0.0690
# 迭代: [16/200], Loss: 0.0919
# 迭代: [16/200], Loss: 0.0857
# 迭代: [16/200], Loss: 0.1213
# 迭代: [16/200], Loss: 0.1297
# 迭代: [16/200], Loss: 0.0939
# 迭代: [16/200], Loss: 0.1249
# 迭代: [16/200], Loss: 0.0872
# 迭代: [16/200], Loss: 0.1053
# 迭代: [16/200], Loss: 0.0886
# 迭代: [16/200], Loss: 0.1015
# 迭代: [16/200], Loss: 0.1037
# 迭代: [16/200], Loss: 0.0611
# 迭代: [16/200], Loss: 0.0993
# 迭代: [16/200], Loss: 0.0535
# 迭代: [16/200], Loss: 0.1011
# 迭代: [16/200], Loss: 0.0740
# 迭代: [16/200], Loss: 0.1121
# 迭代: [16/200], Loss: 0.1365
# 迭代: [16/200], Loss: 0.0699
# 迭代: [16/200], Loss: 0.1047
# 迭代: [16/200], Loss: 0.0899
# 迭代: [16/200], Loss: 0.0747
# 迭代: [16/200], Loss: 0.0749
# 迭代: [16/200], Loss: 0.1234
# 迭代: [16/200], Loss: 0.1017
# 迭代: [16/200], Loss: 0.0839
# 迭代: [16/200], Loss: 0.0737
# 迭代: [16/200], Loss: 0.0873
# 迭代: [16/200], Loss: 0.0744
# 迭代: [16/200], Loss: 0.0723
# 迭代: [16/200], Loss: 0.0927
# 迭代: [16/200], Loss: 0.0768
# 迭代: [17/200], Loss: 0.0820
# 迭代: [17/200], Loss: 0.0972
# 迭代: [17/200], Loss: 0.0986
# 迭代: [17/200], Loss: 0.0703
# 迭代: [17/200], Loss: 0.1234
# 迭代: [17/200], Loss: 0.1044
# 迭代: [17/200], Loss: 0.0742
# 迭代: [17/200], Loss: 0.1185
# 迭代: [17/200], Loss: 0.1333
# 迭代: [17/200], Loss: 0.0781
# 迭代: [17/200], Loss: 0.0838
# 迭代: [17/200], Loss: 0.1178
# 迭代: [17/200], Loss: 0.1605
# 迭代: [17/200], Loss: 0.0604
# 迭代: [17/200], Loss: 0.0539
# 迭代: [17/200], Loss: 0.0838
# 迭代: [17/200], Loss: 0.1165
# 迭代: [17/200], Loss: 0.0563
# 迭代: [17/200], Loss: 0.0660
# 迭代: [17/200], Loss: 0.1111
# 迭代: [17/200], Loss: 0.1378
# 迭代: [17/200], Loss: 0.0640
# 迭代: [17/200], Loss: 0.0764
# 迭代: [17/200], Loss: 0.0880
# 迭代: [17/200], Loss: 0.0915
# 迭代: [17/200], Loss: 0.0895
# 迭代: [17/200], Loss: 0.1036
# 迭代: [17/200], Loss: 0.0761
# 迭代: [17/200], Loss: 0.0600
# 迭代: [17/200], Loss: 0.1540
# 迭代: [17/200], Loss: 0.0745
# 迭代: [17/200], Loss: 0.0994
# 迭代: [17/200], Loss: 0.0740
# 迭代: [17/200], Loss: 0.0813
# 迭代: [17/200], Loss: 0.1241
# 迭代: [17/200], Loss: 0.1301
# 迭代: [17/200], Loss: 0.1288
# 迭代: [17/200], Loss: 0.1160
# 迭代: [17/200], Loss: 0.0994
# 迭代: [17/200], Loss: 0.0939
# 迭代: [17/200], Loss: 0.0816
# 迭代: [17/200], Loss: 0.0997
# 迭代: [17/200], Loss: 0.0938
# 迭代: [17/200], Loss: 0.1039
# 迭代: [17/200], Loss: 0.0733
# 迭代: [17/200], Loss: 0.1298
# 迭代: [17/200], Loss: 0.0826
# 迭代: [17/200], Loss: 0.1097
# 迭代: [17/200], Loss: 0.0536
# 迭代: [17/200], Loss: 0.0980
# 迭代: [18/200], Loss: 0.1110
# 迭代: [18/200], Loss: 0.0891
# 迭代: [18/200], Loss: 0.1203
# 迭代: [18/200], Loss: 0.0740
# 迭代: [18/200], Loss: 0.1136
# 迭代: [18/200], Loss: 0.1328
# 迭代: [18/200], Loss: 0.0765
# 迭代: [18/200], Loss: 0.2188
# 迭代: [18/200], Loss: 0.0829
# 迭代: [18/200], Loss: 0.0745
# 迭代: [18/200], Loss: 0.0732
# 迭代: [18/200], Loss: 0.1779
# 迭代: [18/200], Loss: 0.0572
# 迭代: [18/200], Loss: 0.0641
# 迭代: [18/200], Loss: 0.1322
# 迭代: [18/200], Loss: 0.1117
# 迭代: [18/200], Loss: 0.1168
# 迭代: [18/200], Loss: 0.1073
# 迭代: [18/200], Loss: 0.0848
# 迭代: [18/200], Loss: 0.0605
# 迭代: [18/200], Loss: 0.0817
# 迭代: [18/200], Loss: 0.0648
# 迭代: [18/200], Loss: 0.0646
# 迭代: [18/200], Loss: 0.0898
# 迭代: [18/200], Loss: 0.0925
# 迭代: [18/200], Loss: 0.1249
# 迭代: [18/200], Loss: 0.0962
# 迭代: [18/200], Loss: 0.1511
# 迭代: [18/200], Loss: 0.0990
# 迭代: [18/200], Loss: 0.1009
# 迭代: [18/200], Loss: 0.0972
# 迭代: [18/200], Loss: 0.0435
# 迭代: [18/200], Loss: 0.0807
# 迭代: [18/200], Loss: 0.0934
# 迭代: [18/200], Loss: 0.1297
# 迭代: [18/200], Loss: 0.1258
# 迭代: [18/200], Loss: 0.1659
# 迭代: [18/200], Loss: 0.0924
# 迭代: [18/200], Loss: 0.0404
# 迭代: [18/200], Loss: 0.1013
# 迭代: [18/200], Loss: 0.0424
# 迭代: [18/200], Loss: 0.1147
# 迭代: [18/200], Loss: 0.0407
# 迭代: [18/200], Loss: 0.0687
# 迭代: [18/200], Loss: 0.1815
# 迭代: [18/200], Loss: 0.1038
# 迭代: [18/200], Loss: 0.0792
# 迭代: [18/200], Loss: 0.0793
# 迭代: [18/200], Loss: 0.0764
# 迭代: [18/200], Loss: 0.0622
# 迭代: [19/200], Loss: 0.1699
# 迭代: [19/200], Loss: 0.1183
# 迭代: [19/200], Loss: 0.1230
# 迭代: [19/200], Loss: 0.1252
# 迭代: [19/200], Loss: 0.1083
# 迭代: [19/200], Loss: 0.1217
# 迭代: [19/200], Loss: 0.0614
# 迭代: [19/200], Loss: 0.0925
# 迭代: [19/200], Loss: 0.0482
# 迭代: [19/200], Loss: 0.0568
# 迭代: [19/200], Loss: 0.0905
# 迭代: [19/200], Loss: 0.0598
# 迭代: [19/200], Loss: 0.0604
# 迭代: [19/200], Loss: 0.0558
# 迭代: [19/200], Loss: 0.1420
# 迭代: [19/200], Loss: 0.1070
# 迭代: [19/200], Loss: 0.0916
# 迭代: [19/200], Loss: 0.0916
# 迭代: [19/200], Loss: 0.1246
# 迭代: [19/200], Loss: 0.0457
# 迭代: [19/200], Loss: 0.1241
# 迭代: [19/200], Loss: 0.1206
# 迭代: [19/200], Loss: 0.0758
# 迭代: [19/200], Loss: 0.0972
# 迭代: [19/200], Loss: 0.1036
# 迭代: [19/200], Loss: 0.0738
# 迭代: [19/200], Loss: 0.1078
# 迭代: [19/200], Loss: 0.0966
# 迭代: [19/200], Loss: 0.0594
# 迭代: [19/200], Loss: 0.0929
# 迭代: [19/200], Loss: 0.0392
# 迭代: [19/200], Loss: 0.1691
# 迭代: [19/200], Loss: 0.0859
# 迭代: [19/200], Loss: 0.0639
# 迭代: [19/200], Loss: 0.0839
# 迭代: [19/200], Loss: 0.1089
# 迭代: [19/200], Loss: 0.1124
# 迭代: [19/200], Loss: 0.0790
# 迭代: [19/200], Loss: 0.1399
# 迭代: [19/200], Loss: 0.1022
# 迭代: [19/200], Loss: 0.1279
# 迭代: [19/200], Loss: 0.1021
# 迭代: [19/200], Loss: 0.1353
# 迭代: [19/200], Loss: 0.1076
# 迭代: [19/200], Loss: 0.1140
# 迭代: [19/200], Loss: 0.0888
# 迭代: [19/200], Loss: 0.1082
# 迭代: [19/200], Loss: 0.1558
# 迭代: [19/200], Loss: 0.0775
# 迭代: [19/200], Loss: 0.1365
# 迭代: [20/200], Loss: 0.1008
# 迭代: [20/200], Loss: 0.1055
# 迭代: [20/200], Loss: 0.1053
# 迭代: [20/200], Loss: 0.0596
# 迭代: [20/200], Loss: 0.1262
# 迭代: [20/200], Loss: 0.0530
# 迭代: [20/200], Loss: 0.1705
# 迭代: [20/200], Loss: 0.0711
# 迭代: [20/200], Loss: 0.0614
# 迭代: [20/200], Loss: 0.0699
# 迭代: [20/200], Loss: 0.0745
# 迭代: [20/200], Loss: 0.0589
# 迭代: [20/200], Loss: 0.1532
# 迭代: [20/200], Loss: 0.1036
# 迭代: [20/200], Loss: 0.0947
# 迭代: [20/200], Loss: 0.0848
# 迭代: [20/200], Loss: 0.0693
# 迭代: [20/200], Loss: 0.0655
# 迭代: [20/200], Loss: 0.1215
# 迭代: [20/200], Loss: 0.0529
# 迭代: [20/200], Loss: 0.1035
# 迭代: [20/200], Loss: 0.0537
# 迭代: [20/200], Loss: 0.1233
# 迭代: [20/200], Loss: 0.0934
# 迭代: [20/200], Loss: 0.1435
# 迭代: [20/200], Loss: 0.0918
# 迭代: [20/200], Loss: 0.0956
# 迭代: [20/200], Loss: 0.0983
# 迭代: [20/200], Loss: 0.0936
# 迭代: [20/200], Loss: 0.0646
# 迭代: [20/200], Loss: 0.0925
# 迭代: [20/200], Loss: 0.0671
# 迭代: [20/200], Loss: 0.1136
# 迭代: [20/200], Loss: 0.1037
# 迭代: [20/200], Loss: 0.0510
# 迭代: [20/200], Loss: 0.1120
# 迭代: [20/200], Loss: 0.0851
# 迭代: [20/200], Loss: 0.0719
# 迭代: [20/200], Loss: 0.0641
# 迭代: [20/200], Loss: 0.0559
# 迭代: [20/200], Loss: 0.1045
# 迭代: [20/200], Loss: 0.1038
# 迭代: [20/200], Loss: 0.0674
# 迭代: [20/200], Loss: 0.1382
# 迭代: [20/200], Loss: 0.0706
# 迭代: [20/200], Loss: 0.0814
# 迭代: [20/200], Loss: 0.1092
# 迭代: [20/200], Loss: 0.0580
# 迭代: [20/200], Loss: 0.1058
# 迭代: [20/200], Loss: 0.0688
# 迭代: [21/200], Loss: 0.1041
# 迭代: [21/200], Loss: 0.1827
# 迭代: [21/200], Loss: 0.1267
# 迭代: [21/200], Loss: 0.1128
# 迭代: [21/200], Loss: 0.1031
# 迭代: [21/200], Loss: 0.0952
# 迭代: [21/200], Loss: 0.0623
# 迭代: [21/200], Loss: 0.0832
# 迭代: [21/200], Loss: 0.0680
# 迭代: [21/200], Loss: 0.0600
# 迭代: [21/200], Loss: 0.0401
# 迭代: [21/200], Loss: 0.1318
# 迭代: [21/200], Loss: 0.1080
# 迭代: [21/200], Loss: 0.0588
# 迭代: [21/200], Loss: 0.0740
# 迭代: [21/200], Loss: 0.0998
# 迭代: [21/200], Loss: 0.0438
# 迭代: [21/200], Loss: 0.0832
# 迭代: [21/200], Loss: 0.0403
# 迭代: [21/200], Loss: 0.0858
# 迭代: [21/200], Loss: 0.0511
# 迭代: [21/200], Loss: 0.1107
# 迭代: [21/200], Loss: 0.0727
# 迭代: [21/200], Loss: 0.0694
# 迭代: [21/200], Loss: 0.1039
# 迭代: [21/200], Loss: 0.0597
# 迭代: [21/200], Loss: 0.0850
# 迭代: [21/200], Loss: 0.0564
# 迭代: [21/200], Loss: 0.1609
# 迭代: [21/200], Loss: 0.0717
# 迭代: [21/200], Loss: 0.1299
# 迭代: [21/200], Loss: 0.1103
# 迭代: [21/200], Loss: 0.1319
# 迭代: [21/200], Loss: 0.0953
# 迭代: [21/200], Loss: 0.0933
# 迭代: [21/200], Loss: 0.1466
# 迭代: [21/200], Loss: 0.0766
# 迭代: [21/200], Loss: 0.0628
# 迭代: [21/200], Loss: 0.1206
# 迭代: [21/200], Loss: 0.1067
# 迭代: [21/200], Loss: 0.0597
# 迭代: [21/200], Loss: 0.1030
# 迭代: [21/200], Loss: 0.0895
# 迭代: [21/200], Loss: 0.1095
# 迭代: [21/200], Loss: 0.1092
# 迭代: [21/200], Loss: 0.0925
# 迭代: [21/200], Loss: 0.1421
# 迭代: [21/200], Loss: 0.0748
# 迭代: [21/200], Loss: 0.0868
# 迭代: [21/200], Loss: 0.0941
# 迭代: [22/200], Loss: 0.1291
# 迭代: [22/200], Loss: 0.0823
# 迭代: [22/200], Loss: 0.1038
# 迭代: [22/200], Loss: 0.0634
# 迭代: [22/200], Loss: 0.0849
# 迭代: [22/200], Loss: 0.0741
# 迭代: [22/200], Loss: 0.0777
# 迭代: [22/200], Loss: 0.0881
# 迭代: [22/200], Loss: 0.0275
# 迭代: [22/200], Loss: 0.0629
# 迭代: [22/200], Loss: 0.0837
# 迭代: [22/200], Loss: 0.1025
# 迭代: [22/200], Loss: 0.1358
# 迭代: [22/200], Loss: 0.1381
# 迭代: [22/200], Loss: 0.1162
# 迭代: [22/200], Loss: 0.0740
# 迭代: [22/200], Loss: 0.0756
# 迭代: [22/200], Loss: 0.1461
# 迭代: [22/200], Loss: 0.0800
# 迭代: [22/200], Loss: 0.0309
# 迭代: [22/200], Loss: 0.0434
# 迭代: [22/200], Loss: 0.1546
# 迭代: [22/200], Loss: 0.0474
# 迭代: [22/200], Loss: 0.0614
# 迭代: [22/200], Loss: 0.0450
# 迭代: [22/200], Loss: 0.0998
# 迭代: [22/200], Loss: 0.1517
# 迭代: [22/200], Loss: 0.0885
# 迭代: [22/200], Loss: 0.1608
# 迭代: [22/200], Loss: 0.1218
# 迭代: [22/200], Loss: 0.0750
# 迭代: [22/200], Loss: 0.0707
# 迭代: [22/200], Loss: 0.0787
# 迭代: [22/200], Loss: 0.0403
# 迭代: [22/200], Loss: 0.0836
# 迭代: [22/200], Loss: 0.1005
# 迭代: [22/200], Loss: 0.1043
# 迭代: [22/200], Loss: 0.0509
# 迭代: [22/200], Loss: 0.0647
# 迭代: [22/200], Loss: 0.1853
# 迭代: [22/200], Loss: 0.0887
# 迭代: [22/200], Loss: 0.0180
# 迭代: [22/200], Loss: 0.0967
# 迭代: [22/200], Loss: 0.0623
# 迭代: [22/200], Loss: 0.0808
# 迭代: [22/200], Loss: 0.1431
# 迭代: [22/200], Loss: 0.0869
# 迭代: [22/200], Loss: 0.0689
# 迭代: [22/200], Loss: 0.0893
# 迭代: [22/200], Loss: 0.0683
# 迭代: [23/200], Loss: 0.1300
# 迭代: [23/200], Loss: 0.1265
# 迭代: [23/200], Loss: 0.1331
# 迭代: [23/200], Loss: 0.0636
# 迭代: [23/200], Loss: 0.1118
# 迭代: [23/200], Loss: 0.0737
# 迭代: [23/200], Loss: 0.1115
# 迭代: [23/200], Loss: 0.0672
# 迭代: [23/200], Loss: 0.0748
# 迭代: [23/200], Loss: 0.0626
# 迭代: [23/200], Loss: 0.0830
# 迭代: [23/200], Loss: 0.1076
# 迭代: [23/200], Loss: 0.1147
# 迭代: [23/200], Loss: 0.0698
# 迭代: [23/200], Loss: 0.0975
# 迭代: [23/200], Loss: 0.1193
# 迭代: [23/200], Loss: 0.0830
# 迭代: [23/200], Loss: 0.0647
# 迭代: [23/200], Loss: 0.0675
# 迭代: [23/200], Loss: 0.0614
# 迭代: [23/200], Loss: 0.1326
# 迭代: [23/200], Loss: 0.0802
# 迭代: [23/200], Loss: 0.0706
# 迭代: [23/200], Loss: 0.0795
# 迭代: [23/200], Loss: 0.0818
# 迭代: [23/200], Loss: 0.0684
# 迭代: [23/200], Loss: 0.0707
# 迭代: [23/200], Loss: 0.0451
# 迭代: [23/200], Loss: 0.1058
# 迭代: [23/200], Loss: 0.1102
# 迭代: [23/200], Loss: 0.0663
# 迭代: [23/200], Loss: 0.0695
# 迭代: [23/200], Loss: 0.1461
# 迭代: [23/200], Loss: 0.1223
# 迭代: [23/200], Loss: 0.0841
# 迭代: [23/200], Loss: 0.0836
# 迭代: [23/200], Loss: 0.0610
# 迭代: [23/200], Loss: 0.0962
# 迭代: [23/200], Loss: 0.1024
# 迭代: [23/200], Loss: 0.1503
# 迭代: [23/200], Loss: 0.1770
# 迭代: [23/200], Loss: 0.1002
# 迭代: [23/200], Loss: 0.0652
# 迭代: [23/200], Loss: 0.0947
# 迭代: [23/200], Loss: 0.0953
# 迭代: [23/200], Loss: 0.0957
# 迭代: [23/200], Loss: 0.0659
# 迭代: [23/200], Loss: 0.0903
# 迭代: [23/200], Loss: 0.0868
# 迭代: [23/200], Loss: 0.0797
# 迭代: [24/200], Loss: 0.0745
# 迭代: [24/200], Loss: 0.1174
# 迭代: [24/200], Loss: 0.0892
# 迭代: [24/200], Loss: 0.0593
# 迭代: [24/200], Loss: 0.0935
# 迭代: [24/200], Loss: 0.0675
# 迭代: [24/200], Loss: 0.0597
# 迭代: [24/200], Loss: 0.0649
# 迭代: [24/200], Loss: 0.0691
# 迭代: [24/200], Loss: 0.1114
# 迭代: [24/200], Loss: 0.0780
# 迭代: [24/200], Loss: 0.1037
# 迭代: [24/200], Loss: 0.0660
# 迭代: [24/200], Loss: 0.0843
# 迭代: [24/200], Loss: 0.0453
# 迭代: [24/200], Loss: 0.0685
# 迭代: [24/200], Loss: 0.1163
# 迭代: [24/200], Loss: 0.1481
# 迭代: [24/200], Loss: 0.0619
# 迭代: [24/200], Loss: 0.0994
# 迭代: [24/200], Loss: 0.0837
# 迭代: [24/200], Loss: 0.0891
# 迭代: [24/200], Loss: 0.1103
# 迭代: [24/200], Loss: 0.0517
# 迭代: [24/200], Loss: 0.1161
# 迭代: [24/200], Loss: 0.1094
# 迭代: [24/200], Loss: 0.1128
# 迭代: [24/200], Loss: 0.1022
# 迭代: [24/200], Loss: 0.0558
# 迭代: [24/200], Loss: 0.0632
# 迭代: [24/200], Loss: 0.0906
# 迭代: [24/200], Loss: 0.1392
# 迭代: [24/200], Loss: 0.1011
# 迭代: [24/200], Loss: 0.0855
# 迭代: [24/200], Loss: 0.1124
# 迭代: [24/200], Loss: 0.0593
# 迭代: [24/200], Loss: 0.0684
# 迭代: [24/200], Loss: 0.0486
# 迭代: [24/200], Loss: 0.1058
# 迭代: [24/200], Loss: 0.0592
# 迭代: [24/200], Loss: 0.1257
# 迭代: [24/200], Loss: 0.1364
# 迭代: [24/200], Loss: 0.0868
# 迭代: [24/200], Loss: 0.1326
# 迭代: [24/200], Loss: 0.1964
# 迭代: [24/200], Loss: 0.0731
# 迭代: [24/200], Loss: 0.0501
# 迭代: [24/200], Loss: 0.0883
# 迭代: [24/200], Loss: 0.1144
# 迭代: [24/200], Loss: 0.1314
# 迭代: [25/200], Loss: 0.0687
# 迭代: [25/200], Loss: 0.0926
# 迭代: [25/200], Loss: 0.1123
# 迭代: [25/200], Loss: 0.0687
# 迭代: [25/200], Loss: 0.0628
# 迭代: [25/200], Loss: 0.1023
# 迭代: [25/200], Loss: 0.0346
# 迭代: [25/200], Loss: 0.1192
# 迭代: [25/200], Loss: 0.0878
# 迭代: [25/200], Loss: 0.1862
# 迭代: [25/200], Loss: 0.0585
# 迭代: [25/200], Loss: 0.0722
# 迭代: [25/200], Loss: 0.0699
# 迭代: [25/200], Loss: 0.1156
# 迭代: [25/200], Loss: 0.0711
# 迭代: [25/200], Loss: 0.1076
# 迭代: [25/200], Loss: 0.0888
# 迭代: [25/200], Loss: 0.0779
# 迭代: [25/200], Loss: 0.0923
# 迭代: [25/200], Loss: 0.0600
# 迭代: [25/200], Loss: 0.1599
# 迭代: [25/200], Loss: 0.0684
# 迭代: [25/200], Loss: 0.0575
# 迭代: [25/200], Loss: 0.0988
# 迭代: [25/200], Loss: 0.0634
# 迭代: [25/200], Loss: 0.0705
# 迭代: [25/200], Loss: 0.0938
# 迭代: [25/200], Loss: 0.1052
# 迭代: [25/200], Loss: 0.0761
# 迭代: [25/200], Loss: 0.0832
# 迭代: [25/200], Loss: 0.0796
# 迭代: [25/200], Loss: 0.0690
# 迭代: [25/200], Loss: 0.1112
# 迭代: [25/200], Loss: 0.0811
# 迭代: [25/200], Loss: 0.1130
# 迭代: [25/200], Loss: 0.1484
# 迭代: [25/200], Loss: 0.0930
# 迭代: [25/200], Loss: 0.1457
# 迭代: [25/200], Loss: 0.1247
# 迭代: [25/200], Loss: 0.0431
# 迭代: [25/200], Loss: 0.0925
# 迭代: [25/200], Loss: 0.1076
# 迭代: [25/200], Loss: 0.0572
# 迭代: [25/200], Loss: 0.1296
# 迭代: [25/200], Loss: 0.0862
# 迭代: [25/200], Loss: 0.0706
# 迭代: [25/200], Loss: 0.0466
# 迭代: [25/200], Loss: 0.1014
# 迭代: [25/200], Loss: 0.0616
# 迭代: [25/200], Loss: 0.0544
# 迭代: [26/200], Loss: 0.0795
# 迭代: [26/200], Loss: 0.1083
# 迭代: [26/200], Loss: 0.0916
# 迭代: [26/200], Loss: 0.0647
# 迭代: [26/200], Loss: 0.0436
# 迭代: [26/200], Loss: 0.0948
# 迭代: [26/200], Loss: 0.0450
# 迭代: [26/200], Loss: 0.0998
# 迭代: [26/200], Loss: 0.0845
# 迭代: [26/200], Loss: 0.0813
# 迭代: [26/200], Loss: 0.0507
# 迭代: [26/200], Loss: 0.1283
# 迭代: [26/200], Loss: 0.0815
# 迭代: [26/200], Loss: 0.0800
# 迭代: [26/200], Loss: 0.0865
# 迭代: [26/200], Loss: 0.0836
# 迭代: [26/200], Loss: 0.1209
# 迭代: [26/200], Loss: 0.0998
# 迭代: [26/200], Loss: 0.1036
# 迭代: [26/200], Loss: 0.0783
# 迭代: [26/200], Loss: 0.0778
# 迭代: [26/200], Loss: 0.1204
# 迭代: [26/200], Loss: 0.0585
# 迭代: [26/200], Loss: 0.0570
# 迭代: [26/200], Loss: 0.0869
# 迭代: [26/200], Loss: 0.1319
# 迭代: [26/200], Loss: 0.0980
# 迭代: [26/200], Loss: 0.0594
# 迭代: [26/200], Loss: 0.0731
# 迭代: [26/200], Loss: 0.0925
# 迭代: [26/200], Loss: 0.1097
# 迭代: [26/200], Loss: 0.1061
# 迭代: [26/200], Loss: 0.0897
# 迭代: [26/200], Loss: 0.0719
# 迭代: [26/200], Loss: 0.1307
# 迭代: [26/200], Loss: 0.0815
# 迭代: [26/200], Loss: 0.1016
# 迭代: [26/200], Loss: 0.0945
# 迭代: [26/200], Loss: 0.0848
# 迭代: [26/200], Loss: 0.0825
# 迭代: [26/200], Loss: 0.0689
# 迭代: [26/200], Loss: 0.1146
# 迭代: [26/200], Loss: 0.1211
# 迭代: [26/200], Loss: 0.0758
# 迭代: [26/200], Loss: 0.0927
# 迭代: [26/200], Loss: 0.0498
# 迭代: [26/200], Loss: 0.0598
# 迭代: [26/200], Loss: 0.0300
# 迭代: [26/200], Loss: 0.0849
# 迭代: [26/200], Loss: 0.0836
# 迭代: [27/200], Loss: 0.0790
# 迭代: [27/200], Loss: 0.0790
# 迭代: [27/200], Loss: 0.1135
# 迭代: [27/200], Loss: 0.1169
# 迭代: [27/200], Loss: 0.1062
# 迭代: [27/200], Loss: 0.0535
# 迭代: [27/200], Loss: 0.1100
# 迭代: [27/200], Loss: 0.0640
# 迭代: [27/200], Loss: 0.0814
# 迭代: [27/200], Loss: 0.0585
# 迭代: [27/200], Loss: 0.1132
# 迭代: [27/200], Loss: 0.0834
# 迭代: [27/200], Loss: 0.0970
# 迭代: [27/200], Loss: 0.0852
# 迭代: [27/200], Loss: 0.0581
# 迭代: [27/200], Loss: 0.1188
# 迭代: [27/200], Loss: 0.0667
# 迭代: [27/200], Loss: 0.0650
# 迭代: [27/200], Loss: 0.0458
# 迭代: [27/200], Loss: 0.0804
# 迭代: [27/200], Loss: 0.0687
# 迭代: [27/200], Loss: 0.1045
# 迭代: [27/200], Loss: 0.0517
# 迭代: [27/200], Loss: 0.0860
# 迭代: [27/200], Loss: 0.0211
# 迭代: [27/200], Loss: 0.1298
# 迭代: [27/200], Loss: 0.0859
# 迭代: [27/200], Loss: 0.1135
# 迭代: [27/200], Loss: 0.0493
# 迭代: [27/200], Loss: 0.0925
# 迭代: [27/200], Loss: 0.0894
# 迭代: [27/200], Loss: 0.0763
# 迭代: [27/200], Loss: 0.0678
# 迭代: [27/200], Loss: 0.0616
# 迭代: [27/200], Loss: 0.1234
# 迭代: [27/200], Loss: 0.0714
# 迭代: [27/200], Loss: 0.0557
# 迭代: [27/200], Loss: 0.0805
# 迭代: [27/200], Loss: 0.0696
# 迭代: [27/200], Loss: 0.1121
# 迭代: [27/200], Loss: 0.0643
# 迭代: [27/200], Loss: 0.0455
# 迭代: [27/200], Loss: 0.1670
# 迭代: [27/200], Loss: 0.0974
# 迭代: [27/200], Loss: 0.0851
# 迭代: [27/200], Loss: 0.0915
# 迭代: [27/200], Loss: 0.0440
# 迭代: [27/200], Loss: 0.0539
# 迭代: [27/200], Loss: 0.1159
# 迭代: [27/200], Loss: 0.0797
# 迭代: [28/200], Loss: 0.1830
# 迭代: [28/200], Loss: 0.1214
# 迭代: [28/200], Loss: 0.0690
# 迭代: [28/200], Loss: 0.0473
# 迭代: [28/200], Loss: 0.1131
# 迭代: [28/200], Loss: 0.0766
# 迭代: [28/200], Loss: 0.1036
# 迭代: [28/200], Loss: 0.0831
# 迭代: [28/200], Loss: 0.0513
# 迭代: [28/200], Loss: 0.1298
# 迭代: [28/200], Loss: 0.0564
# 迭代: [28/200], Loss: 0.1333
# 迭代: [28/200], Loss: 0.0466
# 迭代: [28/200], Loss: 0.0734
# 迭代: [28/200], Loss: 0.1173
# 迭代: [28/200], Loss: 0.1511
# 迭代: [28/200], Loss: 0.0533
# 迭代: [28/200], Loss: 0.0721
# 迭代: [28/200], Loss: 0.0921
# 迭代: [28/200], Loss: 0.0541
# 迭代: [28/200], Loss: 0.1175
# 迭代: [28/200], Loss: 0.0721
# 迭代: [28/200], Loss: 0.0577
# 迭代: [28/200], Loss: 0.1217
# 迭代: [28/200], Loss: 0.0483
# 迭代: [28/200], Loss: 0.0486
# 迭代: [28/200], Loss: 0.0446
# 迭代: [28/200], Loss: 0.1019
# 迭代: [28/200], Loss: 0.0681
# 迭代: [28/200], Loss: 0.0610
# 迭代: [28/200], Loss: 0.0786
# 迭代: [28/200], Loss: 0.1095
# 迭代: [28/200], Loss: 0.0739
# 迭代: [28/200], Loss: 0.0642
# 迭代: [28/200], Loss: 0.1664
# 迭代: [28/200], Loss: 0.1585
# 迭代: [28/200], Loss: 0.0668
# 迭代: [28/200], Loss: 0.0873
# 迭代: [28/200], Loss: 0.0582
# 迭代: [28/200], Loss: 0.0772
# 迭代: [28/200], Loss: 0.0912
# 迭代: [28/200], Loss: 0.0847
# 迭代: [28/200], Loss: 0.0765
# 迭代: [28/200], Loss: 0.0774
# 迭代: [28/200], Loss: 0.0797
# 迭代: [28/200], Loss: 0.1071
# 迭代: [28/200], Loss: 0.0525
# 迭代: [28/200], Loss: 0.0565
# 迭代: [28/200], Loss: 0.0913
# 迭代: [28/200], Loss: 0.1566
# 迭代: [29/200], Loss: 0.0503
# 迭代: [29/200], Loss: 0.1278
# 迭代: [29/200], Loss: 0.0793
# 迭代: [29/200], Loss: 0.0428
# 迭代: [29/200], Loss: 0.0644
# 迭代: [29/200], Loss: 0.0512
# 迭代: [29/200], Loss: 0.0885
# 迭代: [29/200], Loss: 0.0746
# 迭代: [29/200], Loss: 0.0515
# 迭代: [29/200], Loss: 0.1183
# 迭代: [29/200], Loss: 0.0798
# 迭代: [29/200], Loss: 0.0689
# 迭代: [29/200], Loss: 0.0736
# 迭代: [29/200], Loss: 0.0639
# 迭代: [29/200], Loss: 0.0829
# 迭代: [29/200], Loss: 0.0684
# 迭代: [29/200], Loss: 0.0840
# 迭代: [29/200], Loss: 0.0871
# 迭代: [29/200], Loss: 0.0443
# 迭代: [29/200], Loss: 0.0654
# 迭代: [29/200], Loss: 0.0641
# 迭代: [29/200], Loss: 0.0958
# 迭代: [29/200], Loss: 0.1104
# 迭代: [29/200], Loss: 0.0597
# 迭代: [29/200], Loss: 0.1307
# 迭代: [29/200], Loss: 0.0706
# 迭代: [29/200], Loss: 0.1181
# 迭代: [29/200], Loss: 0.0653
# 迭代: [29/200], Loss: 0.0597
# 迭代: [29/200], Loss: 0.0941
# 迭代: [29/200], Loss: 0.0767
# 迭代: [29/200], Loss: 0.0746
# 迭代: [29/200], Loss: 0.0660
# 迭代: [29/200], Loss: 0.0749
# 迭代: [29/200], Loss: 0.1276
# 迭代: [29/200], Loss: 0.0844
# 迭代: [29/200], Loss: 0.1034
# 迭代: [29/200], Loss: 0.0666
# 迭代: [29/200], Loss: 0.0901
# 迭代: [29/200], Loss: 0.0216
# 迭代: [29/200], Loss: 0.1182
# 迭代: [29/200], Loss: 0.0874
# 迭代: [29/200], Loss: 0.0661
# 迭代: [29/200], Loss: 0.0615
# 迭代: [29/200], Loss: 0.0719
# 迭代: [29/200], Loss: 0.0681
# 迭代: [29/200], Loss: 0.0877
# 迭代: [29/200], Loss: 0.0997
# 迭代: [29/200], Loss: 0.0839
# 迭代: [29/200], Loss: 0.0969
# 迭代: [30/200], Loss: 0.1187
# 迭代: [30/200], Loss: 0.0431
# 迭代: [30/200], Loss: 0.0765
# 迭代: [30/200], Loss: 0.0861
# 迭代: [30/200], Loss: 0.0569
# 迭代: [30/200], Loss: 0.0507
# 迭代: [30/200], Loss: 0.0300
# 迭代: [30/200], Loss: 0.0711
# 迭代: [30/200], Loss: 0.0582
# 迭代: [30/200], Loss: 0.0652
# 迭代: [30/200], Loss: 0.0844
# 迭代: [30/200], Loss: 0.0535
# 迭代: [30/200], Loss: 0.0649
# 迭代: [30/200], Loss: 0.0631
# 迭代: [30/200], Loss: 0.0568
# 迭代: [30/200], Loss: 0.0619
# 迭代: [30/200], Loss: 0.0804
# 迭代: [30/200], Loss: 0.0592
# 迭代: [30/200], Loss: 0.1060
# 迭代: [30/200], Loss: 0.0703
# 迭代: [30/200], Loss: 0.1485
# 迭代: [30/200], Loss: 0.0560
# 迭代: [30/200], Loss: 0.0619
# 迭代: [30/200], Loss: 0.0657
# 迭代: [30/200], Loss: 0.0838
# 迭代: [30/200], Loss: 0.0727
# 迭代: [30/200], Loss: 0.0961
# 迭代: [30/200], Loss: 0.0893
# 迭代: [30/200], Loss: 0.0977
# 迭代: [30/200], Loss: 0.0360
# 迭代: [30/200], Loss: 0.0694
# 迭代: [30/200], Loss: 0.0737
# 迭代: [30/200], Loss: 0.1287
# 迭代: [30/200], Loss: 0.0687
# 迭代: [30/200], Loss: 0.0994
# 迭代: [30/200], Loss: 0.1372
# 迭代: [30/200], Loss: 0.0672
# 迭代: [30/200], Loss: 0.0955
# 迭代: [30/200], Loss: 0.1046
# 迭代: [30/200], Loss: 0.1280
# 迭代: [30/200], Loss: 0.0991
# 迭代: [30/200], Loss: 0.0603
# 迭代: [30/200], Loss: 0.0841
# 迭代: [30/200], Loss: 0.0547
# 迭代: [30/200], Loss: 0.1348
# 迭代: [30/200], Loss: 0.0737
# 迭代: [30/200], Loss: 0.1146
# 迭代: [30/200], Loss: 0.0616
# 迭代: [30/200], Loss: 0.1352
# 迭代: [30/200], Loss: 0.0631
# 迭代: [31/200], Loss: 0.0849
# 迭代: [31/200], Loss: 0.1910
# 迭代: [31/200], Loss: 0.1137
# 迭代: [31/200], Loss: 0.0654
# 迭代: [31/200], Loss: 0.0813
# 迭代: [31/200], Loss: 0.0808
# 迭代: [31/200], Loss: 0.1154
# 迭代: [31/200], Loss: 0.1644
# 迭代: [31/200], Loss: 0.0872
# 迭代: [31/200], Loss: 0.0555
# 迭代: [31/200], Loss: 0.0764
# 迭代: [31/200], Loss: 0.0552
# 迭代: [31/200], Loss: 0.0864
# 迭代: [31/200], Loss: 0.0457
# 迭代: [31/200], Loss: 0.0751
# 迭代: [31/200], Loss: 0.0846
# 迭代: [31/200], Loss: 0.0851
# 迭代: [31/200], Loss: 0.0441
# 迭代: [31/200], Loss: 0.0633
# 迭代: [31/200], Loss: 0.0743
# 迭代: [31/200], Loss: 0.0712
# 迭代: [31/200], Loss: 0.0710
# 迭代: [31/200], Loss: 0.0858
# 迭代: [31/200], Loss: 0.0983
# 迭代: [31/200], Loss: 0.0712
# 迭代: [31/200], Loss: 0.0813
# 迭代: [31/200], Loss: 0.0480
# 迭代: [31/200], Loss: 0.0904
# 迭代: [31/200], Loss: 0.0822
# 迭代: [31/200], Loss: 0.1317
# 迭代: [31/200], Loss: 0.0361
# 迭代: [31/200], Loss: 0.0567
# 迭代: [31/200], Loss: 0.0607
# 迭代: [31/200], Loss: 0.0709
# 迭代: [31/200], Loss: 0.0686
# 迭代: [31/200], Loss: 0.0630
# 迭代: [31/200], Loss: 0.0768
# 迭代: [31/200], Loss: 0.1159
# 迭代: [31/200], Loss: 0.1082
# 迭代: [31/200], Loss: 0.1039
# 迭代: [31/200], Loss: 0.0604
# 迭代: [31/200], Loss: 0.1395
# 迭代: [31/200], Loss: 0.0971
# 迭代: [31/200], Loss: 0.0614
# 迭代: [31/200], Loss: 0.0409
# 迭代: [31/200], Loss: 0.0689
# 迭代: [31/200], Loss: 0.0579
# 迭代: [31/200], Loss: 0.1330
# 迭代: [31/200], Loss: 0.0510
# 迭代: [31/200], Loss: 0.1559
# 迭代: [32/200], Loss: 0.1155
# 迭代: [32/200], Loss: 0.1678
# 迭代: [32/200], Loss: 0.1187
# 迭代: [32/200], Loss: 0.0383
# 迭代: [32/200], Loss: 0.0452
# 迭代: [32/200], Loss: 0.0740
# 迭代: [32/200], Loss: 0.0538
# 迭代: [32/200], Loss: 0.0417
# 迭代: [32/200], Loss: 0.0802
# 迭代: [32/200], Loss: 0.0822
# 迭代: [32/200], Loss: 0.1294
# 迭代: [32/200], Loss: 0.0743
# 迭代: [32/200], Loss: 0.0725
# 迭代: [32/200], Loss: 0.0644
# 迭代: [32/200], Loss: 0.0735
# 迭代: [32/200], Loss: 0.0856
# 迭代: [32/200], Loss: 0.0474
# 迭代: [32/200], Loss: 0.1055
# 迭代: [32/200], Loss: 0.0864
# 迭代: [32/200], Loss: 0.1172
# 迭代: [32/200], Loss: 0.1256
# 迭代: [32/200], Loss: 0.0786
# 迭代: [32/200], Loss: 0.1151
# 迭代: [32/200], Loss: 0.0534
# 迭代: [32/200], Loss: 0.0638
# 迭代: [32/200], Loss: 0.0911
# 迭代: [32/200], Loss: 0.0959
# 迭代: [32/200], Loss: 0.0471
# 迭代: [32/200], Loss: 0.1084
# 迭代: [32/200], Loss: 0.1452
# 迭代: [32/200], Loss: 0.1168
# 迭代: [32/200], Loss: 0.0706
# 迭代: [32/200], Loss: 0.0554
# 迭代: [32/200], Loss: 0.0831
# 迭代: [32/200], Loss: 0.0984
# 迭代: [32/200], Loss: 0.0596
# 迭代: [32/200], Loss: 0.0884
# 迭代: [32/200], Loss: 0.0847
# 迭代: [32/200], Loss: 0.0789
# 迭代: [32/200], Loss: 0.0786
# 迭代: [32/200], Loss: 0.0662
# 迭代: [32/200], Loss: 0.0673
# 迭代: [32/200], Loss: 0.0606
# 迭代: [32/200], Loss: 0.0295
# 迭代: [32/200], Loss: 0.0871
# 迭代: [32/200], Loss: 0.0601
# 迭代: [32/200], Loss: 0.0822
# 迭代: [32/200], Loss: 0.0411
# 迭代: [32/200], Loss: 0.0706
# 迭代: [32/200], Loss: 0.0781
# 迭代: [33/200], Loss: 0.0536
# 迭代: [33/200], Loss: 0.0964
# 迭代: [33/200], Loss: 0.0965
# 迭代: [33/200], Loss: 0.0897
# 迭代: [33/200], Loss: 0.0908
# 迭代: [33/200], Loss: 0.0867
# 迭代: [33/200], Loss: 0.0497
# 迭代: [33/200], Loss: 0.1309
# 迭代: [33/200], Loss: 0.0841
# 迭代: [33/200], Loss: 0.0754
# 迭代: [33/200], Loss: 0.0555
# 迭代: [33/200], Loss: 0.0597
# 迭代: [33/200], Loss: 0.0972
# 迭代: [33/200], Loss: 0.0340
# 迭代: [33/200], Loss: 0.1426
# 迭代: [33/200], Loss: 0.0527
# 迭代: [33/200], Loss: 0.0927
# 迭代: [33/200], Loss: 0.1122
# 迭代: [33/200], Loss: 0.1532
# 迭代: [33/200], Loss: 0.0655
# 迭代: [33/200], Loss: 0.0763
# 迭代: [33/200], Loss: 0.0734
# 迭代: [33/200], Loss: 0.0671
# 迭代: [33/200], Loss: 0.0536
# 迭代: [33/200], Loss: 0.0617
# 迭代: [33/200], Loss: 0.0904
# 迭代: [33/200], Loss: 0.0761
# 迭代: [33/200], Loss: 0.0845
# 迭代: [33/200], Loss: 0.0689
# 迭代: [33/200], Loss: 0.0469
# 迭代: [33/200], Loss: 0.0920
# 迭代: [33/200], Loss: 0.0631
# 迭代: [33/200], Loss: 0.0613
# 迭代: [33/200], Loss: 0.1194
# 迭代: [33/200], Loss: 0.0990
# 迭代: [33/200], Loss: 0.0674
# 迭代: [33/200], Loss: 0.0637
# 迭代: [33/200], Loss: 0.0784
# 迭代: [33/200], Loss: 0.0493
# 迭代: [33/200], Loss: 0.0580
# 迭代: [33/200], Loss: 0.0822
# 迭代: [33/200], Loss: 0.0753
# 迭代: [33/200], Loss: 0.0263
# 迭代: [33/200], Loss: 0.0478
# 迭代: [33/200], Loss: 0.1038
# 迭代: [33/200], Loss: 0.0671
# 迭代: [33/200], Loss: 0.1018
# 迭代: [33/200], Loss: 0.0548
# 迭代: [33/200], Loss: 0.1190
# 迭代: [33/200], Loss: 0.1068
# 迭代: [34/200], Loss: 0.0778
# 迭代: [34/200], Loss: 0.0701
# 迭代: [34/200], Loss: 0.1066
# 迭代: [34/200], Loss: 0.0408
# 迭代: [34/200], Loss: 0.0632
# 迭代: [34/200], Loss: 0.1005
# 迭代: [34/200], Loss: 0.1299
# 迭代: [34/200], Loss: 0.1146
# 迭代: [34/200], Loss: 0.0872
# 迭代: [34/200], Loss: 0.0802
# 迭代: [34/200], Loss: 0.0458
# 迭代: [34/200], Loss: 0.0469
# 迭代: [34/200], Loss: 0.0810
# 迭代: [34/200], Loss: 0.0806
# 迭代: [34/200], Loss: 0.0710
# 迭代: [34/200], Loss: 0.0981
# 迭代: [34/200], Loss: 0.1034
# 迭代: [34/200], Loss: 0.1078
# 迭代: [34/200], Loss: 0.0729
# 迭代: [34/200], Loss: 0.0851
# 迭代: [34/200], Loss: 0.1192
# 迭代: [34/200], Loss: 0.0699
# 迭代: [34/200], Loss: 0.0621
# 迭代: [34/200], Loss: 0.0705
# 迭代: [34/200], Loss: 0.0785
# 迭代: [34/200], Loss: 0.0475
# 迭代: [34/200], Loss: 0.0726
# 迭代: [34/200], Loss: 0.0444
# 迭代: [34/200], Loss: 0.0665
# 迭代: [34/200], Loss: 0.0542
# 迭代: [34/200], Loss: 0.0835
# 迭代: [34/200], Loss: 0.0678
# 迭代: [34/200], Loss: 0.0774
# 迭代: [34/200], Loss: 0.0461
# 迭代: [34/200], Loss: 0.1124
# 迭代: [34/200], Loss: 0.0634
# 迭代: [34/200], Loss: 0.1538
# 迭代: [34/200], Loss: 0.0815
# 迭代: [34/200], Loss: 0.0456
# 迭代: [34/200], Loss: 0.0298
# 迭代: [34/200], Loss: 0.1122
# 迭代: [34/200], Loss: 0.0274
# 迭代: [34/200], Loss: 0.0474
# 迭代: [34/200], Loss: 0.0687
# 迭代: [34/200], Loss: 0.0776
# 迭代: [34/200], Loss: 0.0526
# 迭代: [34/200], Loss: 0.1193
# 迭代: [34/200], Loss: 0.2180
# 迭代: [34/200], Loss: 0.0728
# 迭代: [34/200], Loss: 0.1073
# 迭代: [35/200], Loss: 0.1196
# 迭代: [35/200], Loss: 0.0714
# 迭代: [35/200], Loss: 0.0718
# 迭代: [35/200], Loss: 0.0599
# 迭代: [35/200], Loss: 0.0761
# 迭代: [35/200], Loss: 0.0672
# 迭代: [35/200], Loss: 0.0831
# 迭代: [35/200], Loss: 0.0870
# 迭代: [35/200], Loss: 0.0328
# 迭代: [35/200], Loss: 0.1194
# 迭代: [35/200], Loss: 0.0291
# 迭代: [35/200], Loss: 0.0569
# 迭代: [35/200], Loss: 0.0898
# 迭代: [35/200], Loss: 0.0884
# 迭代: [35/200], Loss: 0.0346
# 迭代: [35/200], Loss: 0.0519
# 迭代: [35/200], Loss: 0.0906
# 迭代: [35/200], Loss: 0.0674
# 迭代: [35/200], Loss: 0.0614
# 迭代: [35/200], Loss: 0.0689
# 迭代: [35/200], Loss: 0.0867
# 迭代: [35/200], Loss: 0.0772
# 迭代: [35/200], Loss: 0.0692
# 迭代: [35/200], Loss: 0.0963
# 迭代: [35/200], Loss: 0.0312
# 迭代: [35/200], Loss: 0.0958
# 迭代: [35/200], Loss: 0.0877
# 迭代: [35/200], Loss: 0.0871
# 迭代: [35/200], Loss: 0.0754
# 迭代: [35/200], Loss: 0.0818
# 迭代: [35/200], Loss: 0.0546
# 迭代: [35/200], Loss: 0.0640
# 迭代: [35/200], Loss: 0.0763
# 迭代: [35/200], Loss: 0.0625
# 迭代: [35/200], Loss: 0.0792
# 迭代: [35/200], Loss: 0.0560
# 迭代: [35/200], Loss: 0.0701
# 迭代: [35/200], Loss: 0.1117
# 迭代: [35/200], Loss: 0.0992
# 迭代: [35/200], Loss: 0.1378
# 迭代: [35/200], Loss: 0.0467
# 迭代: [35/200], Loss: 0.1094
# 迭代: [35/200], Loss: 0.0506
# 迭代: [35/200], Loss: 0.1010
# 迭代: [35/200], Loss: 0.0716
# 迭代: [35/200], Loss: 0.1015
# 迭代: [35/200], Loss: 0.0550
# 迭代: [35/200], Loss: 0.0626
# 迭代: [35/200], Loss: 0.0699
# 迭代: [35/200], Loss: 0.0669
# 迭代: [36/200], Loss: 0.0446
# 迭代: [36/200], Loss: 0.0703
# 迭代: [36/200], Loss: 0.0852
# 迭代: [36/200], Loss: 0.0580
# 迭代: [36/200], Loss: 0.1015
# 迭代: [36/200], Loss: 0.0774
# 迭代: [36/200], Loss: 0.1108
# 迭代: [36/200], Loss: 0.0864
# 迭代: [36/200], Loss: 0.1040
# 迭代: [36/200], Loss: 0.0701
# 迭代: [36/200], Loss: 0.0940
# 迭代: [36/200], Loss: 0.0544
# 迭代: [36/200], Loss: 0.0747
# 迭代: [36/200], Loss: 0.0752
# 迭代: [36/200], Loss: 0.0933
# 迭代: [36/200], Loss: 0.0809
# 迭代: [36/200], Loss: 0.0415
# 迭代: [36/200], Loss: 0.1201
# 迭代: [36/200], Loss: 0.0623
# 迭代: [36/200], Loss: 0.1087
# 迭代: [36/200], Loss: 0.0476
# 迭代: [36/200], Loss: 0.0659
# 迭代: [36/200], Loss: 0.1392
# 迭代: [36/200], Loss: 0.0450
# 迭代: [36/200], Loss: 0.0776
# 迭代: [36/200], Loss: 0.0770
# 迭代: [36/200], Loss: 0.0426
# 迭代: [36/200], Loss: 0.0705
# 迭代: [36/200], Loss: 0.0884
# 迭代: [36/200], Loss: 0.0604
# 迭代: [36/200], Loss: 0.0753
# 迭代: [36/200], Loss: 0.0598
# 迭代: [36/200], Loss: 0.0516
# 迭代: [36/200], Loss: 0.1052
# 迭代: [36/200], Loss: 0.1233
# 迭代: [36/200], Loss: 0.0845
# 迭代: [36/200], Loss: 0.0829
# 迭代: [36/200], Loss: 0.0515
# 迭代: [36/200], Loss: 0.0494
# 迭代: [36/200], Loss: 0.0361
# 迭代: [36/200], Loss: 0.0316
# 迭代: [36/200], Loss: 0.0524
# 迭代: [36/200], Loss: 0.0551
# 迭代: [36/200], Loss: 0.0404
# ...
# 迭代: [189/200], Loss: 0.0039
# 迭代: [189/200], Loss: 0.0021
# 迭代: [189/200], Loss: 0.0046
# 迭代: [189/200], Loss: 0.0035
# 迭代: [189/200], Loss: 0.0040
# 迭代: [189/200], Loss: 0.0063
# 迭代: [189/200], Loss: 0.0084
# 迭代: [189/200], Loss: 0.0037
# 迭代: [189/200], Loss: 0.0023
# 迭代: [189/200], Loss: 0.0014
# 迭代: [189/200], Loss: 0.0039
# 迭代: [189/200], Loss: 0.0037
# 迭代: [189/200], Loss: 0.0056
# 迭代: [189/200], Loss: 0.0043
# 迭代: [189/200], Loss: 0.0063
# 迭代: [189/200], Loss: 0.0021
# 迭代: [189/200], Loss: 0.0078
# 迭代: [189/200], Loss: 0.0026
# 迭代: [189/200], Loss: 0.0071
# 迭代: [189/200], Loss: 0.0068
# 迭代: [189/200], Loss: 0.0021
# 迭代: [190/200], Loss: 0.0047
# 迭代: [190/200], Loss: 0.0053
# 迭代: [190/200], Loss: 0.0034
# 迭代: [190/200], Loss: 0.0053
# 迭代: [190/200], Loss: 0.0059
# 迭代: [190/200], Loss: 0.0040
# 迭代: [190/200], Loss: 0.0053
# 迭代: [190/200], Loss: 0.0027
# 迭代: [190/200], Loss: 0.0075
# 迭代: [190/200], Loss: 0.0020
# 迭代: [190/200], Loss: 0.0072
# 迭代: [190/200], Loss: 0.0051
# 迭代: [190/200], Loss: 0.0065
# 迭代: [190/200], Loss: 0.0029
# 迭代: [190/200], Loss: 0.0082
# 迭代: [190/200], Loss: 0.0023
# 迭代: [190/200], Loss: 0.0046
# 迭代: [190/200], Loss: 0.0017
# 迭代: [190/200], Loss: 0.0038
# 迭代: [190/200], Loss: 0.0043
# 迭代: [190/200], Loss: 0.0055
# 迭代: [190/200], Loss: 0.0060
# 迭代: [190/200], Loss: 0.0047
# 迭代: [190/200], Loss: 0.0048
# 迭代: [190/200], Loss: 0.0024
# 迭代: [190/200], Loss: 0.0052
# 迭代: [190/200], Loss: 0.0031
# 迭代: [190/200], Loss: 0.0028
# 迭代: [190/200], Loss: 0.0062
# 迭代: [190/200], Loss: 0.0074
# 迭代: [190/200], Loss: 0.0033
# 迭代: [190/200], Loss: 0.0033
# 迭代: [190/200], Loss: 0.0020
# 迭代: [190/200], Loss: 0.0019
# 迭代: [190/200], Loss: 0.0043
# 迭代: [190/200], Loss: 0.0033
# 迭代: [190/200], Loss: 0.0017
# 迭代: [190/200], Loss: 0.0056
# 迭代: [190/200], Loss: 0.0032
# 迭代: [190/200], Loss: 0.0054
# 迭代: [190/200], Loss: 0.0050
# 迭代: [190/200], Loss: 0.0033
# 迭代: [190/200], Loss: 0.0111
# 迭代: [190/200], Loss: 0.0060
# 迭代: [190/200], Loss: 0.0039
# 迭代: [190/200], Loss: 0.0061
# 迭代: [190/200], Loss: 0.0030
# 迭代: [190/200], Loss: 0.0056
# 迭代: [190/200], Loss: 0.0076
# 迭代: [190/200], Loss: 0.0076
# 迭代: [191/200], Loss: 0.0021
# 迭代: [191/200], Loss: 0.0052
# 迭代: [191/200], Loss: 0.0031
# 迭代: [191/200], Loss: 0.0031
# 迭代: [191/200], Loss: 0.0027
# 迭代: [191/200], Loss: 0.0057
# 迭代: [191/200], Loss: 0.0039
# 迭代: [191/200], Loss: 0.0044
# 迭代: [191/200], Loss: 0.0049
# 迭代: [191/200], Loss: 0.0040
# 迭代: [191/200], Loss: 0.0017
# 迭代: [191/200], Loss: 0.0043
# 迭代: [191/200], Loss: 0.0101
# 迭代: [191/200], Loss: 0.0036
# 迭代: [191/200], Loss: 0.0043
# 迭代: [191/200], Loss: 0.0021
# 迭代: [191/200], Loss: 0.0045
# 迭代: [191/200], Loss: 0.0051
# 迭代: [191/200], Loss: 0.0030
# 迭代: [191/200], Loss: 0.0044
# 迭代: [191/200], Loss: 0.0039
# 迭代: [191/200], Loss: 0.0042
# 迭代: [191/200], Loss: 0.0059
# 迭代: [191/200], Loss: 0.0029
# 迭代: [191/200], Loss: 0.0064
# 迭代: [191/200], Loss: 0.0064
# 迭代: [191/200], Loss: 0.0034
# 迭代: [191/200], Loss: 0.0066
# 迭代: [191/200], Loss: 0.0037
# 迭代: [191/200], Loss: 0.0040
# 迭代: [191/200], Loss: 0.0050
# 迭代: [191/200], Loss: 0.0055
# 迭代: [191/200], Loss: 0.0041
# 迭代: [191/200], Loss: 0.0031
# 迭代: [191/200], Loss: 0.0040
# 迭代: [191/200], Loss: 0.0058
# 迭代: [191/200], Loss: 0.0046
# 迭代: [191/200], Loss: 0.0050
# 迭代: [191/200], Loss: 0.0035
# 迭代: [191/200], Loss: 0.0042
# 迭代: [191/200], Loss: 0.0062
# 迭代: [191/200], Loss: 0.0037
# 迭代: [191/200], Loss: 0.0020
# 迭代: [191/200], Loss: 0.0058
# 迭代: [191/200], Loss: 0.0051
# 迭代: [191/200], Loss: 0.0084
# 迭代: [191/200], Loss: 0.0069
# 迭代: [191/200], Loss: 0.0035
# 迭代: [191/200], Loss: 0.0040
# 迭代: [191/200], Loss: 0.0023
# 迭代: [192/200], Loss: 0.0050
# 迭代: [192/200], Loss: 0.0036
# 迭代: [192/200], Loss: 0.0040
# 迭代: [192/200], Loss: 0.0015
# 迭代: [192/200], Loss: 0.0075
# 迭代: [192/200], Loss: 0.0122
# 迭代: [192/200], Loss: 0.0090
# 迭代: [192/200], Loss: 0.0099
# 迭代: [192/200], Loss: 0.0073
# 迭代: [192/200], Loss: 0.0057
# 迭代: [192/200], Loss: 0.0063
# 迭代: [192/200], Loss: 0.0014
# 迭代: [192/200], Loss: 0.0039
# 迭代: [192/200], Loss: 0.0034
# 迭代: [192/200], Loss: 0.0099
# 迭代: [192/200], Loss: 0.0045
# 迭代: [192/200], Loss: 0.0042
# 迭代: [192/200], Loss: 0.0052
# 迭代: [192/200], Loss: 0.0031
# 迭代: [192/200], Loss: 0.0038
# 迭代: [192/200], Loss: 0.0069
# 迭代: [192/200], Loss: 0.0067
# 迭代: [192/200], Loss: 0.0008
# 迭代: [192/200], Loss: 0.0035
# 迭代: [192/200], Loss: 0.0047
# 迭代: [192/200], Loss: 0.0046
# 迭代: [192/200], Loss: 0.0036
# 迭代: [192/200], Loss: 0.0067
# 迭代: [192/200], Loss: 0.0061
# 迭代: [192/200], Loss: 0.0049
# 迭代: [192/200], Loss: 0.0035
# 迭代: [192/200], Loss: 0.0043
# 迭代: [192/200], Loss: 0.0029
# 迭代: [192/200], Loss: 0.0048
# 迭代: [192/200], Loss: 0.0028
# 迭代: [192/200], Loss: 0.0051
# 迭代: [192/200], Loss: 0.0048
# 迭代: [192/200], Loss: 0.0076
# 迭代: [192/200], Loss: 0.0082
# 迭代: [192/200], Loss: 0.0065
# 迭代: [192/200], Loss: 0.0021
# 迭代: [192/200], Loss: 0.0049
# 迭代: [192/200], Loss: 0.0045
# 迭代: [192/200], Loss: 0.0054
# 迭代: [192/200], Loss: 0.0058
# 迭代: [192/200], Loss: 0.0067
# 迭代: [192/200], Loss: 0.0030
# 迭代: [192/200], Loss: 0.0025
# 迭代: [192/200], Loss: 0.0046
# 迭代: [192/200], Loss: 0.0027
# 迭代: [193/200], Loss: 0.0019
# 迭代: [193/200], Loss: 0.0024
# 迭代: [193/200], Loss: 0.0073
# 迭代: [193/200], Loss: 0.0071
# 迭代: [193/200], Loss: 0.0031
# 迭代: [193/200], Loss: 0.0038
# 迭代: [193/200], Loss: 0.0038
# 迭代: [193/200], Loss: 0.0033
# 迭代: [193/200], Loss: 0.0054
# 迭代: [193/200], Loss: 0.0028
# 迭代: [193/200], Loss: 0.0048
# 迭代: [193/200], Loss: 0.0042
# 迭代: [193/200], Loss: 0.0045
# 迭代: [193/200], Loss: 0.0034
# 迭代: [193/200], Loss: 0.0072
# 迭代: [193/200], Loss: 0.0019
# 迭代: [193/200], Loss: 0.0074
# 迭代: [193/200], Loss: 0.0156
# 迭代: [193/200], Loss: 0.0170
# 迭代: [193/200], Loss: 0.0122
# 迭代: [193/200], Loss: 0.0081
# 迭代: [193/200], Loss: 0.0053
# 迭代: [193/200], Loss: 0.0037
# 迭代: [193/200], Loss: 0.0053
# 迭代: [193/200], Loss: 0.0034
# 迭代: [193/200], Loss: 0.0065
# 迭代: [193/200], Loss: 0.0033
# 迭代: [193/200], Loss: 0.0048
# 迭代: [193/200], Loss: 0.0038
# 迭代: [193/200], Loss: 0.0044
# 迭代: [193/200], Loss: 0.0044
# 迭代: [193/200], Loss: 0.0043
# 迭代: [193/200], Loss: 0.0020
# 迭代: [193/200], Loss: 0.0067
# 迭代: [193/200], Loss: 0.0132
# 迭代: [193/200], Loss: 0.0079
# 迭代: [193/200], Loss: 0.0076
# 迭代: [193/200], Loss: 0.0066
# 迭代: [193/200], Loss: 0.0058
# 迭代: [193/200], Loss: 0.0063
# 迭代: [193/200], Loss: 0.0044
# 迭代: [193/200], Loss: 0.0028
# 迭代: [193/200], Loss: 0.0044
# 迭代: [193/200], Loss: 0.0084
# 迭代: [193/200], Loss: 0.0058
# 迭代: [193/200], Loss: 0.0023
# 迭代: [193/200], Loss: 0.0028
# 迭代: [193/200], Loss: 0.0052
# 迭代: [193/200], Loss: 0.0022
# 迭代: [193/200], Loss: 0.0062
# 迭代: [194/200], Loss: 0.0069
# 迭代: [194/200], Loss: 0.0043
# 迭代: [194/200], Loss: 0.0034
# 迭代: [194/200], Loss: 0.0039
# 迭代: [194/200], Loss: 0.0015
# 迭代: [194/200], Loss: 0.0033
# 迭代: [194/200], Loss: 0.0042
# 迭代: [194/200], Loss: 0.0079
# 迭代: [194/200], Loss: 0.0043
# 迭代: [194/200], Loss: 0.0036
# 迭代: [194/200], Loss: 0.0089
# 迭代: [194/200], Loss: 0.0097
# 迭代: [194/200], Loss: 0.0058
# 迭代: [194/200], Loss: 0.0053
# 迭代: [194/200], Loss: 0.0077
# 迭代: [194/200], Loss: 0.0060
# 迭代: [194/200], Loss: 0.0068
# 迭代: [194/200], Loss: 0.0044
# 迭代: [194/200], Loss: 0.0057
# 迭代: [194/200], Loss: 0.0083
# 迭代: [194/200], Loss: 0.0049
# 迭代: [194/200], Loss: 0.0035
# 迭代: [194/200], Loss: 0.0024
# 迭代: [194/200], Loss: 0.0052
# 迭代: [194/200], Loss: 0.0033
# 迭代: [194/200], Loss: 0.0050
# 迭代: [194/200], Loss: 0.0030
# 迭代: [194/200], Loss: 0.0020
# 迭代: [194/200], Loss: 0.0039
# 迭代: [194/200], Loss: 0.0071
# 迭代: [194/200], Loss: 0.0035
# 迭代: [194/200], Loss: 0.0024
# 迭代: [194/200], Loss: 0.0046
# 迭代: [194/200], Loss: 0.0031
# 迭代: [194/200], Loss: 0.0046
# 迭代: [194/200], Loss: 0.0024
# 迭代: [194/200], Loss: 0.0082
# 迭代: [194/200], Loss: 0.0032
# 迭代: [194/200], Loss: 0.0043
# 迭代: [194/200], Loss: 0.0088
# 迭代: [194/200], Loss: 0.0032
# 迭代: [194/200], Loss: 0.0032
# 迭代: [194/200], Loss: 0.0037
# 迭代: [194/200], Loss: 0.0047
# 迭代: [194/200], Loss: 0.0036
# 迭代: [194/200], Loss: 0.0050
# 迭代: [194/200], Loss: 0.0041
# 迭代: [194/200], Loss: 0.0049
# 迭代: [194/200], Loss: 0.0039
# 迭代: [194/200], Loss: 0.0029
# 迭代: [195/200], Loss: 0.0040
# 迭代: [195/200], Loss: 0.0050
# 迭代: [195/200], Loss: 0.0060
# 迭代: [195/200], Loss: 0.0156
# 迭代: [195/200], Loss: 0.0031
# 迭代: [195/200], Loss: 0.0061
# 迭代: [195/200], Loss: 0.0051
# 迭代: [195/200], Loss: 0.0041
# 迭代: [195/200], Loss: 0.0027
# 迭代: [195/200], Loss: 0.0039
# 迭代: [195/200], Loss: 0.0055
# 迭代: [195/200], Loss: 0.0021
# 迭代: [195/200], Loss: 0.0016
# 迭代: [195/200], Loss: 0.0054
# 迭代: [195/200], Loss: 0.0034
# 迭代: [195/200], Loss: 0.0027
# 迭代: [195/200], Loss: 0.0036
# 迭代: [195/200], Loss: 0.0049
# 迭代: [195/200], Loss: 0.0040
# 迭代: [195/200], Loss: 0.0022
# 迭代: [195/200], Loss: 0.0047
# 迭代: [195/200], Loss: 0.0081
# 迭代: [195/200], Loss: 0.0057
# 迭代: [195/200], Loss: 0.0033
# 迭代: [195/200], Loss: 0.0049
# 迭代: [195/200], Loss: 0.0034
# 迭代: [195/200], Loss: 0.0040
# 迭代: [195/200], Loss: 0.0044
# 迭代: [195/200], Loss: 0.0030
# 迭代: [195/200], Loss: 0.0062
# 迭代: [195/200], Loss: 0.0024
# 迭代: [195/200], Loss: 0.0033
# 迭代: [195/200], Loss: 0.0034
# 迭代: [195/200], Loss: 0.0060
# 迭代: [195/200], Loss: 0.0038
# 迭代: [195/200], Loss: 0.0034
# 迭代: [195/200], Loss: 0.0027
# 迭代: [195/200], Loss: 0.0033
# 迭代: [195/200], Loss: 0.0036
# 迭代: [195/200], Loss: 0.0045
# 迭代: [195/200], Loss: 0.0021
# 迭代: [195/200], Loss: 0.0051
# 迭代: [195/200], Loss: 0.0023
# 迭代: [195/200], Loss: 0.0109
# 迭代: [195/200], Loss: 0.0024
# 迭代: [195/200], Loss: 0.0043
# 迭代: [195/200], Loss: 0.0043
# 迭代: [195/200], Loss: 0.0041
# 迭代: [195/200], Loss: 0.0038
# 迭代: [195/200], Loss: 0.0023
# 迭代: [196/200], Loss: 0.0044
# 迭代: [196/200], Loss: 0.0047
# 迭代: [196/200], Loss: 0.0013
# 迭代: [196/200], Loss: 0.0028
# 迭代: [196/200], Loss: 0.0048
# 迭代: [196/200], Loss: 0.0031
# 迭代: [196/200], Loss: 0.0028
# 迭代: [196/200], Loss: 0.0039
# 迭代: [196/200], Loss: 0.0038
# 迭代: [196/200], Loss: 0.0044
# 迭代: [196/200], Loss: 0.0043
# 迭代: [196/200], Loss: 0.0032
# 迭代: [196/200], Loss: 0.0052
# 迭代: [196/200], Loss: 0.0043
# 迭代: [196/200], Loss: 0.0044
# 迭代: [196/200], Loss: 0.0032
# 迭代: [196/200], Loss: 0.0044
# 迭代: [196/200], Loss: 0.0018
# 迭代: [196/200], Loss: 0.0034
# 迭代: [196/200], Loss: 0.0030
# 迭代: [196/200], Loss: 0.0027
# 迭代: [196/200], Loss: 0.0050
# 迭代: [196/200], Loss: 0.0074
# 迭代: [196/200], Loss: 0.0058
# 迭代: [196/200], Loss: 0.0059
# 迭代: [196/200], Loss: 0.0040
# 迭代: [196/200], Loss: 0.0097
# 迭代: [196/200], Loss: 0.0144
# 迭代: [196/200], Loss: 0.0110
# 迭代: [196/200], Loss: 0.0082
# 迭代: [196/200], Loss: 0.0038
# 迭代: [196/200], Loss: 0.0053
# 迭代: [196/200], Loss: 0.0062
# 迭代: [196/200], Loss: 0.0043
# 迭代: [196/200], Loss: 0.0050
# 迭代: [196/200], Loss: 0.0050
# 迭代: [196/200], Loss: 0.0067
# 迭代: [196/200], Loss: 0.0046
# 迭代: [196/200], Loss: 0.0030
# 迭代: [196/200], Loss: 0.0044
# 迭代: [196/200], Loss: 0.0031
# 迭代: [196/200], Loss: 0.0117
# 迭代: [196/200], Loss: 0.0108
# 迭代: [196/200], Loss: 0.0070
# 迭代: [196/200], Loss: 0.0083
# 迭代: [196/200], Loss: 0.0037
# 迭代: [196/200], Loss: 0.0039
# 迭代: [196/200], Loss: 0.0037
# 迭代: [196/200], Loss: 0.0050
# 迭代: [196/200], Loss: 0.0067
# 迭代: [197/200], Loss: 0.0066
# 迭代: [197/200], Loss: 0.0133
# 迭代: [197/200], Loss: 0.0066
# 迭代: [197/200], Loss: 0.0030
# 迭代: [197/200], Loss: 0.0030
# 迭代: [197/200], Loss: 0.0024
# 迭代: [197/200], Loss: 0.0034
# 迭代: [197/200], Loss: 0.0044
# 迭代: [197/200], Loss: 0.0031
# 迭代: [197/200], Loss: 0.0023
# 迭代: [197/200], Loss: 0.0013
# 迭代: [197/200], Loss: 0.0034
# 迭代: [197/200], Loss: 0.0104
# 迭代: [197/200], Loss: 0.0094
# 迭代: [197/200], Loss: 0.0064
# 迭代: [197/200], Loss: 0.0049
# 迭代: [197/200], Loss: 0.0060
# 迭代: [197/200], Loss: 0.0181
# 迭代: [197/200], Loss: 0.0140
# 迭代: [197/200], Loss: 0.0064
# 迭代: [197/200], Loss: 0.0029
# 迭代: [197/200], Loss: 0.0075
# 迭代: [197/200], Loss: 0.0049
# 迭代: [197/200], Loss: 0.0051
# 迭代: [197/200], Loss: 0.0027
# 迭代: [197/200], Loss: 0.0049
# 迭代: [197/200], Loss: 0.0044
# 迭代: [197/200], Loss: 0.0030
# 迭代: [197/200], Loss: 0.0057
# 迭代: [197/200], Loss: 0.0050
# 迭代: [197/200], Loss: 0.0044
# 迭代: [197/200], Loss: 0.0070
# 迭代: [197/200], Loss: 0.0034
# 迭代: [197/200], Loss: 0.0037
# 迭代: [197/200], Loss: 0.0058
# 迭代: [197/200], Loss: 0.0047
# 迭代: [197/200], Loss: 0.0024
# 迭代: [197/200], Loss: 0.0021
# 迭代: [197/200], Loss: 0.0043
# 迭代: [197/200], Loss: 0.0047
# 迭代: [197/200], Loss: 0.0047
# 迭代: [197/200], Loss: 0.0061
# 迭代: [197/200], Loss: 0.0020
# 迭代: [197/200], Loss: 0.0032
# 迭代: [197/200], Loss: 0.0050
# 迭代: [197/200], Loss: 0.0022
# 迭代: [197/200], Loss: 0.0053
# 迭代: [197/200], Loss: 0.0028
# 迭代: [197/200], Loss: 0.0067
# 迭代: [197/200], Loss: 0.0027
# 迭代: [198/200], Loss: 0.0034
# 迭代: [198/200], Loss: 0.0046
# 迭代: [198/200], Loss: 0.0032
# 迭代: [198/200], Loss: 0.0056
# 迭代: [198/200], Loss: 0.0042
# 迭代: [198/200], Loss: 0.0044
# 迭代: [198/200], Loss: 0.0017
# 迭代: [198/200], Loss: 0.0021
# 迭代: [198/200], Loss: 0.0034
# 迭代: [198/200], Loss: 0.0079
# 迭代: [198/200], Loss: 0.0113
# 迭代: [198/200], Loss: 0.0135
# 迭代: [198/200], Loss: 0.0069
# 迭代: [198/200], Loss: 0.0051
# 迭代: [198/200], Loss: 0.0087
# 迭代: [198/200], Loss: 0.0070
# 迭代: [198/200], Loss: 0.0018
# 迭代: [198/200], Loss: 0.0049
# 迭代: [198/200], Loss: 0.0056
# 迭代: [198/200], Loss: 0.0021
# 迭代: [198/200], Loss: 0.0037
# 迭代: [198/200], Loss: 0.0026
# 迭代: [198/200], Loss: 0.0060
# 迭代: [198/200], Loss: 0.0064
# 迭代: [198/200], Loss: 0.0040
# 迭代: [198/200], Loss: 0.0041
# 迭代: [198/200], Loss: 0.0011
# 迭代: [198/200], Loss: 0.0047
# 迭代: [198/200], Loss: 0.0026
# 迭代: [198/200], Loss: 0.0087
# 迭代: [198/200], Loss: 0.0025
# 迭代: [198/200], Loss: 0.0045
# 迭代: [198/200], Loss: 0.0021
# 迭代: [198/200], Loss: 0.0063
# 迭代: [198/200], Loss: 0.0048
# 迭代: [198/200], Loss: 0.0071
# 迭代: [198/200], Loss: 0.0097
# 迭代: [198/200], Loss: 0.0017
# 迭代: [198/200], Loss: 0.0032
# 迭代: [198/200], Loss: 0.0029
# 迭代: [198/200], Loss: 0.0039
# 迭代: [198/200], Loss: 0.0039
# 迭代: [198/200], Loss: 0.0022
# 迭代: [198/200], Loss: 0.0055
# 迭代: [198/200], Loss: 0.0017
# 迭代: [198/200], Loss: 0.0046
# 迭代: [198/200], Loss: 0.0028
# 迭代: [198/200], Loss: 0.0097
# 迭代: [198/200], Loss: 0.0101
# 迭代: [198/200], Loss: 0.0035
# 迭代: [199/200], Loss: 0.0073
# 迭代: [199/200], Loss: 0.0046
# 迭代: [199/200], Loss: 0.0054
# 迭代: [199/200], Loss: 0.0056
# 迭代: [199/200], Loss: 0.0074
# 迭代: [199/200], Loss: 0.0028
# 迭代: [199/200], Loss: 0.0039
# 迭代: [199/200], Loss: 0.0085
# 迭代: [199/200], Loss: 0.0203
# 迭代: [199/200], Loss: 0.0108
# 迭代: [199/200], Loss: 0.0033
# 迭代: [199/200], Loss: 0.0025
# 迭代: [199/200], Loss: 0.0020
# 迭代: [199/200], Loss: 0.0060
# 迭代: [199/200], Loss: 0.0048
# 迭代: [199/200], Loss: 0.0035
# 迭代: [199/200], Loss: 0.0046
# 迭代: [199/200], Loss: 0.0041
# 迭代: [199/200], Loss: 0.0049
# 迭代: [199/200], Loss: 0.0062
# 迭代: [199/200], Loss: 0.0023
# 迭代: [199/200], Loss: 0.0049
# 迭代: [199/200], Loss: 0.0053
# 迭代: [199/200], Loss: 0.0036
# 迭代: [199/200], Loss: 0.0050
# 迭代: [199/200], Loss: 0.0026
# 迭代: [199/200], Loss: 0.0046
# 迭代: [199/200], Loss: 0.0064
# 迭代: [199/200], Loss: 0.0035
# 迭代: [199/200], Loss: 0.0022
# 迭代: [199/200], Loss: 0.0055
# 迭代: [199/200], Loss: 0.0062
# 迭代: [199/200], Loss: 0.0031
# 迭代: [199/200], Loss: 0.0025
# 迭代: [199/200], Loss: 0.0044
# 迭代: [199/200], Loss: 0.0040
# 迭代: [199/200], Loss: 0.0014
# 迭代: [199/200], Loss: 0.0033
# 迭代: [199/200], Loss: 0.0054
# 迭代: [199/200], Loss: 0.0052
# 迭代: [199/200], Loss: 0.0058
# 迭代: [199/200], Loss: 0.0056
# 迭代: [199/200], Loss: 0.0027
# 迭代: [199/200], Loss: 0.0026
# 迭代: [199/200], Loss: 0.0062
# 迭代: [199/200], Loss: 0.0063
# 迭代: [199/200], Loss: 0.0062
# 迭代: [199/200], Loss: 0.0036
# 迭代: [199/200], Loss: 0.0033
# 迭代: [199/200], Loss: 0.0052
# 迭代: [200/200], Loss: 0.0044
# 迭代: [200/200], Loss: 0.0038
# 迭代: [200/200], Loss: 0.0066
# 迭代: [200/200], Loss: 0.0099
# 迭代: [200/200], Loss: 0.0074
# 迭代: [200/200], Loss: 0.0057
# 迭代: [200/200], Loss: 0.0061
# 迭代: [200/200], Loss: 0.0053
# 迭代: [200/200], Loss: 0.0022
# 迭代: [200/200], Loss: 0.0045
# 迭代: [200/200], Loss: 0.0038
# 迭代: [200/200], Loss: 0.0045
# 迭代: [200/200], Loss: 0.0088
# 迭代: [200/200], Loss: 0.0033
# 迭代: [200/200], Loss: 0.0026
# 迭代: [200/200], Loss: 0.0032
# 迭代: [200/200], Loss: 0.0035
# 迭代: [200/200], Loss: 0.0060
# 迭代: [200/200], Loss: 0.0032
# 迭代: [200/200], Loss: 0.0036
# 迭代: [200/200], Loss: 0.0074
# 迭代: [200/200], Loss: 0.0062
# 迭代: [200/200], Loss: 0.0025
# 迭代: [200/200], Loss: 0.0066
# 迭代: [200/200], Loss: 0.0068
# 迭代: [200/200], Loss: 0.0085
# 迭代: [200/200], Loss: 0.0057
# 迭代: [200/200], Loss: 0.0053
# 迭代: [200/200], Loss: 0.0045
# 迭代: [200/200], Loss: 0.0005
# 迭代: [200/200], Loss: 0.0043
# 迭代: [200/200], Loss: 0.0023
# 迭代: [200/200], Loss: 0.0050
# 迭代: [200/200], Loss: 0.0049
# 迭代: [200/200], Loss: 0.0024
# 迭代: [200/200], Loss: 0.0041
# 迭代: [200/200], Loss: 0.0045
# 迭代: [200/200], Loss: 0.0021
# 迭代: [200/200], Loss: 0.0014
# 迭代: [200/200], Loss: 0.0043
# 迭代: [200/200], Loss: 0.0033
# 迭代: [200/200], Loss: 0.0049
# 迭代: [200/200], Loss: 0.0037
# 迭代: [200/200], Loss: 0.0038
# 迭代: [200/200], Loss: 0.0040
# 迭代: [200/200], Loss: 0.0046
# 迭代: [200/200], Loss: 0.0042
# 迭代: [200/200], Loss: 0.0025
# 迭代: [200/200], Loss: 0.0038
# 迭代: [200/200], Loss: 0.0020

# %% [markdown]
# #### 可视化loss

# %%
plt.plot(loss_arr)
plt.ylim(0,0.5)
# Out:
# (0.0, 0.5)

# %% [markdown]
# #### 测试代码
# 测试数据的dataSet

# %%
import numpy as np
class PredDataset(Dataset):
    def __init__(self):
        self.u = np.linspace(0, 1, 50)
    def __len__(self):
        return len(self.u)

    def __getitem__(self, idx):
        X = torch.tensor([self.u[idx]]).float()
        return X
pred_data = PredDataset()
pred_dataloader = DataLoader(pred_data, batch_size=len(pred_data), shuffle=False)

# %% [markdown]
# 测试：

# %%
def test(dataloader, model):
    model.eval()
    with torch.no_grad():
        for X in dataloader:
            X = X.to(device)
            pred = model(X)
            return pred
plot_y = test(pred_dataloader,model)

# %% [markdown]
# #### 结果可视化

# %%
plt.scatter(data['X'],data['Y'])
plot_y = plot_y.cpu()
plt.plot(pred_data.u,plot_y.reshape(-1),'r')
