# %% [markdown]
# ### 线性多分类
# 加载自定义数据：

# %%
import pandas as pd
import torch
import matplotlib.pyplot as plt
data = pd.read_csv("data/myData/data_6d.csv")
RDot = data[data['T']==1]
YDot = data[data['T']==2]
BDot = data[data['T']==3]
plt.scatter(BDot['X'],BDot['Y'])
plt.scatter(RDot['X'],RDot['Y'],c='r')
plt.scatter(YDot['X'],YDot['Y'],c='y')

# %%
import pandas as pd
from torch.utils.data import DataLoader, TensorDataset
from torch.utils.data import Dataset

class CustomDataset(Dataset):
    def __init__(self, file):
        self.data = pd.read_csv(file)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        X = torch.tensor(self.data.iloc[idx, 1:3]).float()
        Y = torch.tensor([self.data.iloc[idx, 3]]).float()
        return X, Y

# %%
training_data = CustomDataset("data/myData/data_5d.csv")
train_dataloader = DataLoader(training_data, batch_size=20, shuffle=True)

# %%
import torch
from torch import nn

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# #### 定义类

# %% [markdown]
# 单层神经元

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(2, 1)  # 输入维度为 2，输出维度为 1
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        y_pred = self.linear(x)
        y_pred = self.sigmoid(y_pred)
        return y_pred

# %% [markdown]
# #### 激活函数
# - Sigmoid函数：Sigmoid函数是一种常用的非线性激活函数，其数学形式为$f(x)=\frac{1}{1+e^{-x}}$。它的输出范围在0到1之间，可以用于二分类问题。
# - ReLU函数：ReLU函数是一种非线性激活函数，其数学形式为$f(x)=max(0,x)$。它在$x>0$时输出$x$，在$x\leq 0$时输出0。ReLU函数计算速度快，可以加速神经网络的训练过程。
# - LeakyReLU函数：LeakyReLU函数是一种改进的ReLU函数，其数学形式为$f(x)=max(ax,x)$，其中$a$是一个小于1的常数。当$x\leq 0$时，LeakyReLU函数会输出一个非零的值，避免了ReLU函数在$x<0$时出现的“神经元死亡”现象。
# - Tanh函数：Tanh函数是一种常用的非线性激活函数，其数学形式为$f(x)=\frac{e^{x}-e^{-x}}{e^{x}+e^{-x}}$。它的输出范围在-1到1之间，可以用于多分类问题。
# - Softmax函数：Softmax函数是一种常用的激活函数，主要用于多分类问题。其数学形式为$f(x_{i})=\frac{e^{x_{i}}}{\sum_{j=1}^{K}e^{x_{j}}}$，其中$x_{i}$表示第$i$个神经元的输出，$K$表示神经网络的输出层大小。Softmax函数会将所有输出映射到一个概率分布上，保证所有输出的和为1。
#
# #### 损失函数
# - nn.MSELoss：均方误差损失函数，用于回归任务。
# - nn.CrossEntropyLoss：交叉熵损失函数，用于多分类任务。
# - nn.BCELoss：二元交叉熵损失函数，用于二分类任务。
# - nn.NLLLoss：负对数似然损失函数，通常用于文本分类任务。
# - nn.KLDivLoss：KL 散度损失函数，用于计算两个概率分布之间的距离。
# - nn.SmoothL1Loss：平滑 L1 损失函数，与均方误差损失函数类似，但对离群值的惩罚更小，适用于回归任务。

# %%
#将模型添加到GPU
model = NeuralNetwork().to(device)
# 定义损失函数和优化器
# 二元交叉熵
criterion = torch.nn.BCELoss()
# 随机梯度下降
optimizer = torch.optim.SGD(model.parameters(), lr=0.4)
# model.parameters()用于返回模型中所有可训练的参数

# %% [markdown]
# 训练模型

# %%
num_epochs = 200
loss_arr = []
loss_recode_num = 100
loss_recode = 0
for epoch in range(num_epochs):
        #模型进入训练模式
        model.train()
        #遍历数据
        for batch, (inputs, targets) in enumerate(train_dataloader):
                #将数据添加到GPU
                inputs, targets = inputs.to(device), targets.to(device)
                # 前向传播
                pred = model(inputs)
                # loss计算
                loss = criterion(pred, targets)
                # 梯度清零
                optimizer.zero_grad()
                # 反向传播
                loss.backward()
                # 更新参数的值
                optimizer.step()
                # 输出数据
                print('迭代: [{}/{}], Loss: {:.4f}'.format(epoch+1, num_epochs, loss.item()))
        loss_arr.append(loss.item())
# Out:
# 迭代: [1/200], Loss: 0.7377
# 迭代: [1/200], Loss: 0.7506
# 迭代: [1/200], Loss: 0.6503
# 迭代: [1/200], Loss: 0.8509
# 迭代: [1/200], Loss: 0.7111
# 迭代: [1/200], Loss: 0.6906
# 迭代: [1/200], Loss: 0.6856
# 迭代: [1/200], Loss: 0.6877
# 迭代: [1/200], Loss: 0.6886
# 迭代: [1/200], Loss: 0.7188
# 迭代: [2/200], Loss: 0.6425
# 迭代: [2/200], Loss: 0.6410
# 迭代: [2/200], Loss: 0.6408
# 迭代: [2/200], Loss: 0.6336
# 迭代: [2/200], Loss: 0.6865
# 迭代: [2/200], Loss: 0.6441
# 迭代: [2/200], Loss: 0.6526
# 迭代: [2/200], Loss: 0.6144
# 迭代: [2/200], Loss: 0.6146
# 迭代: [2/200], Loss: 0.6038
# 迭代: [3/200], Loss: 0.5829
# 迭代: [3/200], Loss: 0.6093
# 迭代: [3/200], Loss: 0.6017
# 迭代: [3/200], Loss: 0.6089
# 迭代: [3/200], Loss: 0.5759
# 迭代: [3/200], Loss: 0.5908
# 迭代: [3/200], Loss: 0.5936
# 迭代: [3/200], Loss: 0.5572
# 迭代: [3/200], Loss: 0.5948
# 迭代: [3/200], Loss: 0.5707
# 迭代: [4/200], Loss: 0.5777
# 迭代: [4/200], Loss: 0.5733
# 迭代: [4/200], Loss: 0.5821
# 迭代: [4/200], Loss: 0.5470
# 迭代: [4/200], Loss: 0.5280
# 迭代: [4/200], Loss: 0.5276
# 迭代: [4/200], Loss: 0.5439
# 迭代: [4/200], Loss: 0.5522
# 迭代: [4/200], Loss: 0.5359
# 迭代: [4/200], Loss: 0.5408
# 迭代: [5/200], Loss: 0.5617
# 迭代: [5/200], Loss: 0.5006
# 迭代: [5/200], Loss: 0.4974
# 迭代: [5/200], Loss: 0.5492
# 迭代: [5/200], Loss: 0.5040
# 迭代: [5/200], Loss: 0.5209
# 迭代: [5/200], Loss: 0.4820
# 迭代: [5/200], Loss: 0.5051
# 迭代: [5/200], Loss: 0.4831
# 迭代: [5/200], Loss: 0.5701
# 迭代: [6/200], Loss: 0.5146
# 迭代: [6/200], Loss: 0.4920
# 迭代: [6/200], Loss: 0.5097
# 迭代: [6/200], Loss: 0.4629
# 迭代: [6/200], Loss: 0.4744
# 迭代: [6/200], Loss: 0.4823
# 迭代: [6/200], Loss: 0.4927
# 迭代: [6/200], Loss: 0.4904
# 迭代: [6/200], Loss: 0.4764
# 迭代: [6/200], Loss: 0.4848
# 迭代: [7/200], Loss: 0.4741
# 迭代: [7/200], Loss: 0.4652
# 迭代: [7/200], Loss: 0.4199
# 迭代: [7/200], Loss: 0.4832
# 迭代: [7/200], Loss: 0.4724
# 迭代: [7/200], Loss: 0.4566
# 迭代: [7/200], Loss: 0.4964
# 迭代: [7/200], Loss: 0.4623
# 迭代: [7/200], Loss: 0.4437
# 迭代: [7/200], Loss: 0.4716
# 迭代: [8/200], Loss: 0.4668
# 迭代: [8/200], Loss: 0.4372
# 迭代: [8/200], Loss: 0.4485
# 迭代: [8/200], Loss: 0.4217
# 迭代: [8/200], Loss: 0.3881
# 迭代: [8/200], Loss: 0.4638
# 迭代: [8/200], Loss: 0.4529
# 迭代: [8/200], Loss: 0.4594
# 迭代: [8/200], Loss: 0.4637
# 迭代: [8/200], Loss: 0.4175
# 迭代: [9/200], Loss: 0.4668
# 迭代: [9/200], Loss: 0.4320
# 迭代: [9/200], Loss: 0.3861
# 迭代: [9/200], Loss: 0.4348
# 迭代: [9/200], Loss: 0.4481
# 迭代: [9/200], Loss: 0.4032
# 迭代: [9/200], Loss: 0.4697
# 迭代: [9/200], Loss: 0.4446
# 迭代: [9/200], Loss: 0.3640
# 迭代: [9/200], Loss: 0.3677
# 迭代: [10/200], Loss: 0.4172
# 迭代: [10/200], Loss: 0.4346
# 迭代: [10/200], Loss: 0.3757
# 迭代: [10/200], Loss: 0.4084
# 迭代: [10/200], Loss: 0.3999
# 迭代: [10/200], Loss: 0.3933
# 迭代: [10/200], Loss: 0.4388
# 迭代: [10/200], Loss: 0.3771
# 迭代: [10/200], Loss: 0.3577
# 迭代: [10/200], Loss: 0.4530
# 迭代: [11/200], Loss: 0.3746
# 迭代: [11/200], Loss: 0.3821
# 迭代: [11/200], Loss: 0.3855
# 迭代: [11/200], Loss: 0.4049
# 迭代: [11/200], Loss: 0.4574
# 迭代: [11/200], Loss: 0.3462
# 迭代: [11/200], Loss: 0.3461
# 迭代: [11/200], Loss: 0.3524
# 迭代: [11/200], Loss: 0.4539
# 迭代: [11/200], Loss: 0.4056
# 迭代: [12/200], Loss: 0.4078
# 迭代: [12/200], Loss: 0.3964
# 迭代: [12/200], Loss: 0.3809
# 迭代: [12/200], Loss: 0.3714
# 迭代: [12/200], Loss: 0.3934
# 迭代: [12/200], Loss: 0.3650
# 迭代: [12/200], Loss: 0.3740
# 迭代: [12/200], Loss: 0.3449
# 迭代: [12/200], Loss: 0.3759
# 迭代: [12/200], Loss: 0.3563
# 迭代: [13/200], Loss: 0.3928
# 迭代: [13/200], Loss: 0.3702
# 迭代: [13/200], Loss: 0.4204
# 迭代: [13/200], Loss: 0.3487
# 迭代: [13/200], Loss: 0.3511
# 迭代: [13/200], Loss: 0.3762
# 迭代: [13/200], Loss: 0.3787
# 迭代: [13/200], Loss: 0.3381
# 迭代: [13/200], Loss: 0.3368
# 迭代: [13/200], Loss: 0.3322
# 迭代: [14/200], Loss: 0.3964
# 迭代: [14/200], Loss: 0.3189
# 迭代: [14/200], Loss: 0.3448
# 迭代: [14/200], Loss: 0.2856
# 迭代: [14/200], Loss: 0.2777
# 迭代: [14/200], Loss: 0.3946
# 迭代: [14/200], Loss: 0.3745
# 迭代: [14/200], Loss: 0.4127
# 迭代: [14/200], Loss: 0.3441
# 迭代: [14/200], Loss: 0.3827
# 迭代: [15/200], Loss: 0.3101
# 迭代: [15/200], Loss: 0.3367
# 迭代: [15/200], Loss: 0.3384
# 迭代: [15/200], Loss: 0.3679
# 迭代: [15/200], Loss: 0.3625
# 迭代: [15/200], Loss: 0.3344
# 迭代: [15/200], Loss: 0.3612
# 迭代: [15/200], Loss: 0.3158
# 迭代: [15/200], Loss: 0.3931
# 迭代: [15/200], Loss: 0.3273
# 迭代: [16/200], Loss: 0.3361
# 迭代: [16/200], Loss: 0.3322
# 迭代: [16/200], Loss: 0.3763
# 迭代: [16/200], Loss: 0.3571
# 迭代: [16/200], Loss: 0.3618
# 迭代: [16/200], Loss: 0.3089
# 迭代: [16/200], Loss: 0.2833
# 迭代: [16/200], Loss: 0.3250
# 迭代: [16/200], Loss: 0.3400
# 迭代: [16/200], Loss: 0.3230
# 迭代: [17/200], Loss: 0.2921
# 迭代: [17/200], Loss: 0.3788
# 迭代: [17/200], Loss: 0.2829
# 迭代: [17/200], Loss: 0.3038
# 迭代: [17/200], Loss: 0.3394
# 迭代: [17/200], Loss: 0.2600
# 迭代: [17/200], Loss: 0.3631
# 迭代: [17/200], Loss: 0.3484
# 迭代: [17/200], Loss: 0.3323
# 迭代: [17/200], Loss: 0.3477
# 迭代: [18/200], Loss: 0.3751
# 迭代: [18/200], Loss: 0.3583
# 迭代: [18/200], Loss: 0.3579
# 迭代: [18/200], Loss: 0.2636
# 迭代: [18/200], Loss: 0.3049
# 迭代: [18/200], Loss: 0.3425
# 迭代: [18/200], Loss: 0.2337
# 迭代: [18/200], Loss: 0.3570
# 迭代: [18/200], Loss: 0.2642
# 迭代: [18/200], Loss: 0.3219
# 迭代: [19/200], Loss: 0.3742
# 迭代: [19/200], Loss: 0.2723
# 迭代: [19/200], Loss: 0.3788
# 迭代: [19/200], Loss: 0.3194
# 迭代: [19/200], Loss: 0.2351
# 迭代: [19/200], Loss: 0.2891
# 迭代: [19/200], Loss: 0.2843
# 迭代: [19/200], Loss: 0.3597
# 迭代: [19/200], Loss: 0.2274
# 迭代: [19/200], Loss: 0.3691
# 迭代: [20/200], Loss: 0.2673
# 迭代: [20/200], Loss: 0.3078
# 迭代: [20/200], Loss: 0.3597
# 迭代: [20/200], Loss: 0.2705
# 迭代: [20/200], Loss: 0.2960
# 迭代: [20/200], Loss: 0.3409
# 迭代: [20/200], Loss: 0.3171
# 迭代: [20/200], Loss: 0.2711
# 迭代: [20/200], Loss: 0.2994
# 迭代: [20/200], Loss: 0.3061
# 迭代: [21/200], Loss: 0.2826
# 迭代: [21/200], Loss: 0.3021
# 迭代: [21/200], Loss: 0.2745
# 迭代: [21/200], Loss: 0.2701
# 迭代: [21/200], Loss: 0.3012
# 迭代: [21/200], Loss: 0.3463
# 迭代: [21/200], Loss: 0.2940
# 迭代: [21/200], Loss: 0.2619
# 迭代: [21/200], Loss: 0.3316
# 迭代: [21/200], Loss: 0.3087
# 迭代: [22/200], Loss: 0.1942
# 迭代: [22/200], Loss: 0.3390
# 迭代: [22/200], Loss: 0.3274
# 迭代: [22/200], Loss: 0.2396
# 迭代: [22/200], Loss: 0.2433
# 迭代: [22/200], Loss: 0.3478
# 迭代: [22/200], Loss: 0.2935
# 迭代: [22/200], Loss: 0.3849
# 迭代: [22/200], Loss: 0.2934
# 迭代: [22/200], Loss: 0.2466
# 迭代: [23/200], Loss: 0.2896
# 迭代: [23/200], Loss: 0.2988
# 迭代: [23/200], Loss: 0.2687
# 迭代: [23/200], Loss: 0.2827
# 迭代: [23/200], Loss: 0.2710
# 迭代: [23/200], Loss: 0.2688
# 迭代: [23/200], Loss: 0.2935
# 迭代: [23/200], Loss: 0.3081
# 迭代: [23/200], Loss: 0.3364
# 迭代: [23/200], Loss: 0.2320
# 迭代: [24/200], Loss: 0.3372
# 迭代: [24/200], Loss: 0.2777
# 迭代: [24/200], Loss: 0.3528
# 迭代: [24/200], Loss: 0.2673
# 迭代: [24/200], Loss: 0.2293
# 迭代: [24/200], Loss: 0.2608
# 迭代: [24/200], Loss: 0.2323
# 迭代: [24/200], Loss: 0.3793
# 迭代: [24/200], Loss: 0.2545
# 迭代: [24/200], Loss: 0.2056
# 迭代: [25/200], Loss: 0.2991
# 迭代: [25/200], Loss: 0.2784
# 迭代: [25/200], Loss: 0.3067
# 迭代: [25/200], Loss: 0.2470
# 迭代: [25/200], Loss: 0.2499
# 迭代: [25/200], Loss: 0.3203
# 迭代: [25/200], Loss: 0.2502
# 迭代: [25/200], Loss: 0.2765
# 迭代: [25/200], Loss: 0.2219
# 迭代: [25/200], Loss: 0.3008
# 迭代: [26/200], Loss: 0.2866
# 迭代: [26/200], Loss: 0.2699
# 迭代: [26/200], Loss: 0.2734
# 迭代: [26/200], Loss: 0.2935
# 迭代: [26/200], Loss: 0.2711
# 迭代: [26/200], Loss: 0.2299
# 迭代: [26/200], Loss: 0.2548
# 迭代: [26/200], Loss: 0.2459
# 迭代: [26/200], Loss: 0.3914
# 迭代: [26/200], Loss: 0.1895
# 迭代: [27/200], Loss: 0.3174
# 迭代: [27/200], Loss: 0.3124
# 迭代: [27/200], Loss: 0.2701
# 迭代: [27/200], Loss: 0.2949
# 迭代: [27/200], Loss: 0.2277
# 迭代: [27/200], Loss: 0.3337
# 迭代: [27/200], Loss: 0.2583
# 迭代: [27/200], Loss: 0.2229
# 迭代: [27/200], Loss: 0.2442
# 迭代: [27/200], Loss: 0.1761
# 迭代: [28/200], Loss: 0.2027
# 迭代: [28/200], Loss: 0.3333
# 迭代: [28/200], Loss: 0.2487
# 迭代: [28/200], Loss: 0.2106
# 迭代: [28/200], Loss: 0.2557
# 迭代: [28/200], Loss: 0.2842
# 迭代: [28/200], Loss: 0.3344
# 迭代: [28/200], Loss: 0.2290
# 迭代: [28/200], Loss: 0.3174
# 迭代: [28/200], Loss: 0.2091
# 迭代: [29/200], Loss: 0.2439
# 迭代: [29/200], Loss: 0.2652
# 迭代: [29/200], Loss: 0.2437
# 迭代: [29/200], Loss: 0.2055
# 迭代: [29/200], Loss: 0.2896
# 迭代: [29/200], Loss: 0.1904
# 迭代: [29/200], Loss: 0.2692
# 迭代: [29/200], Loss: 0.2456
# 迭代: [29/200], Loss: 0.3725
# 迭代: [29/200], Loss: 0.2607
# 迭代: [30/200], Loss: 0.2760
# 迭代: [30/200], Loss: 0.2731
# 迭代: [30/200], Loss: 0.2291
# 迭代: [30/200], Loss: 0.2532
# 迭代: [30/200], Loss: 0.1899
# 迭代: [30/200], Loss: 0.3439
# 迭代: [30/200], Loss: 0.1894
# 迭代: [30/200], Loss: 0.2860
# 迭代: [30/200], Loss: 0.2367
# 迭代: [30/200], Loss: 0.2690
# 迭代: [31/200], Loss: 0.2124
# 迭代: [31/200], Loss: 0.2735
# 迭代: [31/200], Loss: 0.2049
# 迭代: [31/200], Loss: 0.2351
# 迭代: [31/200], Loss: 0.2474
# 迭代: [31/200], Loss: 0.2743
# 迭代: [31/200], Loss: 0.2715
# 迭代: [31/200], Loss: 0.2499
# 迭代: [31/200], Loss: 0.2104
# 迭代: [31/200], Loss: 0.3254
# 迭代: [32/200], Loss: 0.2116
# 迭代: [32/200], Loss: 0.2492
# 迭代: [32/200], Loss: 0.3004
# 迭代: [32/200], Loss: 0.2541
# 迭代: [32/200], Loss: 0.2532
# 迭代: [32/200], Loss: 0.2416
# 迭代: [32/200], Loss: 0.1996
# 迭代: [32/200], Loss: 0.2438
# 迭代: [32/200], Loss: 0.2499
# 迭代: [32/200], Loss: 0.2634
# 迭代: [33/200], Loss: 0.2942
# 迭代: [33/200], Loss: 0.1951
# 迭代: [33/200], Loss: 0.2102
# 迭代: [33/200], Loss: 0.2696
# 迭代: [33/200], Loss: 0.2543
# 迭代: [33/200], Loss: 0.2189
# 迭代: [33/200], Loss: 0.3120
# 迭代: [33/200], Loss: 0.2228
# 迭代: [33/200], Loss: 0.2225
# 迭代: [33/200], Loss: 0.2427
# 迭代: [34/200], Loss: 0.2323
# 迭代: [34/200], Loss: 0.2802
# 迭代: [34/200], Loss: 0.2816
# 迭代: [34/200], Loss: 0.2632
# 迭代: [34/200], Loss: 0.2570
# 迭代: [34/200], Loss: 0.2361
# 迭代: [34/200], Loss: 0.2146
# 迭代: [34/200], Loss: 0.1990
# 迭代: [34/200], Loss: 0.2336
# 迭代: [34/200], Loss: 0.2070
# 迭代: [35/200], Loss: 0.2463
# 迭代: [35/200], Loss: 0.2484
# 迭代: [35/200], Loss: 0.3414
# 迭代: [35/200], Loss: 0.2405
# 迭代: [35/200], Loss: 0.2258
# 迭代: [35/200], Loss: 0.1991
# 迭代: [35/200], Loss: 0.1570
# 迭代: [35/200], Loss: 0.2384
# 迭代: [35/200], Loss: 0.2119
# 迭代: [35/200], Loss: 0.2661
# 迭代: [36/200], Loss: 0.2525
# 迭代: [36/200], Loss: 0.2772
# 迭代: [36/200], Loss: 0.2765
# 迭代: [36/200], Loss: 0.1766
# 迭代: [36/200], Loss: 0.2205
# 迭代: [36/200], Loss: 0.2088
# 迭代: [36/200], Loss: 0.2634
# 迭代: [36/200], Loss: 0.2308
# 迭代: [36/200], Loss: 0.2245
# 迭代: [36/200], Loss: 0.2163
# 迭代: [37/200], Loss: 0.1733
# 迭代: [37/200], Loss: 0.2571
# 迭代: [37/200], Loss: 0.2051
# 迭代: [37/200], Loss: 0.2352
# 迭代: [37/200], Loss: 0.1771
# 迭代: [37/200], Loss: 0.2555
# 迭代: [37/200], Loss: 0.2933
# 迭代: [37/200], Loss: 0.3193
# 迭代: [37/200], Loss: 0.1866
# 迭代: [37/200], Loss: 0.2202
# 迭代: [38/200], Loss: 0.1972
# 迭代: [38/200], Loss: 0.3127
# 迭代: [38/200], Loss: 0.2270
# 迭代: [38/200], Loss: 0.1914
# 迭代: [38/200], Loss: 0.1972
# 迭代: [38/200], Loss: 0.2545
# 迭代: [38/200], Loss: 0.2378
# 迭代: [38/200], Loss: 0.2378
# 迭代: [38/200], Loss: 0.2190
# 迭代: [38/200], Loss: 0.2136
# 迭代: [39/200], Loss: 0.2490
# 迭代: [39/200], Loss: 0.1701
# 迭代: [39/200], Loss: 0.1921
# 迭代: [39/200], Loss: 0.2354
# 迭代: [39/200], Loss: 0.1657
# 迭代: [39/200], Loss: 0.2237
# 迭代: [39/200], Loss: 0.2800
# 迭代: [39/200], Loss: 0.2017
# 迭代: [39/200], Loss: 0.2398
# 迭代: [39/200], Loss: 0.3091
# 迭代: [40/200], Loss: 0.2056
# 迭代: [40/200], Loss: 0.2475
# 迭代: [40/200], Loss: 0.2026
# 迭代: [40/200], Loss: 0.2507
# 迭代: [40/200], Loss: 0.1548
# 迭代: [40/200], Loss: 0.2285
# 迭代: [40/200], Loss: 0.1937
# 迭代: [40/200], Loss: 0.2806
# 迭代: [40/200], Loss: 0.2926
# 迭代: [40/200], Loss: 0.1832
# 迭代: [41/200], Loss: 0.2686
# 迭代: [41/200], Loss: 0.2858
# 迭代: [41/200], Loss: 0.1840
# 迭代: [41/200], Loss: 0.2400
# 迭代: [41/200], Loss: 0.2000
# 迭代: [41/200], Loss: 0.1716
# 迭代: [41/200], Loss: 0.1995
# 迭代: [41/200], Loss: 0.1923
# 迭代: [41/200], Loss: 0.2158
# 迭代: [41/200], Loss: 0.2583
# 迭代: [42/200], Loss: 0.2529
# 迭代: [42/200], Loss: 0.2536
# 迭代: [42/200], Loss: 0.2701
# 迭代: [42/200], Loss: 0.2263
# 迭代: [42/200], Loss: 0.2160
# 迭代: [42/200], Loss: 0.1580
# 迭代: [42/200], Loss: 0.2078
# 迭代: [42/200], Loss: 0.1759
# 迭代: [42/200], Loss: 0.2348
# 迭代: [42/200], Loss: 0.2006
# 迭代: [43/200], Loss: 0.2301
# 迭代: [43/200], Loss: 0.2967
# 迭代: [43/200], Loss: 0.2118
# 迭代: [43/200], Loss: 0.1872
# 迭代: [43/200], Loss: 0.1440
# 迭代: [43/200], Loss: 0.2221
# 迭代: [43/200], Loss: 0.2421
# 迭代: [43/200], Loss: 0.2655
# 迭代: [43/200], Loss: 0.1689
# 迭代: [43/200], Loss: 0.2013
# 迭代: [44/200], Loss: 0.1170
# 迭代: [44/200], Loss: 0.2921
# 迭代: [44/200], Loss: 0.1915
# 迭代: [44/200], Loss: 0.2676
# 迭代: [44/200], Loss: 0.2286
# 迭代: [44/200], Loss: 0.1386
# 迭代: [44/200], Loss: 0.2784
# 迭代: [44/200], Loss: 0.2016
# 迭代: [44/200], Loss: 0.2096
# 迭代: [44/200], Loss: 0.2235
# 迭代: [45/200], Loss: 0.2360
# 迭代: [45/200], Loss: 0.1792
# 迭代: [45/200], Loss: 0.2674
# 迭代: [45/200], Loss: 0.1660
# 迭代: [45/200], Loss: 0.2531
# 迭代: [45/200], Loss: 0.2195
# 迭代: [45/200], Loss: 0.2455
# 迭代: [45/200], Loss: 0.1642
# 迭代: [45/200], Loss: 0.2026
# 迭代: [45/200], Loss: 0.2001
# 迭代: [46/200], Loss: 0.1975
# 迭代: [46/200], Loss: 0.2438
# 迭代: [46/200], Loss: 0.1514
# 迭代: [46/200], Loss: 0.2959
# 迭代: [46/200], Loss: 0.2026
# 迭代: [46/200], Loss: 0.2108
# 迭代: [46/200], Loss: 0.2296
# 迭代: [46/200], Loss: 0.1916
# 迭代: [46/200], Loss: 0.2009
# 迭代: [46/200], Loss: 0.1953
# 迭代: [47/200], Loss: 0.1864
# 迭代: [47/200], Loss: 0.2447
# 迭代: [47/200], Loss: 0.1933
# 迭代: [47/200], Loss: 0.2123
# 迭代: [47/200], Loss: 0.2568
# 迭代: [47/200], Loss: 0.1584
# 迭代: [47/200], Loss: 0.2547
# 迭代: [47/200], Loss: 0.1702
# 迭代: [47/200], Loss: 0.2140
# 迭代: [47/200], Loss: 0.2006
# 迭代: [48/200], Loss: 0.2256
# 迭代: [48/200], Loss: 0.1588
# 迭代: [48/200], Loss: 0.1831
# 迭代: [48/200], Loss: 0.2056
# 迭代: [48/200], Loss: 0.2247
# 迭代: [48/200], Loss: 0.2989
# 迭代: [48/200], Loss: 0.1988
# 迭代: [48/200], Loss: 0.1941
# 迭代: [48/200], Loss: 0.1966
# 迭代: [48/200], Loss: 0.1846
# 迭代: [49/200], Loss: 0.2252
# 迭代: [49/200], Loss: 0.1580
# 迭代: [49/200], Loss: 0.2452
# 迭代: [49/200], Loss: 0.2340
# 迭代: [49/200], Loss: 0.1660
# 迭代: [49/200], Loss: 0.2050
# 迭代: [49/200], Loss: 0.2063
# 迭代: [49/200], Loss: 0.1537
# 迭代: [49/200], Loss: 0.2192
# 迭代: [49/200], Loss: 0.2521
# 迭代: [50/200], Loss: 0.2265
# 迭代: [50/200], Loss: 0.2031
# 迭代: [50/200], Loss: 0.1468
# 迭代: [50/200], Loss: 0.2583
# 迭代: [50/200], Loss: 0.2054
# 迭代: [50/200], Loss: 0.2449
# 迭代: [50/200], Loss: 0.2619
# 迭代: [50/200], Loss: 0.1395
# 迭代: [50/200], Loss: 0.2095
# 迭代: [50/200], Loss: 0.1387
# 迭代: [51/200], Loss: 0.1626
# 迭代: [51/200], Loss: 0.1994
# 迭代: [51/200], Loss: 0.1615
# 迭代: [51/200], Loss: 0.2774
# 迭代: [51/200], Loss: 0.2104
# 迭代: [51/200], Loss: 0.2158
# 迭代: [51/200], Loss: 0.1672
# 迭代: [51/200], Loss: 0.1891
# 迭代: [51/200], Loss: 0.2335
# 迭代: [51/200], Loss: 0.2011
# 迭代: [52/200], Loss: 0.2831
# 迭代: [52/200], Loss: 0.2201
# 迭代: [52/200], Loss: 0.1969
# 迭代: [52/200], Loss: 0.1521
# 迭代: [52/200], Loss: 0.2124
# 迭代: [52/200], Loss: 0.1689
# 迭代: [52/200], Loss: 0.1295
# 迭代: [52/200], Loss: 0.2198
# 迭代: [52/200], Loss: 0.1118
# 迭代: [52/200], Loss: 0.3159
# 迭代: [53/200], Loss: 0.2258
# 迭代: [53/200], Loss: 0.1262
# 迭代: [53/200], Loss: 0.2156
# 迭代: [53/200], Loss: 0.1624
# 迭代: [53/200], Loss: 0.2779
# 迭代: [53/200], Loss: 0.2002
# 迭代: [53/200], Loss: 0.1623
# 迭代: [53/200], Loss: 0.2263
# 迭代: [53/200], Loss: 0.1924
# 迭代: [53/200], Loss: 0.1997
# 迭代: [54/200], Loss: 0.1846
# 迭代: [54/200], Loss: 0.2247
# 迭代: [54/200], Loss: 0.1743
# 迭代: [54/200], Loss: 0.2135
# 迭代: [54/200], Loss: 0.2119
# 迭代: [54/200], Loss: 0.2177
# 迭代: [54/200], Loss: 0.1126
# 迭代: [54/200], Loss: 0.2097
# 迭代: [54/200], Loss: 0.1818
# 迭代: [54/200], Loss: 0.2377
# 迭代: [55/200], Loss: 0.1950
# 迭代: [55/200], Loss: 0.1485
# 迭代: [55/200], Loss: 0.2418
# 迭代: [55/200], Loss: 0.2107
# 迭代: [55/200], Loss: 0.1641
# 迭代: [55/200], Loss: 0.2017
# 迭代: [55/200], Loss: 0.1754
# 迭代: [55/200], Loss: 0.1327
# 迭代: [55/200], Loss: 0.2240
# 迭代: [55/200], Loss: 0.2694
# 迭代: [56/200], Loss: 0.2356
# 迭代: [56/200], Loss: 0.1676
# 迭代: [56/200], Loss: 0.1549
# 迭代: [56/200], Loss: 0.2748
# 迭代: [56/200], Loss: 0.1869
# 迭代: [56/200], Loss: 0.1441
# 迭代: [56/200], Loss: 0.1763
# 迭代: [56/200], Loss: 0.1652
# 迭代: [56/200], Loss: 0.1917
# 迭代: [56/200], Loss: 0.2486
# 迭代: [57/200], Loss: 0.1564
# 迭代: [57/200], Loss: 0.1942
# 迭代: [57/200], Loss: 0.2330
# 迭代: [57/200], Loss: 0.1871
# 迭代: [57/200], Loss: 0.1344
# 迭代: [57/200], Loss: 0.2042
# 迭代: [57/200], Loss: 0.2043
# 迭代: [57/200], Loss: 0.2011
# 迭代: [57/200], Loss: 0.2316
# 迭代: [57/200], Loss: 0.1839
# 迭代: [58/200], Loss: 0.1953
# 迭代: [58/200], Loss: 0.1543
# 迭代: [58/200], Loss: 0.1744
# 迭代: [58/200], Loss: 0.2549
# 迭代: [58/200], Loss: 0.1465
# 迭代: [58/200], Loss: 0.2112
# 迭代: [58/200], Loss: 0.2570
# 迭代: [58/200], Loss: 0.1704
# 迭代: [58/200], Loss: 0.1644
# 迭代: [58/200], Loss: 0.1832
# 迭代: [59/200], Loss: 0.2552
# 迭代: [59/200], Loss: 0.1903
# 迭代: [59/200], Loss: 0.1281
# 迭代: [59/200], Loss: 0.2115
# 迭代: [59/200], Loss: 0.1234
# 迭代: [59/200], Loss: 0.1815
# 迭代: [59/200], Loss: 0.1605
# 迭代: [59/200], Loss: 0.1929
# 迭代: [59/200], Loss: 0.2257
# 迭代: [59/200], Loss: 0.2316
# 迭代: [60/200], Loss: 0.1727
# 迭代: [60/200], Loss: 0.1901
# 迭代: [60/200], Loss: 0.1623
# 迭代: [60/200], Loss: 0.1437
# 迭代: [60/200], Loss: 0.2215
# 迭代: [60/200], Loss: 0.2259
# 迭代: [60/200], Loss: 0.1705
# 迭代: [60/200], Loss: 0.2096
# 迭代: [60/200], Loss: 0.1715
# 迭代: [60/200], Loss: 0.2204
# 迭代: [61/200], Loss: 0.2507
# 迭代: [61/200], Loss: 0.2483
# 迭代: [61/200], Loss: 0.1622
# 迭代: [61/200], Loss: 0.1786
# 迭代: [61/200], Loss: 0.1819
# 迭代: [61/200], Loss: 0.2088
# 迭代: [61/200], Loss: 0.1674
# 迭代: [61/200], Loss: 0.2438
# 迭代: [61/200], Loss: 0.1203
# 迭代: [61/200], Loss: 0.1088
# 迭代: [62/200], Loss: 0.2452
# 迭代: [62/200], Loss: 0.1794
# 迭代: [62/200], Loss: 0.1451
# 迭代: [62/200], Loss: 0.1354
# 迭代: [62/200], Loss: 0.2131
# 迭代: [62/200], Loss: 0.1713
# 迭代: [62/200], Loss: 0.1270
# 迭代: [62/200], Loss: 0.3303
# 迭代: [62/200], Loss: 0.1422
# 迭代: [62/200], Loss: 0.1769
# 迭代: [63/200], Loss: 0.1976
# 迭代: [63/200], Loss: 0.1678
# 迭代: [63/200], Loss: 0.1470
# 迭代: [63/200], Loss: 0.1379
# 迭代: [63/200], Loss: 0.1510
# 迭代: [63/200], Loss: 0.2184
# 迭代: [63/200], Loss: 0.1906
# 迭代: [63/200], Loss: 0.1771
# 迭代: [63/200], Loss: 0.2980
# 迭代: [63/200], Loss: 0.1638
# 迭代: [64/200], Loss: 0.1516
# 迭代: [64/200], Loss: 0.1891
# 迭代: [64/200], Loss: 0.1750
# 迭代: [64/200], Loss: 0.0998
# 迭代: [64/200], Loss: 0.1663
# 迭代: [64/200], Loss: 0.1679
# 迭代: [64/200], Loss: 0.2283
# 迭代: [64/200], Loss: 0.1830
# 迭代: [64/200], Loss: 0.2389
# 迭代: [64/200], Loss: 0.2328
# 迭代: [65/200], Loss: 0.1755
# 迭代: [65/200], Loss: 0.2459
# 迭代: [65/200], Loss: 0.1580
# 迭代: [65/200], Loss: 0.1552
# 迭代: [65/200], Loss: 0.1373
# 迭代: [65/200], Loss: 0.1577
# 迭代: [65/200], Loss: 0.0938
# 迭代: [65/200], Loss: 0.2261
# 迭代: [65/200], Loss: 0.2616
# 迭代: [65/200], Loss: 0.2140
# 迭代: [66/200], Loss: 0.1885
# 迭代: [66/200], Loss: 0.2274
# 迭代: [66/200], Loss: 0.2286
# 迭代: [66/200], Loss: 0.2224
# 迭代: [66/200], Loss: 0.1658
# 迭代: [66/200], Loss: 0.2308
# 迭代: [66/200], Loss: 0.1366
# 迭代: [66/200], Loss: 0.1728
# 迭代: [66/200], Loss: 0.1210
# 迭代: [66/200], Loss: 0.1176
# 迭代: [67/200], Loss: 0.1539
# 迭代: [67/200], Loss: 0.1830
# 迭代: [67/200], Loss: 0.2189
# 迭代: [67/200], Loss: 0.1130
# 迭代: [67/200], Loss: 0.2403
# 迭代: [67/200], Loss: 0.2160
# 迭代: [67/200], Loss: 0.1254
# 迭代: [67/200], Loss: 0.1909
# 迭代: [67/200], Loss: 0.1909
# 迭代: [67/200], Loss: 0.1660
# 迭代: [68/200], Loss: 0.1654
# 迭代: [68/200], Loss: 0.2084
# 迭代: [68/200], Loss: 0.1259
# 迭代: [68/200], Loss: 0.1589
# 迭代: [68/200], Loss: 0.1751
# 迭代: [68/200], Loss: 0.2061
# 迭代: [68/200], Loss: 0.2504
# 迭代: [68/200], Loss: 0.2003
# 迭代: [68/200], Loss: 0.1680
# 迭代: [68/200], Loss: 0.1320
# 迭代: [69/200], Loss: 0.1146
# 迭代: [69/200], Loss: 0.2373
# 迭代: [69/200], Loss: 0.0880
# 迭代: [69/200], Loss: 0.2182
# 迭代: [69/200], Loss: 0.1438
# 迭代: [69/200], Loss: 0.1376
# 迭代: [69/200], Loss: 0.1660
# 迭代: [69/200], Loss: 0.2635
# 迭代: [69/200], Loss: 0.2433
# 迭代: [69/200], Loss: 0.1684
# 迭代: [70/200], Loss: 0.1513
# 迭代: [70/200], Loss: 0.1573
# 迭代: [70/200], Loss: 0.1923
# 迭代: [70/200], Loss: 0.2130
# 迭代: [70/200], Loss: 0.1586
# 迭代: [70/200], Loss: 0.1434
# 迭代: [70/200], Loss: 0.1687
# 迭代: [70/200], Loss: 0.1458
# 迭代: [70/200], Loss: 0.2038
# 迭代: [70/200], Loss: 0.2364
# 迭代: [71/200], Loss: 0.1635
# 迭代: [71/200], Loss: 0.1994
# 迭代: [71/200], Loss: 0.1380
# 迭代: [71/200], Loss: 0.1376
# 迭代: [71/200], Loss: 0.2102
# 迭代: [71/200], Loss: 0.1913
# 迭代: [71/200], Loss: 0.1221
# 迭代: [71/200], Loss: 0.2701
# 迭代: [71/200], Loss: 0.1709
# 迭代: [71/200], Loss: 0.1536
# 迭代: [72/200], Loss: 0.1582
# 迭代: [72/200], Loss: 0.1602
# 迭代: [72/200], Loss: 0.2214
# 迭代: [72/200], Loss: 0.0834
# 迭代: [72/200], Loss: 0.1647
# 迭代: [72/200], Loss: 0.2267
# 迭代: [72/200], Loss: 0.1779
# 迭代: [72/200], Loss: 0.1797
# 迭代: [72/200], Loss: 0.1445
# 迭代: [72/200], Loss: 0.2313
# 迭代: [73/200], Loss: 0.1465
# 迭代: [73/200], Loss: 0.1591
# 迭代: [73/200], Loss: 0.1856
# 迭代: [73/200], Loss: 0.1292
# 迭代: [73/200], Loss: 0.1081
# 迭代: [73/200], Loss: 0.1706
# 迭代: [73/200], Loss: 0.1421
# 迭代: [73/200], Loss: 0.2829
# 迭代: [73/200], Loss: 0.1627
# 迭代: [73/200], Loss: 0.2476
# 迭代: [74/200], Loss: 0.2280
# 迭代: [74/200], Loss: 0.1391
# 迭代: [74/200], Loss: 0.1242
# 迭代: [74/200], Loss: 0.1564
# 迭代: [74/200], Loss: 0.1632
# 迭代: [74/200], Loss: 0.1638
# 迭代: [74/200], Loss: 0.1899
# 迭代: [74/200], Loss: 0.2189
# 迭代: [74/200], Loss: 0.1205
# 迭代: [74/200], Loss: 0.2236
# 迭代: [75/200], Loss: 0.1508
# 迭代: [75/200], Loss: 0.1948
# 迭代: [75/200], Loss: 0.1844
# 迭代: [75/200], Loss: 0.1377
# 迭代: [75/200], Loss: 0.1484
# 迭代: [75/200], Loss: 0.1527
# 迭代: [75/200], Loss: 0.1963
# 迭代: [75/200], Loss: 0.2220
# 迭代: [75/200], Loss: 0.1242
# 迭代: [75/200], Loss: 0.2050
# 迭代: [76/200], Loss: 0.1244
# 迭代: [76/200], Loss: 0.1573
# 迭代: [76/200], Loss: 0.2231
# 迭代: [76/200], Loss: 0.1643
# 迭代: [76/200], Loss: 0.1801
# 迭代: [76/200], Loss: 0.1087
# 迭代: [76/200], Loss: 0.1432
# 迭代: [76/200], Loss: 0.2317
# 迭代: [76/200], Loss: 0.2139
# 迭代: [76/200], Loss: 0.1622
# 迭代: [77/200], Loss: 0.1877
# 迭代: [77/200], Loss: 0.1461
# 迭代: [77/200], Loss: 0.1617
# 迭代: [77/200], Loss: 0.1706
# 迭代: [77/200], Loss: 0.1860
# 迭代: [77/200], Loss: 0.1662
# 迭代: [77/200], Loss: 0.1699
# 迭代: [77/200], Loss: 0.2073
# 迭代: [77/200], Loss: 0.1604
# 迭代: [77/200], Loss: 0.1441
# 迭代: [78/200], Loss: 0.1814
# 迭代: [78/200], Loss: 0.1778
# 迭代: [78/200], Loss: 0.1573
# 迭代: [78/200], Loss: 0.1759
# 迭代: [78/200], Loss: 0.1049
# 迭代: [78/200], Loss: 0.1520
# 迭代: [78/200], Loss: 0.1536
# 迭代: [78/200], Loss: 0.2000
# 迭代: [78/200], Loss: 0.1929
# 迭代: [78/200], Loss: 0.1953
# 迭代: [79/200], Loss: 0.1851
# 迭代: [79/200], Loss: 0.1534
# 迭代: [79/200], Loss: 0.1475
# 迭代: [79/200], Loss: 0.1713
# 迭代: [79/200], Loss: 0.1482
# 迭代: [79/200], Loss: 0.2270
# 迭代: [79/200], Loss: 0.1993
# 迭代: [79/200], Loss: 0.1324
# 迭代: [79/200], Loss: 0.1531
# 迭代: [79/200], Loss: 0.1645
# 迭代: [80/200], Loss: 0.1362
# 迭代: [80/200], Loss: 0.1903
# 迭代: [80/200], Loss: 0.2058
# 迭代: [80/200], Loss: 0.2124
# 迭代: [80/200], Loss: 0.1083
# 迭代: [80/200], Loss: 0.1824
# 迭代: [80/200], Loss: 0.1925
# 迭代: [80/200], Loss: 0.1462
# 迭代: [80/200], Loss: 0.1505
# 迭代: [80/200], Loss: 0.1489
# 迭代: [81/200], Loss: 0.1979
# 迭代: [81/200], Loss: 0.1780
# 迭代: [81/200], Loss: 0.1628
# 迭代: [81/200], Loss: 0.1453
# 迭代: [81/200], Loss: 0.1611
# 迭代: [81/200], Loss: 0.1150
# 迭代: [81/200], Loss: 0.2139
# 迭代: [81/200], Loss: 0.1604
# 迭代: [81/200], Loss: 0.1062
# 迭代: [81/200], Loss: 0.2244
# 迭代: [82/200], Loss: 0.1296
# 迭代: [82/200], Loss: 0.1917
# 迭代: [82/200], Loss: 0.1482
# 迭代: [82/200], Loss: 0.1778
# 迭代: [82/200], Loss: 0.1291
# 迭代: [82/200], Loss: 0.2382
# 迭代: [82/200], Loss: 0.2079
# 迭代: [82/200], Loss: 0.1268
# 迭代: [82/200], Loss: 0.1323
# 迭代: [82/200], Loss: 0.1721
# 迭代: [83/200], Loss: 0.1026
# 迭代: [83/200], Loss: 0.1814
# 迭代: [83/200], Loss: 0.1666
# 迭代: [83/200], Loss: 0.1819
# 迭代: [83/200], Loss: 0.1442
# 迭代: [83/200], Loss: 0.1648
# 迭代: [83/200], Loss: 0.2340
# 迭代: [83/200], Loss: 0.1924
# 迭代: [83/200], Loss: 0.1745
# 迭代: [83/200], Loss: 0.1055
# 迭代: [84/200], Loss: 0.1458
# 迭代: [84/200], Loss: 0.2033
# 迭代: [84/200], Loss: 0.1179
# 迭代: [84/200], Loss: 0.1407
# 迭代: [84/200], Loss: 0.1345
# 迭代: [84/200], Loss: 0.2007
# 迭代: [84/200], Loss: 0.2048
# 迭代: [84/200], Loss: 0.1244
# 迭代: [84/200], Loss: 0.1798
# 迭代: [84/200], Loss: 0.1877
# 迭代: [85/200], Loss: 0.1899
# 迭代: [85/200], Loss: 0.1795
# 迭代: [85/200], Loss: 0.1533
# 迭代: [85/200], Loss: 0.1865
# 迭代: [85/200], Loss: 0.1270
# 迭代: [85/200], Loss: 0.1724
# 迭代: [85/200], Loss: 0.2014
# 迭代: [85/200], Loss: 0.1757
# 迭代: [85/200], Loss: 0.1098
# 迭代: [85/200], Loss: 0.1351
# 迭代: [86/200], Loss: 0.1768
# 迭代: [86/200], Loss: 0.1301
# 迭代: [86/200], Loss: 0.1818
# 迭代: [86/200], Loss: 0.1903
# 迭代: [86/200], Loss: 0.1454
# 迭代: [86/200], Loss: 0.1850
# 迭代: [86/200], Loss: 0.1444
# 迭代: [86/200], Loss: 0.1505
# 迭代: [86/200], Loss: 0.1424
# 迭代: [86/200], Loss: 0.1778
# 迭代: [87/200], Loss: 0.1708
# 迭代: [87/200], Loss: 0.1755
# 迭代: [87/200], Loss: 0.0870
# 迭代: [87/200], Loss: 0.1579
# 迭代: [87/200], Loss: 0.1621
# 迭代: [87/200], Loss: 0.2456
# 迭代: [87/200], Loss: 0.1634
# 迭代: [87/200], Loss: 0.1457
# 迭代: [87/200], Loss: 0.1819
# 迭代: [87/200], Loss: 0.1287
# 迭代: [88/200], Loss: 0.1706
# 迭代: [88/200], Loss: 0.2043
# 迭代: [88/200], Loss: 0.1434
# 迭代: [88/200], Loss: 0.1774
# 迭代: [88/200], Loss: 0.1428
# 迭代: [88/200], Loss: 0.1975
# 迭代: [88/200], Loss: 0.1131
# 迭代: [88/200], Loss: 0.1397
# 迭代: [88/200], Loss: 0.1355
# 迭代: [88/200], Loss: 0.1851
# 迭代: [89/200], Loss: 0.1473
# 迭代: [89/200], Loss: 0.2021
# 迭代: [89/200], Loss: 0.1227
# 迭代: [89/200], Loss: 0.1074
# 迭代: [89/200], Loss: 0.2731
# 迭代: [89/200], Loss: 0.1126
# 迭代: [89/200], Loss: 0.1648
# 迭代: [89/200], Loss: 0.0845
# 迭代: [89/200], Loss: 0.2639
# 迭代: [89/200], Loss: 0.1226
# 迭代: [90/200], Loss: 0.2002
# 迭代: [90/200], Loss: 0.1684
# 迭代: [90/200], Loss: 0.1518
# 迭代: [90/200], Loss: 0.1235
# 迭代: [90/200], Loss: 0.2050
# 迭代: [90/200], Loss: 0.1749
# 迭代: [90/200], Loss: 0.1003
# 迭代: [90/200], Loss: 0.1364
# 迭代: [90/200], Loss: 0.2128
# 迭代: [90/200], Loss: 0.1209
# 迭代: [91/200], Loss: 0.1385
# 迭代: [91/200], Loss: 0.1461
# 迭代: [91/200], Loss: 0.1660
# 迭代: [91/200], Loss: 0.1488
# 迭代: [91/200], Loss: 0.1729
# 迭代: [91/200], Loss: 0.2306
# 迭代: [91/200], Loss: 0.1800
# 迭代: [91/200], Loss: 0.1348
# 迭代: [91/200], Loss: 0.0937
# 迭代: [91/200], Loss: 0.1749
# 迭代: [92/200], Loss: 0.1780
# 迭代: [92/200], Loss: 0.2456
# 迭代: [92/200], Loss: 0.1229
# 迭代: [92/200], Loss: 0.1429
# 迭代: [92/200], Loss: 0.1504
# 迭代: [92/200], Loss: 0.1259
# 迭代: [92/200], Loss: 0.2058
# 迭代: [92/200], Loss: 0.1059
# 迭代: [92/200], Loss: 0.1696
# 迭代: [92/200], Loss: 0.1359
# 迭代: [93/200], Loss: 0.1890
# 迭代: [93/200], Loss: 0.1109
# 迭代: [93/200], Loss: 0.1818
# 迭代: [93/200], Loss: 0.2195
# 迭代: [93/200], Loss: 0.1541
# 迭代: [93/200], Loss: 0.1775
# 迭代: [93/200], Loss: 0.1364
# 迭代: [93/200], Loss: 0.1372
# 迭代: [93/200], Loss: 0.1418
# 迭代: [93/200], Loss: 0.1238
# 迭代: [94/200], Loss: 0.1878
# 迭代: [94/200], Loss: 0.0774
# 迭代: [94/200], Loss: 0.2306
# 迭代: [94/200], Loss: 0.1476
# 迭代: [94/200], Loss: 0.1468
# 迭代: [94/200], Loss: 0.1065
# 迭代: [94/200], Loss: 0.2159
# 迭代: [94/200], Loss: 0.0939
# 迭代: [94/200], Loss: 0.2175
# 迭代: [94/200], Loss: 0.1405
# 迭代: [95/200], Loss: 0.1527
# 迭代: [95/200], Loss: 0.1674
# 迭代: [95/200], Loss: 0.1792
# 迭代: [95/200], Loss: 0.1450
# 迭代: [95/200], Loss: 0.1549
# 迭代: [95/200], Loss: 0.1900
# 迭代: [95/200], Loss: 0.0865
# 迭代: [95/200], Loss: 0.1603
# 迭代: [95/200], Loss: 0.1600
# 迭代: [95/200], Loss: 0.1635
# 迭代: [96/200], Loss: 0.1313
# 迭代: [96/200], Loss: 0.1169
# 迭代: [96/200], Loss: 0.1333
# 迭代: [96/200], Loss: 0.1243
# 迭代: [96/200], Loss: 0.2051
# 迭代: [96/200], Loss: 0.1763
# 迭代: [96/200], Loss: 0.1378
# 迭代: [96/200], Loss: 0.1234
# 迭代: [96/200], Loss: 0.2389
# 迭代: [96/200], Loss: 0.1629
# 迭代: [97/200], Loss: 0.1685
# 迭代: [97/200], Loss: 0.1339
# 迭代: [97/200], Loss: 0.1571
# 迭代: [97/200], Loss: 0.0799
# 迭代: [97/200], Loss: 0.1326
# 迭代: [97/200], Loss: 0.1486
# 迭代: [97/200], Loss: 0.1807
# 迭代: [97/200], Loss: 0.1291
# 迭代: [97/200], Loss: 0.2740
# 迭代: [97/200], Loss: 0.1480
# 迭代: [98/200], Loss: 0.1760
# 迭代: [98/200], Loss: 0.1568
# 迭代: [98/200], Loss: 0.2088
# 迭代: [98/200], Loss: 0.1288
# 迭代: [98/200], Loss: 0.1540
# 迭代: [98/200], Loss: 0.1398
# 迭代: [98/200], Loss: 0.1693
# 迭代: [98/200], Loss: 0.1747
# 迭代: [98/200], Loss: 0.1146
# 迭代: [98/200], Loss: 0.1198
# 迭代: [99/200], Loss: 0.0870
# 迭代: [99/200], Loss: 0.1362
# 迭代: [99/200], Loss: 0.1939
# 迭代: [99/200], Loss: 0.1232
# 迭代: [99/200], Loss: 0.1313
# 迭代: [99/200], Loss: 0.1356
# 迭代: [99/200], Loss: 0.1372
# 迭代: [99/200], Loss: 0.2267
# 迭代: [99/200], Loss: 0.2129
# 迭代: [99/200], Loss: 0.1520
# 迭代: [100/200], Loss: 0.1382
# 迭代: [100/200], Loss: 0.1286
# 迭代: [100/200], Loss: 0.2638
# 迭代: [100/200], Loss: 0.1060
# 迭代: [100/200], Loss: 0.2232
# 迭代: [100/200], Loss: 0.1262
# 迭代: [100/200], Loss: 0.1617
# 迭代: [100/200], Loss: 0.0862
# 迭代: [100/200], Loss: 0.1012
# 迭代: [100/200], Loss: 0.1990
# 迭代: [101/200], Loss: 0.1171
# 迭代: [101/200], Loss: 0.2070
# 迭代: [101/200], Loss: 0.1455
# 迭代: [101/200], Loss: 0.1630
# 迭代: [101/200], Loss: 0.1351
# 迭代: [101/200], Loss: 0.1908
# 迭代: [101/200], Loss: 0.1749
# 迭代: [101/200], Loss: 0.1052
# 迭代: [101/200], Loss: 0.1504
# 迭代: [101/200], Loss: 0.1320
# 迭代: [102/200], Loss: 0.1881
# 迭代: [102/200], Loss: 0.1554
# 迭代: [102/200], Loss: 0.1433
# 迭代: [102/200], Loss: 0.1267
# 迭代: [102/200], Loss: 0.1482
# 迭代: [102/200], Loss: 0.1165
# 迭代: [102/200], Loss: 0.1261
# 迭代: [102/200], Loss: 0.1083
# 迭代: [102/200], Loss: 0.1581
# 迭代: [102/200], Loss: 0.2409
# 迭代: [103/200], Loss: 0.1521
# 迭代: [103/200], Loss: 0.1525
# 迭代: [103/200], Loss: 0.1165
# 迭代: [103/200], Loss: 0.0962
# 迭代: [103/200], Loss: 0.2080
# 迭代: [103/200], Loss: 0.1661
# 迭代: [103/200], Loss: 0.0934
# 迭代: [103/200], Loss: 0.2130
# 迭代: [103/200], Loss: 0.1165
# 迭代: [103/200], Loss: 0.1926
# 迭代: [104/200], Loss: 0.1968
# 迭代: [104/200], Loss: 0.1307
# 迭代: [104/200], Loss: 0.0954
# 迭代: [104/200], Loss: 0.1189
# 迭代: [104/200], Loss: 0.1441
# 迭代: [104/200], Loss: 0.1608
# 迭代: [104/200], Loss: 0.2069
# 迭代: [104/200], Loss: 0.1810
# 迭代: [104/200], Loss: 0.1565
# 迭代: [104/200], Loss: 0.1133
# 迭代: [105/200], Loss: 0.1797
# 迭代: [105/200], Loss: 0.0878
# 迭代: [105/200], Loss: 0.0919
# 迭代: [105/200], Loss: 0.1638
# 迭代: [105/200], Loss: 0.2212
# 迭代: [105/200], Loss: 0.2049
# 迭代: [105/200], Loss: 0.1693
# 迭代: [105/200], Loss: 0.1413
# 迭代: [105/200], Loss: 0.0922
# 迭代: [105/200], Loss: 0.1492
# 迭代: [106/200], Loss: 0.1511
# 迭代: [106/200], Loss: 0.1003
# 迭代: [106/200], Loss: 0.1416
# 迭代: [106/200], Loss: 0.1168
# 迭代: [106/200], Loss: 0.1754
# 迭代: [106/200], Loss: 0.0990
# 迭代: [106/200], Loss: 0.1276
# 迭代: [106/200], Loss: 0.2099
# 迭代: [106/200], Loss: 0.1806
# 迭代: [106/200], Loss: 0.1892
# 迭代: [107/200], Loss: 0.1008
# 迭代: [107/200], Loss: 0.1235
# 迭代: [107/200], Loss: 0.1095
# 迭代: [107/200], Loss: 0.1897
# 迭代: [107/200], Loss: 0.1027
# 迭代: [107/200], Loss: 0.1714
# 迭代: [107/200], Loss: 0.1110
# 迭代: [107/200], Loss: 0.2244
# 迭代: [107/200], Loss: 0.1612
# 迭代: [107/200], Loss: 0.1915
# 迭代: [108/200], Loss: 0.1504
# 迭代: [108/200], Loss: 0.1651
# 迭代: [108/200], Loss: 0.1590
# 迭代: [108/200], Loss: 0.1409
# 迭代: [108/200], Loss: 0.1187
# 迭代: [108/200], Loss: 0.1675
# 迭代: [108/200], Loss: 0.1343
# 迭代: [108/200], Loss: 0.1834
# 迭代: [108/200], Loss: 0.1372
# 迭代: [108/200], Loss: 0.1241
# 迭代: [109/200], Loss: 0.1129
# 迭代: [109/200], Loss: 0.1284
# 迭代: [109/200], Loss: 0.1709
# 迭代: [109/200], Loss: 0.1900
# 迭代: [109/200], Loss: 0.0856
# 迭代: [109/200], Loss: 0.2024
# 迭代: [109/200], Loss: 0.1478
# 迭代: [109/200], Loss: 0.1822
# 迭代: [109/200], Loss: 0.1386
# 迭代: [109/200], Loss: 0.1188
# 迭代: [110/200], Loss: 0.1567
# 迭代: [110/200], Loss: 0.1509
# 迭代: [110/200], Loss: 0.0953
# 迭代: [110/200], Loss: 0.1574
# 迭代: [110/200], Loss: 0.1552
# 迭代: [110/200], Loss: 0.1478
# 迭代: [110/200], Loss: 0.1623
# 迭代: [110/200], Loss: 0.1153
# 迭代: [110/200], Loss: 0.1586
# 迭代: [110/200], Loss: 0.1684
# 迭代: [111/200], Loss: 0.1721
# 迭代: [111/200], Loss: 0.0605
# 迭代: [111/200], Loss: 0.0961
# 迭代: [111/200], Loss: 0.1734
# 迭代: [111/200], Loss: 0.1695
# 迭代: [111/200], Loss: 0.1862
# 迭代: [111/200], Loss: 0.1874
# 迭代: [111/200], Loss: 0.1610
# 迭代: [111/200], Loss: 0.1249
# 迭代: [111/200], Loss: 0.1311
# 迭代: [112/200], Loss: 0.1518
# 迭代: [112/200], Loss: 0.2076
# 迭代: [112/200], Loss: 0.0846
# 迭代: [112/200], Loss: 0.1642
# 迭代: [112/200], Loss: 0.1797
# 迭代: [112/200], Loss: 0.1516
# 迭代: [112/200], Loss: 0.1199
# 迭代: [112/200], Loss: 0.1811
# 迭代: [112/200], Loss: 0.0740
# 迭代: [112/200], Loss: 0.1424
# 迭代: [113/200], Loss: 0.1263
# 迭代: [113/200], Loss: 0.1058
# 迭代: [113/200], Loss: 0.1198
# 迭代: [113/200], Loss: 0.1376
# 迭代: [113/200], Loss: 0.1386
# 迭代: [113/200], Loss: 0.2303
# 迭代: [113/200], Loss: 0.0928
# 迭代: [113/200], Loss: 0.1665
# 迭代: [113/200], Loss: 0.1703
# 迭代: [113/200], Loss: 0.1655
# 迭代: [114/200], Loss: 0.0869
# 迭代: [114/200], Loss: 0.1247
# 迭代: [114/200], Loss: 0.1754
# 迭代: [114/200], Loss: 0.1305
# 迭代: [114/200], Loss: 0.1208
# 迭代: [114/200], Loss: 0.2067
# 迭代: [114/200], Loss: 0.1637
# 迭代: [114/200], Loss: 0.1121
# 迭代: [114/200], Loss: 0.1793
# 迭代: [114/200], Loss: 0.1521
# 迭代: [115/200], Loss: 0.1051
# 迭代: [115/200], Loss: 0.2033
# 迭代: [115/200], Loss: 0.2095
# 迭代: [115/200], Loss: 0.0972
# 迭代: [115/200], Loss: 0.2278
# 迭代: [115/200], Loss: 0.1109
# 迭代: [115/200], Loss: 0.1508
# 迭代: [115/200], Loss: 0.1008
# 迭代: [115/200], Loss: 0.1431
# 迭代: [115/200], Loss: 0.0950
# 迭代: [116/200], Loss: 0.1533
# 迭代: [116/200], Loss: 0.1060
# 迭代: [116/200], Loss: 0.1171
# 迭代: [116/200], Loss: 0.1554
# 迭代: [116/200], Loss: 0.0614
# 迭代: [116/200], Loss: 0.1983
# 迭代: [116/200], Loss: 0.1222
# 迭代: [116/200], Loss: 0.1312
# 迭代: [116/200], Loss: 0.1852
# 迭代: [116/200], Loss: 0.2067
# 迭代: [117/200], Loss: 0.1504
# 迭代: [117/200], Loss: 0.1101
# 迭代: [117/200], Loss: 0.1414
# 迭代: [117/200], Loss: 0.1379
# 迭代: [117/200], Loss: 0.1359
# 迭代: [117/200], Loss: 0.1160
# 迭代: [117/200], Loss: 0.1815
# 迭代: [117/200], Loss: 0.1763
# 迭代: [117/200], Loss: 0.1038
# 迭代: [117/200], Loss: 0.1840
# 迭代: [118/200], Loss: 0.1550
# 迭代: [118/200], Loss: 0.1463
# 迭代: [118/200], Loss: 0.1551
# 迭代: [118/200], Loss: 0.1159
# 迭代: [118/200], Loss: 0.2033
# 迭代: [118/200], Loss: 0.1374
# 迭代: [118/200], Loss: 0.1611
# 迭代: [118/200], Loss: 0.1084
# 迭代: [118/200], Loss: 0.1033
# 迭代: [118/200], Loss: 0.1434
# 迭代: [119/200], Loss: 0.1377
# 迭代: [119/200], Loss: 0.1104
# 迭代: [119/200], Loss: 0.1219
# 迭代: [119/200], Loss: 0.1600
# 迭代: [119/200], Loss: 0.1643
# 迭代: [119/200], Loss: 0.1400
# 迭代: [119/200], Loss: 0.1620
# 迭代: [119/200], Loss: 0.0724
# 迭代: [119/200], Loss: 0.1619
# 迭代: [119/200], Loss: 0.1934
# 迭代: [120/200], Loss: 0.1675
# 迭代: [120/200], Loss: 0.1463
# 迭代: [120/200], Loss: 0.1255
# 迭代: [120/200], Loss: 0.1959
# 迭代: [120/200], Loss: 0.1187
# 迭代: [120/200], Loss: 0.1117
# 迭代: [120/200], Loss: 0.1743
# 迭代: [120/200], Loss: 0.0864
# 迭代: [120/200], Loss: 0.1668
# 迭代: [120/200], Loss: 0.1261
# 迭代: [121/200], Loss: 0.1479
# 迭代: [121/200], Loss: 0.1389
# 迭代: [121/200], Loss: 0.0893
# 迭代: [121/200], Loss: 0.1467
# 迭代: [121/200], Loss: 0.2013
# 迭代: [121/200], Loss: 0.0771
# 迭代: [121/200], Loss: 0.2106
# 迭代: [121/200], Loss: 0.0908
# 迭代: [121/200], Loss: 0.1490
# 迭代: [121/200], Loss: 0.1622
# 迭代: [122/200], Loss: 0.2055
# 迭代: [122/200], Loss: 0.0906
# 迭代: [122/200], Loss: 0.0682
# 迭代: [122/200], Loss: 0.2048
# 迭代: [122/200], Loss: 0.1758
# 迭代: [122/200], Loss: 0.1390
# 迭代: [122/200], Loss: 0.1359
# 迭代: [122/200], Loss: 0.1315
# 迭代: [122/200], Loss: 0.1125
# 迭代: [122/200], Loss: 0.1439
# 迭代: [123/200], Loss: 0.1551
# 迭代: [123/200], Loss: 0.1615
# 迭代: [123/200], Loss: 0.1687
# 迭代: [123/200], Loss: 0.1726
# 迭代: [123/200], Loss: 0.2097
# 迭代: [123/200], Loss: 0.1039
# 迭代: [123/200], Loss: 0.1518
# 迭代: [123/200], Loss: 0.1081
# 迭代: [123/200], Loss: 0.0706
# 迭代: [123/200], Loss: 0.1022
# 迭代: [124/200], Loss: 0.1146
# 迭代: [124/200], Loss: 0.1959
# 迭代: [124/200], Loss: 0.0836
# 迭代: [124/200], Loss: 0.1985
# 迭代: [124/200], Loss: 0.1300
# 迭代: [124/200], Loss: 0.1577
# 迭代: [124/200], Loss: 0.1255
# 迭代: [124/200], Loss: 0.1684
# 迭代: [124/200], Loss: 0.1191
# 迭代: [124/200], Loss: 0.1049
# 迭代: [125/200], Loss: 0.1810
# 迭代: [125/200], Loss: 0.1640
# 迭代: [125/200], Loss: 0.1764
# 迭代: [125/200], Loss: 0.1171
# 迭代: [125/200], Loss: 0.1206
# 迭代: [125/200], Loss: 0.1295
# 迭代: [125/200], Loss: 0.1410
# 迭代: [125/200], Loss: 0.1337
# 迭代: [125/200], Loss: 0.0783
# 迭代: [125/200], Loss: 0.1537
# 迭代: [126/200], Loss: 0.1407
# 迭代: [126/200], Loss: 0.1036
# 迭代: [126/200], Loss: 0.0751
# 迭代: [126/200], Loss: 0.2110
# 迭代: [126/200], Loss: 0.1904
# 迭代: [126/200], Loss: 0.1429
# 迭代: [126/200], Loss: 0.1250
# 迭代: [126/200], Loss: 0.0782
# 迭代: [126/200], Loss: 0.1919
# 迭代: [126/200], Loss: 0.1313
# 迭代: [127/200], Loss: 0.1378
# 迭代: [127/200], Loss: 0.1765
# 迭代: [127/200], Loss: 0.1194
# 迭代: [127/200], Loss: 0.1632
# 迭代: [127/200], Loss: 0.1395
# 迭代: [127/200], Loss: 0.0846
# 迭代: [127/200], Loss: 0.1418
# 迭代: [127/200], Loss: 0.0743
# 迭代: [127/200], Loss: 0.1245
# 迭代: [127/200], Loss: 0.2278
# 迭代: [128/200], Loss: 0.1389
# 迭代: [128/200], Loss: 0.1727
# 迭代: [128/200], Loss: 0.1031
# 迭代: [128/200], Loss: 0.2329
# 迭代: [128/200], Loss: 0.1161
# 迭代: [128/200], Loss: 0.1417
# 迭代: [128/200], Loss: 0.0724
# 迭代: [128/200], Loss: 0.1539
# 迭代: [128/200], Loss: 0.1021
# 迭代: [128/200], Loss: 0.1514
# 迭代: [129/200], Loss: 0.1287
# 迭代: [129/200], Loss: 0.1749
# 迭代: [129/200], Loss: 0.1161
# 迭代: [129/200], Loss: 0.1860
# 迭代: [129/200], Loss: 0.0603
# 迭代: [129/200], Loss: 0.2403
# 迭代: [129/200], Loss: 0.1466
# 迭代: [129/200], Loss: 0.0984
# 迭代: [129/200], Loss: 0.0748
# 迭代: [129/200], Loss: 0.1506
# 迭代: [130/200], Loss: 0.1160
# 迭代: [130/200], Loss: 0.1383
# 迭代: [130/200], Loss: 0.2403
# 迭代: [130/200], Loss: 0.0649
# 迭代: [130/200], Loss: 0.1332
# 迭代: [130/200], Loss: 0.1411
# 迭代: [130/200], Loss: 0.1187
# 迭代: [130/200], Loss: 0.1791
# 迭代: [130/200], Loss: 0.1452
# 迭代: [130/200], Loss: 0.0953
# 迭代: [131/200], Loss: 0.1042
# 迭代: [131/200], Loss: 0.1222
# 迭代: [131/200], Loss: 0.1915
# 迭代: [131/200], Loss: 0.1011
# 迭代: [131/200], Loss: 0.1142
# 迭代: [131/200], Loss: 0.1765
# 迭代: [131/200], Loss: 0.1307
# 迭代: [131/200], Loss: 0.1111
# 迭代: [131/200], Loss: 0.1578
# 迭代: [131/200], Loss: 0.1611
# 迭代: [132/200], Loss: 0.1554
# 迭代: [132/200], Loss: 0.1813
# 迭代: [132/200], Loss: 0.2023
# 迭代: [132/200], Loss: 0.0751
# 迭代: [132/200], Loss: 0.1953
# 迭代: [132/200], Loss: 0.1563
# 迭代: [132/200], Loss: 0.0989
# 迭代: [132/200], Loss: 0.0878
# 迭代: [132/200], Loss: 0.1040
# 迭代: [132/200], Loss: 0.1157
# 迭代: [133/200], Loss: 0.1565
# 迭代: [133/200], Loss: 0.0957
# 迭代: [133/200], Loss: 0.0407
# 迭代: [133/200], Loss: 0.2232
# 迭代: [133/200], Loss: 0.0956
# 迭代: [133/200], Loss: 0.1931
# 迭代: [133/200], Loss: 0.1409
# 迭代: [133/200], Loss: 0.1047
# 迭代: [133/200], Loss: 0.1792
# 迭代: [133/200], Loss: 0.1320
# 迭代: [134/200], Loss: 0.1179
# 迭代: [134/200], Loss: 0.1363
# 迭代: [134/200], Loss: 0.1833
# 迭代: [134/200], Loss: 0.1177
# 迭代: [134/200], Loss: 0.0893
# 迭代: [134/200], Loss: 0.1050
# 迭代: [134/200], Loss: 0.1200
# 迭代: [134/200], Loss: 0.1208
# 迭代: [134/200], Loss: 0.1578
# 迭代: [134/200], Loss: 0.2098
# 迭代: [135/200], Loss: 0.1294
# 迭代: [135/200], Loss: 0.1640
# 迭代: [135/200], Loss: 0.0981
# 迭代: [135/200], Loss: 0.1169
# 迭代: [135/200], Loss: 0.1094
# 迭代: [135/200], Loss: 0.1641
# 迭代: [135/200], Loss: 0.1109
# 迭代: [135/200], Loss: 0.1805
# 迭代: [135/200], Loss: 0.1342
# 迭代: [135/200], Loss: 0.1471
# 迭代: [136/200], Loss: 0.1174
# 迭代: [136/200], Loss: 0.1233
# 迭代: [136/200], Loss: 0.1584
# 迭代: [136/200], Loss: 0.1039
# 迭代: [136/200], Loss: 0.1537
# 迭代: [136/200], Loss: 0.1719
# 迭代: [136/200], Loss: 0.1404
# 迭代: [136/200], Loss: 0.1286
# 迭代: [136/200], Loss: 0.1449
# 迭代: [136/200], Loss: 0.1136
# 迭代: [137/200], Loss: 0.0981
# 迭代: [137/200], Loss: 0.1102
# 迭代: [137/200], Loss: 0.1778
# 迭代: [137/200], Loss: 0.1218
# 迭代: [137/200], Loss: 0.1534
# 迭代: [137/200], Loss: 0.1240
# 迭代: [137/200], Loss: 0.1414
# 迭代: [137/200], Loss: 0.1248
# 迭代: [137/200], Loss: 0.2232
# 迭代: [137/200], Loss: 0.0683
# 迭代: [138/200], Loss: 0.1540
# 迭代: [138/200], Loss: 0.0930
# 迭代: [138/200], Loss: 0.0685
# 迭代: [138/200], Loss: 0.1674
# 迭代: [138/200], Loss: 0.0958
# 迭代: [138/200], Loss: 0.1023
# 迭代: [138/200], Loss: 0.1134
# 迭代: [138/200], Loss: 0.1767
# 迭代: [138/200], Loss: 0.1339
# 迭代: [138/200], Loss: 0.2400
# 迭代: [139/200], Loss: 0.1973
# 迭代: [139/200], Loss: 0.1405
# 迭代: [139/200], Loss: 0.1602
# 迭代: [139/200], Loss: 0.0815
# 迭代: [139/200], Loss: 0.1736
# 迭代: [139/200], Loss: 0.1314
# 迭代: [139/200], Loss: 0.0504
# 迭代: [139/200], Loss: 0.1664
# 迭代: [139/200], Loss: 0.1099
# 迭代: [139/200], Loss: 0.1265
# 迭代: [140/200], Loss: 0.1145
# 迭代: [140/200], Loss: 0.1257
# 迭代: [140/200], Loss: 0.1191
# 迭代: [140/200], Loss: 0.1438
# 迭代: [140/200], Loss: 0.1675
# 迭代: [140/200], Loss: 0.0937
# 迭代: [140/200], Loss: 0.1373
# 迭代: [140/200], Loss: 0.1770
# 迭代: [140/200], Loss: 0.1707
# 迭代: [140/200], Loss: 0.0837
# 迭代: [141/200], Loss: 0.1138
# 迭代: [141/200], Loss: 0.1124
# 迭代: [141/200], Loss: 0.1703
# 迭代: [141/200], Loss: 0.1170
# 迭代: [141/200], Loss: 0.0788
# 迭代: [141/200], Loss: 0.1307
# 迭代: [141/200], Loss: 0.1681
# 迭代: [141/200], Loss: 0.1841
# 迭代: [141/200], Loss: 0.1387
# 迭代: [141/200], Loss: 0.1156
# 迭代: [142/200], Loss: 0.1595
# 迭代: [142/200], Loss: 0.1592
# 迭代: [142/200], Loss: 0.2102
# 迭代: [142/200], Loss: 0.1108
# 迭代: [142/200], Loss: 0.1678
# 迭代: [142/200], Loss: 0.0518
# 迭代: [142/200], Loss: 0.1433
# 迭代: [142/200], Loss: 0.0917
# 迭代: [142/200], Loss: 0.1735
# 迭代: [142/200], Loss: 0.0571
# 迭代: [143/200], Loss: 0.1520
# 迭代: [143/200], Loss: 0.1610
# 迭代: [143/200], Loss: 0.0660
# 迭代: [143/200], Loss: 0.1479
# 迭代: [143/200], Loss: 0.0885
# 迭代: [143/200], Loss: 0.1868
# 迭代: [143/200], Loss: 0.0918
# 迭代: [143/200], Loss: 0.1822
# 迭代: [143/200], Loss: 0.1630
# 迭代: [143/200], Loss: 0.0862
# 迭代: [144/200], Loss: 0.1847
# 迭代: [144/200], Loss: 0.1296
# 迭代: [144/200], Loss: 0.1833
# 迭代: [144/200], Loss: 0.1275
# 迭代: [144/200], Loss: 0.1035
# 迭代: [144/200], Loss: 0.1160
# 迭代: [144/200], Loss: 0.1166
# 迭代: [144/200], Loss: 0.0721
# 迭代: [144/200], Loss: 0.2011
# 迭代: [144/200], Loss: 0.0839
# 迭代: [145/200], Loss: 0.1728
# 迭代: [145/200], Loss: 0.0934
# 迭代: [145/200], Loss: 0.2142
# 迭代: [145/200], Loss: 0.1292
# 迭代: [145/200], Loss: 0.0729
# 迭代: [145/200], Loss: 0.1657
# 迭代: [145/200], Loss: 0.0887
# 迭代: [145/200], Loss: 0.0877
# 迭代: [145/200], Loss: 0.1654
# 迭代: [145/200], Loss: 0.1246
# 迭代: [146/200], Loss: 0.0965
# 迭代: [146/200], Loss: 0.1047
# 迭代: [146/200], Loss: 0.0851
# 迭代: [146/200], Loss: 0.1322
# 迭代: [146/200], Loss: 0.1599
# 迭代: [146/200], Loss: 0.1344
# 迭代: [146/200], Loss: 0.1621
# 迭代: [146/200], Loss: 0.1113
# 迭代: [146/200], Loss: 0.1333
# 迭代: [146/200], Loss: 0.1935
# 迭代: [147/200], Loss: 0.1170
# 迭代: [147/200], Loss: 0.1512
# 迭代: [147/200], Loss: 0.1675
# 迭代: [147/200], Loss: 0.1179
# 迭代: [147/200], Loss: 0.0993
# 迭代: [147/200], Loss: 0.0799
# 迭代: [147/200], Loss: 0.1193
# 迭代: [147/200], Loss: 0.1833
# 迭代: [147/200], Loss: 0.1521
# 迭代: [147/200], Loss: 0.1266
# 迭代: [148/200], Loss: 0.1861
# 迭代: [148/200], Loss: 0.1377
# 迭代: [148/200], Loss: 0.1922
# 迭代: [148/200], Loss: 0.1713
# 迭代: [148/200], Loss: 0.1280
# 迭代: [148/200], Loss: 0.0545
# 迭代: [148/200], Loss: 0.0903
# 迭代: [148/200], Loss: 0.1231
# 迭代: [148/200], Loss: 0.1015
# 迭代: [148/200], Loss: 0.1226
# 迭代: [149/200], Loss: 0.1036
# 迭代: [149/200], Loss: 0.1792
# 迭代: [149/200], Loss: 0.0823
# 迭代: [149/200], Loss: 0.1162
# 迭代: [149/200], Loss: 0.1608
# 迭代: [149/200], Loss: 0.1104
# 迭代: [149/200], Loss: 0.1271
# 迭代: [149/200], Loss: 0.1025
# 迭代: [149/200], Loss: 0.1495
# 迭代: [149/200], Loss: 0.1701
# 迭代: [150/200], Loss: 0.1751
# 迭代: [150/200], Loss: 0.1422
# 迭代: [150/200], Loss: 0.1685
# 迭代: [150/200], Loss: 0.0597
# 迭代: [150/200], Loss: 0.1912
# 迭代: [150/200], Loss: 0.0760
# 迭代: [150/200], Loss: 0.1414
# 迭代: [150/200], Loss: 0.1068
# 迭代: [150/200], Loss: 0.1158
# 迭代: [150/200], Loss: 0.1201
# 迭代: [151/200], Loss: 0.1515
# 迭代: [151/200], Loss: 0.1125
# 迭代: [151/200], Loss: 0.1139
# 迭代: [151/200], Loss: 0.1148
# 迭代: [151/200], Loss: 0.1356
# 迭代: [151/200], Loss: 0.1562
# 迭代: [151/200], Loss: 0.1266
# 迭代: [151/200], Loss: 0.1107
# 迭代: [151/200], Loss: 0.1354
# 迭代: [151/200], Loss: 0.1362
# 迭代: [152/200], Loss: 0.1048
# 迭代: [152/200], Loss: 0.0781
# 迭代: [152/200], Loss: 0.1179
# 迭代: [152/200], Loss: 0.0897
# 迭代: [152/200], Loss: 0.1450
# 迭代: [152/200], Loss: 0.1298
# 迭代: [152/200], Loss: 0.1280
# 迭代: [152/200], Loss: 0.1344
# 迭代: [152/200], Loss: 0.1502
# 迭代: [152/200], Loss: 0.2138
# 迭代: [153/200], Loss: 0.1241
# 迭代: [153/200], Loss: 0.1405
# 迭代: [153/200], Loss: 0.1840
# 迭代: [153/200], Loss: 0.1690
# 迭代: [153/200], Loss: 0.1392
# 迭代: [153/200], Loss: 0.1910
# 迭代: [153/200], Loss: 0.0676
# 迭代: [153/200], Loss: 0.1170
# 迭代: [153/200], Loss: 0.0673
# 迭代: [153/200], Loss: 0.0879
# 迭代: [154/200], Loss: 0.1566
# 迭代: [154/200], Loss: 0.1725
# 迭代: [154/200], Loss: 0.0992
# 迭代: [154/200], Loss: 0.1642
# 迭代: [154/200], Loss: 0.1210
# 迭代: [154/200], Loss: 0.1161
# 迭代: [154/200], Loss: 0.1109
# 迭代: [154/200], Loss: 0.1635
# 迭代: [154/200], Loss: 0.1231
# 迭代: [154/200], Loss: 0.0575
# 迭代: [155/200], Loss: 0.0948
# 迭代: [155/200], Loss: 0.2175
# 迭代: [155/200], Loss: 0.1193
# 迭代: [155/200], Loss: 0.1634
# 迭代: [155/200], Loss: 0.1059
# 迭代: [155/200], Loss: 0.1065
# 迭代: [155/200], Loss: 0.0816
# 迭代: [155/200], Loss: 0.1943
# 迭代: [155/200], Loss: 0.1199
# 迭代: [155/200], Loss: 0.0772
# 迭代: [156/200], Loss: 0.2234
# 迭代: [156/200], Loss: 0.1394
# 迭代: [156/200], Loss: 0.0952
# 迭代: [156/200], Loss: 0.1018
# 迭代: [156/200], Loss: 0.1321
# 迭代: [156/200], Loss: 0.1784
# 迭代: [156/200], Loss: 0.1153
# 迭代: [156/200], Loss: 0.0964
# 迭代: [156/200], Loss: 0.0716
# 迭代: [156/200], Loss: 0.1286
# 迭代: [157/200], Loss: 0.0788
# 迭代: [157/200], Loss: 0.1293
# 迭代: [157/200], Loss: 0.0787
# 迭代: [157/200], Loss: 0.1580
# 迭代: [157/200], Loss: 0.1677
# 迭代: [157/200], Loss: 0.1230
# 迭代: [157/200], Loss: 0.0847
# 迭代: [157/200], Loss: 0.1690
# 迭代: [157/200], Loss: 0.1908
# 迭代: [157/200], Loss: 0.0951
# 迭代: [158/200], Loss: 0.1225
# 迭代: [158/200], Loss: 0.1213
# 迭代: [158/200], Loss: 0.2104
# 迭代: [158/200], Loss: 0.1243
# 迭代: [158/200], Loss: 0.1565
# 迭代: [158/200], Loss: 0.1406
# 迭代: [158/200], Loss: 0.1273
# 迭代: [158/200], Loss: 0.0932
# 迭代: [158/200], Loss: 0.1171
# 迭代: [158/200], Loss: 0.0587
# 迭代: [159/200], Loss: 0.1787
# 迭代: [159/200], Loss: 0.2064
# 迭代: [159/200], Loss: 0.0648
# 迭代: [159/200], Loss: 0.0979
# 迭代: [159/200], Loss: 0.1892
# 迭代: [159/200], Loss: 0.0567
# 迭代: [159/200], Loss: 0.1097
# 迭代: [159/200], Loss: 0.1670
# 迭代: [159/200], Loss: 0.1147
# 迭代: [159/200], Loss: 0.0856
# 迭代: [160/200], Loss: 0.1319
# 迭代: [160/200], Loss: 0.0976
# 迭代: [160/200], Loss: 0.1674
# 迭代: [160/200], Loss: 0.1917
# 迭代: [160/200], Loss: 0.0759
# 迭代: [160/200], Loss: 0.1564
# 迭代: [160/200], Loss: 0.1123
# 迭代: [160/200], Loss: 0.1042
# 迭代: [160/200], Loss: 0.1074
# 迭代: [160/200], Loss: 0.1195
# 迭代: [161/200], Loss: 0.0645
# 迭代: [161/200], Loss: 0.1323
# 迭代: [161/200], Loss: 0.1000
# 迭代: [161/200], Loss: 0.1186
# 迭代: [161/200], Loss: 0.0604
# 迭代: [161/200], Loss: 0.1433
# 迭代: [161/200], Loss: 0.1926
# 迭代: [161/200], Loss: 0.1785
# 迭代: [161/200], Loss: 0.1130
# 迭代: [161/200], Loss: 0.1580
# 迭代: [162/200], Loss: 0.1567
# 迭代: [162/200], Loss: 0.1200
# 迭代: [162/200], Loss: 0.1437
# 迭代: [162/200], Loss: 0.1107
# 迭代: [162/200], Loss: 0.1502
# 迭代: [162/200], Loss: 0.1529
# 迭代: [162/200], Loss: 0.1331
# 迭代: [162/200], Loss: 0.1054
# 迭代: [162/200], Loss: 0.1274
# 迭代: [162/200], Loss: 0.0583
# 迭代: [163/200], Loss: 0.1188
# 迭代: [163/200], Loss: 0.1032
# 迭代: [163/200], Loss: 0.1298
# 迭代: [163/200], Loss: 0.1145
# 迭代: [163/200], Loss: 0.1088
# 迭代: [163/200], Loss: 0.1809
# 迭代: [163/200], Loss: 0.1418
# 迭代: [163/200], Loss: 0.1337
# 迭代: [163/200], Loss: 0.1301
# 迭代: [163/200], Loss: 0.0939
# 迭代: [164/200], Loss: 0.0861
# 迭代: [164/200], Loss: 0.1451
# 迭代: [164/200], Loss: 0.1090
# 迭代: [164/200], Loss: 0.1447
# 迭代: [164/200], Loss: 0.0743
# 迭代: [164/200], Loss: 0.1437
# 迭代: [164/200], Loss: 0.1625
# 迭代: [164/200], Loss: 0.1356
# 迭代: [164/200], Loss: 0.0621
# 迭代: [164/200], Loss: 0.1895
# 迭代: [165/200], Loss: 0.0913
# 迭代: [165/200], Loss: 0.1100
# 迭代: [165/200], Loss: 0.1039
# 迭代: [165/200], Loss: 0.1128
# 迭代: [165/200], Loss: 0.0733
# 迭代: [165/200], Loss: 0.2242
# 迭代: [165/200], Loss: 0.1051
# 迭代: [165/200], Loss: 0.1779
# 迭代: [165/200], Loss: 0.1423
# 迭代: [165/200], Loss: 0.1095
# 迭代: [166/200], Loss: 0.0995
# 迭代: [166/200], Loss: 0.2244
# 迭代: [166/200], Loss: 0.1303
# 迭代: [166/200], Loss: 0.1230
# 迭代: [166/200], Loss: 0.1387
# 迭代: [166/200], Loss: 0.0696
# 迭代: [166/200], Loss: 0.1191
# 迭代: [166/200], Loss: 0.1373
# 迭代: [166/200], Loss: 0.1055
# 迭代: [166/200], Loss: 0.1041
# 迭代: [167/200], Loss: 0.1183
# 迭代: [167/200], Loss: 0.0678
# 迭代: [167/200], Loss: 0.1518
# 迭代: [167/200], Loss: 0.1097
# 迭代: [167/200], Loss: 0.1470
# 迭代: [167/200], Loss: 0.0807
# 迭代: [167/200], Loss: 0.1313
# 迭代: [167/200], Loss: 0.1347
# 迭代: [167/200], Loss: 0.1470
# 迭代: [167/200], Loss: 0.1564
# 迭代: [168/200], Loss: 0.1395
# 迭代: [168/200], Loss: 0.0768
# 迭代: [168/200], Loss: 0.1184
# 迭代: [168/200], Loss: 0.1628
# 迭代: [168/200], Loss: 0.2110
# 迭代: [168/200], Loss: 0.0638
# 迭代: [168/200], Loss: 0.1020
# 迭代: [168/200], Loss: 0.1047
# 迭代: [168/200], Loss: 0.1125
# 迭代: [168/200], Loss: 0.1497
# 迭代: [169/200], Loss: 0.1563
# 迭代: [169/200], Loss: 0.1509
# 迭代: [169/200], Loss: 0.1145
# 迭代: [169/200], Loss: 0.0912
# 迭代: [169/200], Loss: 0.1273
# 迭代: [169/200], Loss: 0.1484
# 迭代: [169/200], Loss: 0.1218
# 迭代: [169/200], Loss: 0.0687
# 迭代: [169/200], Loss: 0.1206
# 迭代: [169/200], Loss: 0.1395
# 迭代: [170/200], Loss: 0.1783
# 迭代: [170/200], Loss: 0.1388
# 迭代: [170/200], Loss: 0.1439
# 迭代: [170/200], Loss: 0.0885
# 迭代: [170/200], Loss: 0.0985
# 迭代: [170/200], Loss: 0.0975
# 迭代: [170/200], Loss: 0.1276
# 迭代: [170/200], Loss: 0.1260
# 迭代: [170/200], Loss: 0.1546
# 迭代: [170/200], Loss: 0.0830
# 迭代: [171/200], Loss: 0.1163
# 迭代: [171/200], Loss: 0.1110
# 迭代: [171/200], Loss: 0.0955
# 迭代: [171/200], Loss: 0.2219
# 迭代: [171/200], Loss: 0.1011
# 迭代: [171/200], Loss: 0.0640
# 迭代: [171/200], Loss: 0.0854
# 迭代: [171/200], Loss: 0.1675
# 迭代: [171/200], Loss: 0.1385
# 迭代: [171/200], Loss: 0.1316
# 迭代: [172/200], Loss: 0.1132
# 迭代: [172/200], Loss: 0.1072
# 迭代: [172/200], Loss: 0.1694
# 迭代: [172/200], Loss: 0.0929
# 迭代: [172/200], Loss: 0.0653
# 迭代: [172/200], Loss: 0.2185
# 迭代: [172/200], Loss: 0.1349
# 迭代: [172/200], Loss: 0.1439
# 迭代: [172/200], Loss: 0.1083
# 迭代: [172/200], Loss: 0.0749
# 迭代: [173/200], Loss: 0.1845
# 迭代: [173/200], Loss: 0.1555
# 迭代: [173/200], Loss: 0.0686
# 迭代: [173/200], Loss: 0.1140
# 迭代: [173/200], Loss: 0.1049
# 迭代: [173/200], Loss: 0.1346
# 迭代: [173/200], Loss: 0.1016
# 迭代: [173/200], Loss: 0.0966
# 迭代: [173/200], Loss: 0.1704
# 迭代: [173/200], Loss: 0.0992
# 迭代: [174/200], Loss: 0.1596
# 迭代: [174/200], Loss: 0.1067
# 迭代: [174/200], Loss: 0.1462
# 迭代: [174/200], Loss: 0.0632
# 迭代: [174/200], Loss: 0.1446
# 迭代: [174/200], Loss: 0.1406
# 迭代: [174/200], Loss: 0.1477
# 迭代: [174/200], Loss: 0.1293
# 迭代: [174/200], Loss: 0.0861
# 迭代: [174/200], Loss: 0.1010
# 迭代: [175/200], Loss: 0.0977
# 迭代: [175/200], Loss: 0.1175
# 迭代: [175/200], Loss: 0.1063
# 迭代: [175/200], Loss: 0.1102
# 迭代: [175/200], Loss: 0.1204
# 迭代: [175/200], Loss: 0.1785
# 迭代: [175/200], Loss: 0.1072
# 迭代: [175/200], Loss: 0.0374
# 迭代: [175/200], Loss: 0.1033
# 迭代: [175/200], Loss: 0.2447
# 迭代: [176/200], Loss: 0.0585
# 迭代: [176/200], Loss: 0.1188
# 迭代: [176/200], Loss: 0.2026
# 迭代: [176/200], Loss: 0.1668
# 迭代: [176/200], Loss: 0.1489
# 迭代: [176/200], Loss: 0.1232
# 迭代: [176/200], Loss: 0.0949
# 迭代: [176/200], Loss: 0.0746
# 迭代: [176/200], Loss: 0.0750
# 迭代: [176/200], Loss: 0.1548
# 迭代: [177/200], Loss: 0.1210
# 迭代: [177/200], Loss: 0.1674
# 迭代: [177/200], Loss: 0.1177
# 迭代: [177/200], Loss: 0.1378
# 迭代: [177/200], Loss: 0.1498
# 迭代: [177/200], Loss: 0.1844
# 迭代: [177/200], Loss: 0.0863
# 迭代: [177/200], Loss: 0.0483
# 迭代: [177/200], Loss: 0.0652
# 迭代: [177/200], Loss: 0.1427
# 迭代: [178/200], Loss: 0.1441
# 迭代: [178/200], Loss: 0.1247
# 迭代: [178/200], Loss: 0.0861
# 迭代: [178/200], Loss: 0.0794
# 迭代: [178/200], Loss: 0.1474
# 迭代: [178/200], Loss: 0.1438
# 迭代: [178/200], Loss: 0.0849
# 迭代: [178/200], Loss: 0.1579
# 迭代: [178/200], Loss: 0.1655
# 迭代: [178/200], Loss: 0.0798
# 迭代: [179/200], Loss: 0.1135
# 迭代: [179/200], Loss: 0.1395
# 迭代: [179/200], Loss: 0.1618
# 迭代: [179/200], Loss: 0.1215
# 迭代: [179/200], Loss: 0.1099
# 迭代: [179/200], Loss: 0.0839
# 迭代: [179/200], Loss: 0.1258
# 迭代: [179/200], Loss: 0.1041
# 迭代: [179/200], Loss: 0.0571
# 迭代: [179/200], Loss: 0.1946
# 迭代: [180/200], Loss: 0.0874
# 迭代: [180/200], Loss: 0.1213
# 迭代: [180/200], Loss: 0.0812
# 迭代: [180/200], Loss: 0.0404
# 迭代: [180/200], Loss: 0.1503
# 迭代: [180/200], Loss: 0.1737
# 迭代: [180/200], Loss: 0.1037
# 迭代: [180/200], Loss: 0.0793
# 迭代: [180/200], Loss: 0.1148
# 迭代: [180/200], Loss: 0.2594
# 迭代: [181/200], Loss: 0.1280
# 迭代: [181/200], Loss: 0.0692
# 迭代: [181/200], Loss: 0.1161
# 迭代: [181/200], Loss: 0.1351
# 迭代: [181/200], Loss: 0.1212
# 迭代: [181/200], Loss: 0.1109
# 迭代: [181/200], Loss: 0.1180
# 迭代: [181/200], Loss: 0.1126
# 迭代: [181/200], Loss: 0.1841
# 迭代: [181/200], Loss: 0.1113
# 迭代: [182/200], Loss: 0.1394
# 迭代: [182/200], Loss: 0.1872
# 迭代: [182/200], Loss: 0.1661
# 迭代: [182/200], Loss: 0.0801
# 迭代: [182/200], Loss: 0.1430
# 迭代: [182/200], Loss: 0.1196
# 迭代: [182/200], Loss: 0.1758
# 迭代: [182/200], Loss: 0.0516
# 迭代: [182/200], Loss: 0.0791
# 迭代: [182/200], Loss: 0.0638
# 迭代: [183/200], Loss: 0.1135
# 迭代: [183/200], Loss: 0.0713
# 迭代: [183/200], Loss: 0.1176
# 迭代: [183/200], Loss: 0.1231
# 迭代: [183/200], Loss: 0.1858
# 迭代: [183/200], Loss: 0.1315
# 迭代: [183/200], Loss: 0.0810
# 迭代: [183/200], Loss: 0.0846
# 迭代: [183/200], Loss: 0.1463
# 迭代: [183/200], Loss: 0.1470
# 迭代: [184/200], Loss: 0.1030
# 迭代: [184/200], Loss: 0.1278
# 迭代: [184/200], Loss: 0.0909
# 迭代: [184/200], Loss: 0.1026
# 迭代: [184/200], Loss: 0.0948
# 迭代: [184/200], Loss: 0.1684
# 迭代: [184/200], Loss: 0.1254
# 迭代: [184/200], Loss: 0.1542
# 迭代: [184/200], Loss: 0.1389
# 迭代: [184/200], Loss: 0.0926
# 迭代: [185/200], Loss: 0.1230
# 迭代: [185/200], Loss: 0.0874
# 迭代: [185/200], Loss: 0.1612
# 迭代: [185/200], Loss: 0.1055
# 迭代: [185/200], Loss: 0.1818
# 迭代: [185/200], Loss: 0.1569
# 迭代: [185/200], Loss: 0.0979
# 迭代: [185/200], Loss: 0.0930
# 迭代: [185/200], Loss: 0.0471
# 迭代: [185/200], Loss: 0.1403
# 迭代: [186/200], Loss: 0.1216
# 迭代: [186/200], Loss: 0.0903
# 迭代: [186/200], Loss: 0.1074
# 迭代: [186/200], Loss: 0.0962
# 迭代: [186/200], Loss: 0.1375
# 迭代: [186/200], Loss: 0.1731
# 迭代: [186/200], Loss: 0.0799
# 迭代: [186/200], Loss: 0.1213
# 迭代: [186/200], Loss: 0.1696
# 迭代: [186/200], Loss: 0.0997
# 迭代: [187/200], Loss: 0.1312
# 迭代: [187/200], Loss: 0.1039
# 迭代: [187/200], Loss: 0.0294
# 迭代: [187/200], Loss: 0.1148
# 迭代: [187/200], Loss: 0.1484
# 迭代: [187/200], Loss: 0.0807
# 迭代: [187/200], Loss: 0.1135
# 迭代: [187/200], Loss: 0.2404
# 迭代: [187/200], Loss: 0.1159
# 迭代: [187/200], Loss: 0.1116
# 迭代: [188/200], Loss: 0.1268
# 迭代: [188/200], Loss: 0.1148
# 迭代: [188/200], Loss: 0.0610
# 迭代: [188/200], Loss: 0.0740
# 迭代: [188/200], Loss: 0.1936
# 迭代: [188/200], Loss: 0.1677
# 迭代: [188/200], Loss: 0.1452
# 迭代: [188/200], Loss: 0.1104
# 迭代: [188/200], Loss: 0.0949
# 迭代: [188/200], Loss: 0.1014
# 迭代: [189/200], Loss: 0.0803
# 迭代: [189/200], Loss: 0.0851
# 迭代: [189/200], Loss: 0.0956
# 迭代: [189/200], Loss: 0.2010
# 迭代: [189/200], Loss: 0.1284
# 迭代: [189/200], Loss: 0.1172
# 迭代: [189/200], Loss: 0.1190
# 迭代: [189/200], Loss: 0.1280
# 迭代: [189/200], Loss: 0.1046
# 迭代: [189/200], Loss: 0.1272
# 迭代: [190/200], Loss: 0.1389
# 迭代: [190/200], Loss: 0.0558
# 迭代: [190/200], Loss: 0.0866
# 迭代: [190/200], Loss: 0.1084
# 迭代: [190/200], Loss: 0.1917
# 迭代: [190/200], Loss: 0.1137
# 迭代: [190/200], Loss: 0.0912
# 迭代: [190/200], Loss: 0.1185
# 迭代: [190/200], Loss: 0.0879
# 迭代: [190/200], Loss: 0.1902
# 迭代: [191/200], Loss: 0.0953
# 迭代: [191/200], Loss: 0.1371
# 迭代: [191/200], Loss: 0.1107
# 迭代: [191/200], Loss: 0.1444
# 迭代: [191/200], Loss: 0.1270
# 迭代: [191/200], Loss: 0.1231
# 迭代: [191/200], Loss: 0.1252
# 迭代: [191/200], Loss: 0.1392
# 迭代: [191/200], Loss: 0.0831
# 迭代: [191/200], Loss: 0.0987
# 迭代: [192/200], Loss: 0.1359
# 迭代: [192/200], Loss: 0.0921
# 迭代: [192/200], Loss: 0.0981
# 迭代: [192/200], Loss: 0.1822
# 迭代: [192/200], Loss: 0.1030
# 迭代: [192/200], Loss: 0.1305
# 迭代: [192/200], Loss: 0.1598
# 迭代: [192/200], Loss: 0.0932
# 迭代: [192/200], Loss: 0.0784
# 迭代: [192/200], Loss: 0.1038
# 迭代: [193/200], Loss: 0.1173
# 迭代: [193/200], Loss: 0.0979
# 迭代: [193/200], Loss: 0.1444
# 迭代: [193/200], Loss: 0.1070
# 迭代: [193/200], Loss: 0.1229
# 迭代: [193/200], Loss: 0.1214
# 迭代: [193/200], Loss: 0.1450
# 迭代: [193/200], Loss: 0.0848
# 迭代: [193/200], Loss: 0.1357
# 迭代: [193/200], Loss: 0.0981
# 迭代: [194/200], Loss: 0.1929
# 迭代: [194/200], Loss: 0.1091
# 迭代: [194/200], Loss: 0.1481
# 迭代: [194/200], Loss: 0.0923
# 迭代: [194/200], Loss: 0.1176
# 迭代: [194/200], Loss: 0.1231
# 迭代: [194/200], Loss: 0.1108
# 迭代: [194/200], Loss: 0.0800
# 迭代: [194/200], Loss: 0.0931
# 迭代: [194/200], Loss: 0.1062
# 迭代: [195/200], Loss: 0.0835
# 迭代: [195/200], Loss: 0.0666
# 迭代: [195/200], Loss: 0.1254
# 迭代: [195/200], Loss: 0.1775
# 迭代: [195/200], Loss: 0.0969
# 迭代: [195/200], Loss: 0.0961
# 迭代: [195/200], Loss: 0.1733
# 迭代: [195/200], Loss: 0.1445
# 迭代: [195/200], Loss: 0.1101
# 迭代: [195/200], Loss: 0.0970
# 迭代: [196/200], Loss: 0.1062
# 迭代: [196/200], Loss: 0.0892
# 迭代: [196/200], Loss: 0.1201
# 迭代: [196/200], Loss: 0.0521
# 迭代: [196/200], Loss: 0.1702
# 迭代: [196/200], Loss: 0.0956
# 迭代: [196/200], Loss: 0.1114
# 迭代: [196/200], Loss: 0.1537
# 迭代: [196/200], Loss: 0.1710
# 迭代: [196/200], Loss: 0.0990
# 迭代: [197/200], Loss: 0.1984
# 迭代: [197/200], Loss: 0.1113
# 迭代: [197/200], Loss: 0.0817
# 迭代: [197/200], Loss: 0.0583
# 迭代: [197/200], Loss: 0.0864
# 迭代: [197/200], Loss: 0.1018
# 迭代: [197/200], Loss: 0.1235
# 迭代: [197/200], Loss: 0.1043
# 迭代: [197/200], Loss: 0.1905
# 迭代: [197/200], Loss: 0.1098
# 迭代: [198/200], Loss: 0.1120
# 迭代: [198/200], Loss: 0.1271
# 迭代: [198/200], Loss: 0.1779
# 迭代: [198/200], Loss: 0.1192
# 迭代: [198/200], Loss: 0.1021
# 迭代: [198/200], Loss: 0.0761
# 迭代: [198/200], Loss: 0.1090
# 迭代: [198/200], Loss: 0.1130
# 迭代: [198/200], Loss: 0.1295
# 迭代: [198/200], Loss: 0.1045
# 迭代: [199/200], Loss: 0.1190
# 迭代: [199/200], Loss: 0.0872
# 迭代: [199/200], Loss: 0.0948
# 迭代: [199/200], Loss: 0.1722
# 迭代: [199/200], Loss: 0.0870
# 迭代: [199/200], Loss: 0.0765
# 迭代: [199/200], Loss: 0.1279
# 迭代: [199/200], Loss: 0.1571
# 迭代: [199/200], Loss: 0.1058
# 迭代: [199/200], Loss: 0.1335
# 迭代: [200/200], Loss: 0.1604
# 迭代: [200/200], Loss: 0.1493
# 迭代: [200/200], Loss: 0.1154
# 迭代: [200/200], Loss: 0.1063
# 迭代: [200/200], Loss: 0.1130
# 迭代: [200/200], Loss: 0.1190
# 迭代: [200/200], Loss: 0.0716
# 迭代: [200/200], Loss: 0.1180
# 迭代: [200/200], Loss: 0.1184
# 迭代: [200/200], Loss: 0.0888

# %% [markdown]
# #### 可视化loss

# %%
plt.plot(loss_arr)
#plt.ylim(0,0.1)

# %% [markdown]
# 测试：

# %%
import numpy as np
class PredDataset(Dataset):
    def __init__(self):
        self.x = np.random.rand(20)
        self.y = np.random.rand(20)
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        X = torch.tensor([self.x[idx],self.y[idx]]).float()
        return X
pred_data = PredDataset()
pred_dataloader = DataLoader(pred_data, batch_size=len(pred_data), shuffle=False)

# %%
def test(dataloader, model):
    model.eval()
    with torch.no_grad():
        for X in dataloader:
            X = X.to(device)
            pred = model(X)
            return pred
plot_y = test(pred_dataloader,model)

# %% [markdown]
# #### 结果可视化

# %%
testData = pd.DataFrame({'X':pred_data.x,'Y':pred_data.y,'Z':plot_y.cpu().reshape(-1)})
ODot = testData[testData['Z'] > 0.5]
YDot = testData[testData['Z'] < 0.5]

# %%
import numpy as np
plt.scatter(BDot['X'],BDot['Y'])
plt.scatter(RDot['X'],RDot['Y'],c='r')
plt.scatter(ODot['X'],ODot['Y'],c='m')
plt.scatter(YDot['X'],YDot['Y'],c='g')
print(list(model.parameters()))
w1 = list(model.parameters())[0][0,0].cpu().detach().numpy()
w2 = list(model.parameters())[0][0,1].cpu().detach().numpy()
b = list(model.parameters())[1][0].cpu().detach().numpy()
x= np.linspace(0,1,10)
y= -x * w1/w2 - b/w2
plt.plot(x,y)
plt.ylim(0,1)
# Out:
# [Parameter containing:
# tensor([[-13.5384,   6.9638]], device='cuda:0', requires_grad=True), Parameter containing:
# tensor([3.3116], device='cuda:0', requires_grad=True)]
# (0.0, 1.0)
